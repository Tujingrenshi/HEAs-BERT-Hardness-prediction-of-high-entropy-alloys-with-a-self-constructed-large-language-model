# %%
import numpy as np
import tensorflow as tf
import os
import json
# Out:
# 2025-12-31 14:17:22.598716: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
data_dir='..//..//二维高熵合金数据'

embedding_path = os.path.join(data_dir, 'alloy_embedding_matrices.npy')
X_all = np.load(embedding_path)

hv_path = os.path.join(data_dir, 'HV_values.npy')
Y_all = np.load(hv_path)

info_path = os.path.join(data_dir, 'data_info.json')
with open(info_path, 'r', encoding='utf-8') as f:
    data_info = json.load(f)

print(f"✓ 数据加载完成")
print(f"  样本数量: {len(X_all)}")
print(f"  嵌入矩阵形状: {X_all.shape}")
print(f"  HV值范围: [{Y_all.min():.2f}, {Y_all.max():.2f}]")

X_all = np.expand_dims(X_all, axis=1)
print(f"  调整后形状: {X_all.shape}")
# Out:
# ✓ 数据加载完成
#   样本数量: 483
#   嵌入矩阵形状: (483, 21, 768)
#   HV值范围: [109.00, 1084.00]
#   调整后形状: (483, 1, 21, 768)

# %%
# 在所有导入之前
import os
os.environ['PYTHONHASHSEED'] = '42'
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# 然后再导入其他库
import numpy as np
import tensorflow as tf
import os
import json
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# 设置中文字体
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei', 'DejaVu Sans']
matplotlib.rcParams['axes.unicode_minus'] = False

# 2. 在set_random_seeds函数中添加GPU配置
def set_random_seeds(seed):
    """设置所有可能的随机种子"""
    import random
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['PYTHONHASHSEED'] = str(seed)
    
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()
    
    # 添加GPU内存配置
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(f"GPU配置警告: {e}")

# 设置随机种子
SEED = 20
set_random_seeds(SEED)

# 输入输出目录
output_dir = './best_model_final_0'


# ============================================================================
# 1. 数据加载函数
# ============================================================================
def load_embedding_data(data_dir='..//..//二维高熵合金数据'):
    """加载生成的嵌入矩阵数据"""
    print("="*60)
    print("加载数据...")
    print("="*60)
    
    embedding_path = os.path.join(data_dir, 'alloy_embedding_matrices.npy')
    X_all = np.load(embedding_path)
    
    hv_path = os.path.join(data_dir, 'HV_values.npy')
    Y_all = np.load(hv_path)
    
    info_path = os.path.join(data_dir, 'data_info.json')
    with open(info_path, 'r', encoding='utf-8') as f:
        data_info = json.load(f)
    
    print(f"✓ 数据加载完成")
    print(f"  样本数量: {len(X_all)}")
    print(f"  嵌入矩阵形状: {X_all.shape}")
    print(f"  HV值范围: [{Y_all.min():.2f}, {Y_all.max():.2f}]")
    
    X_all = np.expand_dims(X_all, axis=1)
    print(f"  调整后形状: {X_all.shape}")
    
    return X_all, Y_all, data_info

# ============================================================================
# 2. CNN模型构建函数
# ============================================================================
def build_cnn_model(input_shape, hyperparams):
    """根据超参数构建CNN模型"""
    model = Sequential()
    
    conv_filters = hyperparams['conv_filters']
    kernel_size = hyperparams['kernel_size']
    use_batch_norm = hyperparams['use_batch_norm']
    dropout_rate = hyperparams['dropout_rate']
    activation = hyperparams['activation']
    
    # 第一个卷积层
    model.add(Conv2D(
        filters=conv_filters[0],
        kernel_size=kernel_size,
        strides=1,
        padding='same',
        data_format='channels_first',
        activation=activation,
        input_shape=input_shape
    ))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='same', 
                           data_format='channels_first'))
    
    # 第二个卷积层
    model.add(Conv2D(conv_filters[1], kernel_size, strides=1, padding='same',
                     data_format='channels_first', activation=activation))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D((2, 2), 2, 'same', data_format='channels_first'))
    
    # 第三个卷积层
    model.add(Conv2D(conv_filters[2], kernel_size, strides=1, padding='same',
                     data_format='channels_first', activation=activation))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D((2, 2), 2, 'same', data_format='channels_first'))
    
    # 展平
    model.add(Flatten())
    
    # 全连接层
    dense_units = hyperparams['dense_units']
    for units in dense_units:
        model.add(Dense(units, activation=activation))
        if dropout_rate > 0:
            model.add(Dropout(dropout_rate))
    
    # 输出层
    model.add(Dense(1, activation='linear'))
    
    # 编译模型
    adam = Adam(learning_rate=hyperparams['learning_rate'])
    model.compile(
        optimizer=adam, 
        loss='mean_squared_error',
        metrics=[
            tf.keras.metrics.RootMeanSquaredError(),
            tf.keras.metrics.MeanAbsoluteError()
        ]
    )
    
    return model

# ============================================================================
# 3. 使用最佳参数进行完整训练
# ============================================================================
def train_with_best_params(X_all, Y_all, best_params, output_dir='./best_model_results'):
    """使用最佳参数进行完整的十折交叉验证训练"""
    os.makedirs(output_dir, exist_ok=True)
    
    print("\n" + "="*60)
    print("使用最佳参数进行完整训练")
    print("="*60)
    print(f"\n最佳参数:")
    for k, v in best_params.items():
        if k in ['conv_filters', 'dense_units']:
            print(f"  {k}: {list(v)}")
        else:
            print(f"  {k}: {v}")
    print("="*60)
    
    kf = KFold(n_splits=10, random_state=2*10+55, shuffle=True)
    
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    results_file = os.path.join(output_dir, 'training_results.csv')
    with open(results_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['fold', 'loss_train', 'loss_test', 'r_train', 
                        'r_test', 'mae', 'rmse'])
    
    # 创建每折预测结果保存目录
    predictions_dir = os.path.join(output_dir, 'fold_predictions')
    os.makedirs(predictions_dir, exist_ok=True)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(X_all)):
        print(f"\n第 {fold + 1}/10 折")
        
        x_train, x_test = X_all[train_idx], X_all[test_idx]
        y_train, y_test = Y_all[train_idx], Y_all[test_idx]
        
        # 保存每折的模型
        model_path = os.path.join(output_dir, f'best_model_fold_{fold}.h5')
        
        callbacks = [
            # EarlyStopping(
            #     monitor='val_loss',
            #     patience=30,
            #     min_delta=0.0001,
            #     restore_best_weights=True,
            #     verbose=1,
            #     mode='min'
            # ),
            ModelCheckpoint(
                filepath=model_path,
                monitor='val_loss',
                save_best_only=True,
                mode='min',
                verbose=1
            )
        ]
        
        input_shape = x_train.shape[1:]
        model = build_cnn_model(input_shape, best_params)
        
        history = model.fit(
            x_train, y_train,
            epochs=500,
            batch_size=best_params['batch_size'],
            validation_data=(x_train, y_train),
            callbacks=callbacks,
            verbose=1
        )
        
        # 加载最佳模型
        model = load_model(model_path)
        
        loss_train, rmse_train, mae_train = model.evaluate(x_train, y_train, verbose=0)
        loss_test, rmse_test, mae_test = model.evaluate(x_test, y_test, verbose=0)
        
        # 预测
        pred_train = model.predict(x_train, batch_size=best_params['batch_size'], verbose=0).reshape(-1)
        pred_test = model.predict(x_test, batch_size=best_params['batch_size'], verbose=0).reshape(-1)
        
        r_train = np.corrcoef(pred_train, y_train)[0, 1]
        r_test = np.corrcoef(pred_test, y_test)[0, 1]
        
        mae = mean_absolute_error(y_test, pred_test)
        rmse = mean_squared_error(y_test, pred_test) ** 0.5
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r_test)
        
        print(f"  测试集 R: {r_test:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
        
        with open(results_file, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([fold, loss_train, loss_test, r_train, r_test, mae, rmse])
        
        # ========== 保存训练集预测结果 ==========
        train_predictions_file = os.path.join(predictions_dir, f'fold_{fold}_train_predictions.csv')
        with open(train_predictions_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['original_index', 'true_value', 'predicted_value', 'error'])
            for idx, true_val, pred_val in zip(train_idx, y_train, pred_train):
                writer.writerow([idx, true_val, pred_val, abs(true_val - pred_val)])
        
        # ========== 保存验证集(测试集)预测结果 ==========
        test_predictions_file = os.path.join(predictions_dir, f'fold_{fold}_test_predictions.csv')
        with open(test_predictions_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['original_index', 'true_value', 'predicted_value', 'error'])
            for idx, true_val, pred_val in zip(test_idx, y_test, pred_test):
                writer.writerow([idx, true_val, pred_val, abs(true_val - pred_val)])
        
        # ========== 保存训练集索引 ==========
        train_indices_file = os.path.join(predictions_dir, f'fold_{fold}_train_indices.npy')
        np.save(train_indices_file, train_idx)
        
        # ========== 保存验证集索引 ==========
        test_indices_file = os.path.join(predictions_dir, f'fold_{fold}_test_indices.npy')
        np.save(test_indices_file, test_idx)
        
        print(f"  ✓ 已保存模型: {model_path}")
        print(f"  ✓ 已保存训练集预测: {train_predictions_file}")
        print(f"  ✓ 已保存验证集预测: {test_predictions_file}")
        
        del model
        tf.keras.backend.clear_session()
    
    # 保存汇总结果
    serializable_params = best_params.copy()
    for key in ['conv_filters', 'dense_units']:
        if key in serializable_params:
            serializable_params[key] = list(serializable_params[key])
    
    summary = {
        'R2_mean': float(np.mean(all_r2)),
        'R2_std': float(np.std(all_r2)),
        'MAE_mean': float(np.mean(all_mae)),
        'MAE_std': float(np.std(all_mae)),
        'RMSE_mean': float(np.mean(all_rmse)),
        'RMSE_std': float(np.std(all_rmse)),
        'best_params': serializable_params
    }
    
    with open(os.path.join(output_dir, 'summary.json'), 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)
    
    print("\n" + "="*60)
    print("最佳模型训练完成!")
    print("="*60)
    print(f"\n总体结果:")
    print(f"  R²:   {np.mean(all_r2):.4f} ± {np.std(all_r2):.4f}")
    print(f"  MAE:  {np.mean(all_mae):.4f} ± {np.std(all_mae):.4f}")
    print(f"  RMSE: {np.mean(all_rmse):.4f} ± {np.std(all_rmse):.4f}")
    print(f"\n结果保存位置:")
    print(f"  - 模型文件: {output_dir}/best_model_fold_*.h5")
    print(f"  - 预测结果: {predictions_dir}/")
    print(f"  - 汇总信息: {output_dir}/summary.json")
    print(f"  - 训练结果: {output_dir}/training_results.csv")
    
    return summary

# ============================================================================
# 4. 主函数
# ============================================================================
def main():
    """使用最佳参数进行训练"""
    print("="*60)
    print("CNN最佳参数训练 - 高熵合金硬度预测")
    print("="*60)
    
    # 加载数据
    X_all, Y_all, data_info = load_embedding_data()
    
    # 最佳参数（来自调参结果）
    best_params = {
        'conv_filters': [12, 28, 56],
        'dense_units': [256, 128, 64, 16],
        'kernel_size': (5, 5),
        'learning_rate': 0.00010956749686519973,
        'batch_size': 12,
        'dropout_rate': 0.0097086836073558,
        'use_batch_norm': True,
        'activation': 'selu'
    }
    
    # 训练模型
    summary = train_with_best_params(X_all, Y_all, best_params, output_dir=output_dir)
    
    print("\n" + "="*60)
    print("所有任务完成!")
    print("="*60)

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# CNN最佳参数训练 - 高熵合金硬度预测
# ============================================================
# ============================================================
# 加载数据...
# ============================================================
# ✓ 数据加载完成
#   样本数量: 483
#   嵌入矩阵形状: (483, 21, 768)
#   HV值范围: [109.00, 1084.00]
#   调整后形状: (483, 1, 21, 768)
#
# ============================================================
# 使用最佳参数进行完整训练
# ============================================================
#
# 最佳参数:
#   conv_filters: [12, 28, 56]
#   dense_units: [256, 128, 64, 16]
#   kernel_size: (5, 5)
#   learning_rate: 0.00010956749686519973
#   batch_size: 12
#   dropout_rate: 0.0097086836073558
#   use_batch_norm: True
#   activation: selu
# ============================================================
#
# 第 1/10 折
# 2025-12-31 14:17:27.283045: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-31 14:17:28.253500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22034 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090 D, pci bus id: 0000:42:00.0, compute capability: 8.9
# Epoch 1/500
# 2025-12-31 14:17:30.132082: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2025-12-31 14:17:31.273692: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2025-12-31 14:17:31.273711: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2025-12-31 14:17:31.273784: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-12-31 14:17:32.329486: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 37/37 [==============================] - ETA: 0s - loss: 164350.1250 - root_mean_squared_error: 405.4012 - mean_absolute_error: 342.9235
# Epoch 1: val_loss improved from inf to 236218.95312, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 5s 21ms/step - loss: 164350.1250 - root_mean_squared_error: 405.4012 - mean_absolute_error: 342.9235 - val_loss: 236218.9531 - val_root_mean_squared_error: 486.0236 - val_mean_absolute_error: 436.8827
# Epoch 2/500
# 30/37 [=======================>......] - ETA: 0s - loss: 29013.4414 - root_mean_squared_error: 170.3333 - mean_absolute_error: 135.6862
# Epoch 2: val_loss improved from 236218.95312 to 228381.34375, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 26935.8320 - root_mean_squared_error: 164.1214 - mean_absolute_error: 130.2762 - val_loss: 228381.3438 - val_root_mean_squared_error: 477.8926 - val_mean_absolute_error: 432.3725
# Epoch 3/500
# 34/37 [==========================>...] - ETA: 0s - loss: 17233.5879 - root_mean_squared_error: 131.2768 - mean_absolute_error: 100.3055
# Epoch 3: val_loss improved from 228381.34375 to 168397.45312, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 16784.7402 - root_mean_squared_error: 129.5559 - mean_absolute_error: 98.6170 - val_loss: 168397.4531 - val_root_mean_squared_error: 410.3626 - val_mean_absolute_error: 357.5006
# Epoch 4/500
# 31/37 [========================>.....] - ETA: 0s - loss: 14912.0742 - root_mean_squared_error: 122.1150 - mean_absolute_error: 94.4972
# Epoch 4: val_loss improved from 168397.45312 to 132421.01562, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 0s 12ms/step - loss: 14954.8271 - root_mean_squared_error: 122.2899 - mean_absolute_error: 95.4322 - val_loss: 132421.0156 - val_root_mean_squared_error: 363.8970 - val_mean_absolute_error: 306.5377
# Epoch 5/500
# 36/37 [============================>.] - ETA: 0s - loss: 14386.1914 - root_mean_squared_error: 119.9424 - mean_absolute_error: 93.9240
# Epoch 5: val_loss improved from 132421.01562 to 120860.57812, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 14330.9219 - root_mean_squared_error: 119.7118 - mean_absolute_error: 93.7164 - val_loss: 120860.5781 - val_root_mean_squared_error: 347.6501 - val_mean_absolute_error: 290.6195
# Epoch 6/500
# 34/37 [==========================>...] - ETA: 0s - loss: 12339.2539 - root_mean_squared_error: 111.0822 - mean_absolute_error: 85.7691
# Epoch 6: val_loss improved from 120860.57812 to 89555.64844, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 12247.9932 - root_mean_squared_error: 110.6707 - mean_absolute_error: 85.8031 - val_loss: 89555.6484 - val_root_mean_squared_error: 299.2585 - val_mean_absolute_error: 246.0464
# Epoch 7/500
# 34/37 [==========================>...] - ETA: 0s - loss: 11080.9229 - root_mean_squared_error: 105.2660 - mean_absolute_error: 79.1628
# Epoch 7: val_loss improved from 89555.64844 to 74094.64844, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 10838.4297 - root_mean_squared_error: 104.1078 - mean_absolute_error: 78.5868 - val_loss: 74094.6484 - val_root_mean_squared_error: 272.2033 - val_mean_absolute_error: 222.5680
# Epoch 8/500
# 33/37 [=========================>....] - ETA: 0s - loss: 10808.3477 - root_mean_squared_error: 103.9632 - mean_absolute_error: 77.8939
# Epoch 8: val_loss improved from 74094.64844 to 45478.35156, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 10380.4697 - root_mean_squared_error: 101.8846 - mean_absolute_error: 76.3093 - val_loss: 45478.3516 - val_root_mean_squared_error: 213.2565 - val_mean_absolute_error: 175.2447
# Epoch 9/500
# 32/37 [========================>.....] - ETA: 0s - loss: 9979.2246 - root_mean_squared_error: 99.8961 - mean_absolute_error: 74.4740
# Epoch 9: val_loss improved from 45478.35156 to 33027.99219, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 10359.3584 - root_mean_squared_error: 101.7809 - mean_absolute_error: 75.6150 - val_loss: 33027.9922 - val_root_mean_squared_error: 181.7361 - val_mean_absolute_error: 149.7095
# Epoch 10/500
# 36/37 [============================>.] - ETA: 0s - loss: 9846.2139 - root_mean_squared_error: 99.2281 - mean_absolute_error: 76.4632
# Epoch 10: val_loss improved from 33027.99219 to 32445.50195, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 9807.5010 - root_mean_squared_error: 99.0328 - mean_absolute_error: 76.2846 - val_loss: 32445.5020 - val_root_mean_squared_error: 180.1263 - val_mean_absolute_error: 147.5921
# Epoch 11/500
# 36/37 [============================>.] - ETA: 0s - loss: 9243.3066 - root_mean_squared_error: 96.1421 - mean_absolute_error: 73.6952
# Epoch 11: val_loss improved from 32445.50195 to 19075.92188, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 9206.8662 - root_mean_squared_error: 95.9524 - mean_absolute_error: 73.4815 - val_loss: 19075.9219 - val_root_mean_squared_error: 138.1156 - val_mean_absolute_error: 114.3211
# Epoch 12/500
# 32/37 [========================>.....] - ETA: 0s - loss: 8277.0664 - root_mean_squared_error: 90.9784 - mean_absolute_error: 68.9568
# Epoch 12: val_loss improved from 19075.92188 to 16048.31152, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 7920.2471 - root_mean_squared_error: 88.9958 - mean_absolute_error: 67.4480 - val_loss: 16048.3115 - val_root_mean_squared_error: 126.6819 - val_mean_absolute_error: 104.5573
# Epoch 13/500
# 33/37 [=========================>....] - ETA: 0s - loss: 7879.5195 - root_mean_squared_error: 88.7667 - mean_absolute_error: 68.6685
# Epoch 13: val_loss improved from 16048.31152 to 12145.46973, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 8160.7852 - root_mean_squared_error: 90.3371 - mean_absolute_error: 68.7918 - val_loss: 12145.4697 - val_root_mean_squared_error: 110.2065 - val_mean_absolute_error: 89.1712
# Epoch 14/500
# 33/37 [=========================>....] - ETA: 0s - loss: 6754.1094 - root_mean_squared_error: 82.1834 - mean_absolute_error: 62.8694
# Epoch 14: val_loss improved from 12145.46973 to 9030.91211, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 17ms/step - loss: 6867.3486 - root_mean_squared_error: 82.8695 - mean_absolute_error: 63.2598 - val_loss: 9030.9121 - val_root_mean_squared_error: 95.0311 - val_mean_absolute_error: 77.7704
# Epoch 15/500
# 28/37 [=====================>........] - ETA: 0s - loss: 6991.1929 - root_mean_squared_error: 83.6133 - mean_absolute_error: 62.8932
# Epoch 15: val_loss did not improve from 9030.91211
# 37/37 [==============================] - 0s 10ms/step - loss: 6705.3218 - root_mean_squared_error: 81.8860 - mean_absolute_error: 61.1799 - val_loss: 10500.1758 - val_root_mean_squared_error: 102.4704 - val_mean_absolute_error: 81.6519
# Epoch 16/500
# 35/37 [===========================>..] - ETA: 0s - loss: 6838.2725 - root_mean_squared_error: 82.6938 - mean_absolute_error: 64.7180
# Epoch 16: val_loss did not improve from 9030.91211
# 37/37 [==============================] - 0s 11ms/step - loss: 6867.5581 - root_mean_squared_error: 82.8707 - mean_absolute_error: 64.8331 - val_loss: 9841.6416 - val_root_mean_squared_error: 99.2051 - val_mean_absolute_error: 80.9488
# Epoch 17/500
# 33/37 [=========================>....] - ETA: 0s - loss: 6961.5728 - root_mean_squared_error: 83.4360 - mean_absolute_error: 64.4492
# Epoch 17: val_loss improved from 9030.91211 to 5822.52344, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 0s 14ms/step - loss: 6815.3838 - root_mean_squared_error: 82.5553 - mean_absolute_error: 64.1913 - val_loss: 5822.5234 - val_root_mean_squared_error: 76.3055 - val_mean_absolute_error: 59.6572
# Epoch 18/500
# 34/37 [==========================>...] - ETA: 0s - loss: 6493.9199 - root_mean_squared_error: 80.5849 - mean_absolute_error: 60.7021
# Epoch 18: val_loss improved from 5822.52344 to 4593.86816, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 0s 14ms/step - loss: 6399.5586 - root_mean_squared_error: 79.9972 - mean_absolute_error: 60.0623 - val_loss: 4593.8682 - val_root_mean_squared_error: 67.7781 - val_mean_absolute_error: 51.9730
# Epoch 19/500
# 33/37 [=========================>....] - ETA: 0s - loss: 5118.7031 - root_mean_squared_error: 71.5451 - mean_absolute_error: 55.3559
# Epoch 19: val_loss did not improve from 4593.86816
# 37/37 [==============================] - 0s 13ms/step - loss: 5200.8003 - root_mean_squared_error: 72.1166 - mean_absolute_error: 55.3676 - val_loss: 5119.2920 - val_root_mean_squared_error: 71.5492 - val_mean_absolute_error: 56.4305
# Epoch 20/500
# 37/37 [==============================] - ETA: 0s - loss: 5240.1987 - root_mean_squared_error: 72.3892 - mean_absolute_error: 54.7435
# Epoch 20: val_loss improved from 4593.86816 to 3667.92334, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 5240.1987 - root_mean_squared_error: 72.3892 - mean_absolute_error: 54.7435 - val_loss: 3667.9233 - val_root_mean_squared_error: 60.5634 - val_mean_absolute_error: 45.9316
# Epoch 21/500
# 34/37 [==========================>...] - ETA: 0s - loss: 5200.0815 - root_mean_squared_error: 72.1116 - mean_absolute_error: 55.4890
# Epoch 21: val_loss did not improve from 3667.92334
# 37/37 [==============================] - 0s 11ms/step - loss: 5617.4883 - root_mean_squared_error: 74.9499 - mean_absolute_error: 57.3336 - val_loss: 4641.0933 - val_root_mean_squared_error: 68.1256 - val_mean_absolute_error: 53.7786
# Epoch 22/500
# 30/37 [=======================>......] - ETA: 0s - loss: 4743.3730 - root_mean_squared_error: 68.8721 - mean_absolute_error: 51.8939
# Epoch 22: val_loss did not improve from 3667.92334
# 37/37 [==============================] - 0s 10ms/step - loss: 5092.5518 - root_mean_squared_error: 71.3621 - mean_absolute_error: 53.5080 - val_loss: 3819.3413 - val_root_mean_squared_error: 61.8008 - val_mean_absolute_error: 47.9978
# Epoch 23/500
# 35/37 [===========================>..] - ETA: 0s - loss: 4311.7114 - root_mean_squared_error: 65.6636 - mean_absolute_error: 49.9398
# Epoch 23: val_loss did not improve from 3667.92334
# 37/37 [==============================] - 0s 11ms/step - loss: 4337.6509 - root_mean_squared_error: 65.8608 - mean_absolute_error: 50.1774 - val_loss: 10052.6553 - val_root_mean_squared_error: 100.2629 - val_mean_absolute_error: 87.5678
# Epoch 24/500
# 36/37 [============================>.] - ETA: 0s - loss: 4452.1895 - root_mean_squared_error: 66.7247 - mean_absolute_error: 50.2828
# Epoch 24: val_loss did not improve from 3667.92334
# 37/37 [==============================] - 0s 12ms/step - loss: 4455.6855 - root_mean_squared_error: 66.7509 - mean_absolute_error: 50.3118 - val_loss: 4510.1543 - val_root_mean_squared_error: 67.1577 - val_mean_absolute_error: 52.1605
# Epoch 25/500
# 35/37 [===========================>..] - ETA: 0s - loss: 4693.4629 - root_mean_squared_error: 68.5089 - mean_absolute_error: 51.4278
# Epoch 25: val_loss improved from 3667.92334 to 2972.98340, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 0s 14ms/step - loss: 4686.3672 - root_mean_squared_error: 68.4570 - mean_absolute_error: 51.4811 - val_loss: 2972.9834 - val_root_mean_squared_error: 54.5251 - val_mean_absolute_error: 42.0462
# Epoch 26/500
# 35/37 [===========================>..] - ETA: 0s - loss: 4844.6094 - root_mean_squared_error: 69.6032 - mean_absolute_error: 52.7684
# Epoch 26: val_loss did not improve from 2972.98340
# 37/37 [==============================] - 0s 11ms/step - loss: 4762.9023 - root_mean_squared_error: 69.0138 - mean_absolute_error: 52.2700 - val_loss: 3437.9453 - val_root_mean_squared_error: 58.6340 - val_mean_absolute_error: 45.8669
# Epoch 27/500
# 36/37 [============================>.] - ETA: 0s - loss: 4788.6382 - root_mean_squared_error: 69.2000 - mean_absolute_error: 53.3026
# Epoch 27: val_loss did not improve from 2972.98340
# 37/37 [==============================] - 0s 12ms/step - loss: 4774.3135 - root_mean_squared_error: 69.0964 - mean_absolute_error: 53.2419 - val_loss: 3232.3228 - val_root_mean_squared_error: 56.8535 - val_mean_absolute_error: 42.9536
# Epoch 28/500
# 35/37 [===========================>..] - ETA: 0s - loss: 4214.6270 - root_mean_squared_error: 64.9202 - mean_absolute_error: 49.1844
# Epoch 28: val_loss did not improve from 2972.98340
# 37/37 [==============================] - 0s 11ms/step - loss: 4219.6606 - root_mean_squared_error: 64.9589 - mean_absolute_error: 49.2431 - val_loss: 3310.5903 - val_root_mean_squared_error: 57.5377 - val_mean_absolute_error: 43.6507
# Epoch 29/500
# 33/37 [=========================>....] - ETA: 0s - loss: 5400.2354 - root_mean_squared_error: 73.4863 - mean_absolute_error: 55.8941
# Epoch 29: val_loss did not improve from 2972.98340
# 37/37 [==============================] - 0s 12ms/step - loss: 5377.7607 - root_mean_squared_error: 73.3332 - mean_absolute_error: 55.8280 - val_loss: 3831.9148 - val_root_mean_squared_error: 61.9025 - val_mean_absolute_error: 49.2663
# Epoch 30/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4862.5107 - root_mean_squared_error: 69.7317 - mean_absolute_error: 52.5984
# Epoch 30: val_loss improved from 2972.98340 to 2879.32544, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 5004.8745 - root_mean_squared_error: 70.7451 - mean_absolute_error: 53.6145 - val_loss: 2879.3254 - val_root_mean_squared_error: 53.6593 - val_mean_absolute_error: 41.1902
# Epoch 31/500
# 34/37 [==========================>...] - ETA: 0s - loss: 4194.7861 - root_mean_squared_error: 64.7672 - mean_absolute_error: 48.9163
# Epoch 31: val_loss improved from 2879.32544 to 2468.91846, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 4250.0688 - root_mean_squared_error: 65.1926 - mean_absolute_error: 49.2301 - val_loss: 2468.9185 - val_root_mean_squared_error: 49.6882 - val_mean_absolute_error: 38.3541
# Epoch 32/500
# 34/37 [==========================>...] - ETA: 0s - loss: 4167.5835 - root_mean_squared_error: 64.5568 - mean_absolute_error: 48.5062
# Epoch 32: val_loss improved from 2468.91846 to 2151.14380, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 4111.6182 - root_mean_squared_error: 64.1219 - mean_absolute_error: 48.2431 - val_loss: 2151.1438 - val_root_mean_squared_error: 46.3804 - val_mean_absolute_error: 34.5206
# Epoch 33/500
# 35/37 [===========================>..] - ETA: 0s - loss: 4269.3359 - root_mean_squared_error: 65.3402 - mean_absolute_error: 48.6019
# Epoch 33: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 11ms/step - loss: 4296.7900 - root_mean_squared_error: 65.5499 - mean_absolute_error: 48.6252 - val_loss: 2311.8020 - val_root_mean_squared_error: 48.0812 - val_mean_absolute_error: 36.3440
# Epoch 34/500
# 33/37 [=========================>....] - ETA: 0s - loss: 3349.7454 - root_mean_squared_error: 57.8770 - mean_absolute_error: 45.3460
# Epoch 34: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 13ms/step - loss: 3240.1077 - root_mean_squared_error: 56.9219 - mean_absolute_error: 44.6941 - val_loss: 2242.0793 - val_root_mean_squared_error: 47.3506 - val_mean_absolute_error: 35.0605
# Epoch 35/500
# 33/37 [=========================>....] - ETA: 0s - loss: 3326.8254 - root_mean_squared_error: 57.6786 - mean_absolute_error: 44.2050
# Epoch 35: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 13ms/step - loss: 3431.1042 - root_mean_squared_error: 58.5756 - mean_absolute_error: 44.8715 - val_loss: 2220.1890 - val_root_mean_squared_error: 47.1189 - val_mean_absolute_error: 35.6658
# Epoch 36/500
# 37/37 [==============================] - ETA: 0s - loss: 3610.8799 - root_mean_squared_error: 60.0906 - mean_absolute_error: 45.4213
# Epoch 36: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 12ms/step - loss: 3610.8799 - root_mean_squared_error: 60.0906 - mean_absolute_error: 45.4213 - val_loss: 2222.0510 - val_root_mean_squared_error: 47.1386 - val_mean_absolute_error: 36.6304
# Epoch 37/500
# 29/37 [======================>.......] - ETA: 0s - loss: 4197.5649 - root_mean_squared_error: 64.7886 - mean_absolute_error: 49.1028
# Epoch 37: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 9ms/step - loss: 3915.7695 - root_mean_squared_error: 62.5761 - mean_absolute_error: 47.9745 - val_loss: 2649.0066 - val_root_mean_squared_error: 51.4685 - val_mean_absolute_error: 40.1395
# Epoch 38/500
# 32/37 [========================>.....] - ETA: 0s - loss: 3026.4639 - root_mean_squared_error: 55.0133 - mean_absolute_error: 41.7935
# Epoch 38: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 10ms/step - loss: 3107.7607 - root_mean_squared_error: 55.7473 - mean_absolute_error: 42.4145 - val_loss: 4392.9561 - val_root_mean_squared_error: 66.2794 - val_mean_absolute_error: 55.1177
# Epoch 39/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3422.3191 - root_mean_squared_error: 58.5006 - mean_absolute_error: 43.9751
# Epoch 39: val_loss did not improve from 2151.14380
# 37/37 [==============================] - 0s 12ms/step - loss: 3452.8042 - root_mean_squared_error: 58.7606 - mean_absolute_error: 44.1599 - val_loss: 3612.8386 - val_root_mean_squared_error: 60.1069 - val_mean_absolute_error: 47.8957
# Epoch 40/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3099.0508 - root_mean_squared_error: 55.6691 - mean_absolute_error: 42.1394
# Epoch 40: val_loss improved from 2151.14380 to 1911.97986, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 3208.8665 - root_mean_squared_error: 56.6469 - mean_absolute_error: 42.4818 - val_loss: 1911.9799 - val_root_mean_squared_error: 43.7262 - val_mean_absolute_error: 32.3453
# Epoch 41/500
# 36/37 [============================>.] - ETA: 0s - loss: 3135.7686 - root_mean_squared_error: 55.9979 - mean_absolute_error: 41.6832
# Epoch 41: val_loss did not improve from 1911.97986
# 37/37 [==============================] - 0s 12ms/step - loss: 3122.5886 - root_mean_squared_error: 55.8801 - mean_absolute_error: 41.5536 - val_loss: 2432.5037 - val_root_mean_squared_error: 49.3204 - val_mean_absolute_error: 38.3856
# Epoch 42/500
# 29/37 [======================>.......] - ETA: 0s - loss: 3471.7239 - root_mean_squared_error: 58.9213 - mean_absolute_error: 44.3247
# Epoch 42: val_loss did not improve from 1911.97986
# 37/37 [==============================] - 0s 11ms/step - loss: 3545.2439 - root_mean_squared_error: 59.5420 - mean_absolute_error: 45.4767 - val_loss: 2854.3191 - val_root_mean_squared_error: 53.4258 - val_mean_absolute_error: 41.9929
# Epoch 43/500
# 37/37 [==============================] - ETA: 0s - loss: 4030.6245 - root_mean_squared_error: 63.4872 - mean_absolute_error: 46.7800
# Epoch 43: val_loss did not improve from 1911.97986
# 37/37 [==============================] - 0s 12ms/step - loss: 4030.6245 - root_mean_squared_error: 63.4872 - mean_absolute_error: 46.7800 - val_loss: 9151.0557 - val_root_mean_squared_error: 95.6611 - val_mean_absolute_error: 86.4487
# Epoch 44/500
# 32/37 [========================>.....] - ETA: 0s - loss: 3335.1633 - root_mean_squared_error: 57.7509 - mean_absolute_error: 42.7032
# Epoch 44: val_loss improved from 1911.97986 to 1574.54712, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 3277.5942 - root_mean_squared_error: 57.2503 - mean_absolute_error: 42.9239 - val_loss: 1574.5471 - val_root_mean_squared_error: 39.6806 - val_mean_absolute_error: 28.6525
# Epoch 45/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2983.8999 - root_mean_squared_error: 54.6251 - mean_absolute_error: 40.7089
# Epoch 45: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 0s 11ms/step - loss: 2954.7632 - root_mean_squared_error: 54.3577 - mean_absolute_error: 40.6351 - val_loss: 2165.2366 - val_root_mean_squared_error: 46.5321 - val_mean_absolute_error: 35.0247
# Epoch 46/500
# 29/37 [======================>.......] - ETA: 0s - loss: 3548.0618 - root_mean_squared_error: 59.5656 - mean_absolute_error: 43.9018
# Epoch 46: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 0s 11ms/step - loss: 3556.7314 - root_mean_squared_error: 59.6383 - mean_absolute_error: 44.0077 - val_loss: 4086.7546 - val_root_mean_squared_error: 63.9277 - val_mean_absolute_error: 54.6484
# Epoch 47/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2932.0498 - root_mean_squared_error: 54.1484 - mean_absolute_error: 39.5763
# Epoch 47: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 1s 14ms/step - loss: 2888.0222 - root_mean_squared_error: 53.7403 - mean_absolute_error: 39.7514 - val_loss: 3467.5193 - val_root_mean_squared_error: 58.8856 - val_mean_absolute_error: 49.5142
# Epoch 48/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2441.4836 - root_mean_squared_error: 49.4114 - mean_absolute_error: 37.0800
# Epoch 48: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 0s 12ms/step - loss: 2549.8079 - root_mean_squared_error: 50.4956 - mean_absolute_error: 37.6280 - val_loss: 1668.1964 - val_root_mean_squared_error: 40.8436 - val_mean_absolute_error: 29.6010
# Epoch 49/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2496.8958 - root_mean_squared_error: 49.9689 - mean_absolute_error: 39.2928
# Epoch 49: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 0s 10ms/step - loss: 2508.7429 - root_mean_squared_error: 50.0874 - mean_absolute_error: 39.2843 - val_loss: 1981.6189 - val_root_mean_squared_error: 44.5154 - val_mean_absolute_error: 35.2891
# Epoch 50/500
# 30/37 [=======================>......] - ETA: 0s - loss: 3252.4473 - root_mean_squared_error: 57.0302 - mean_absolute_error: 40.9968
# Epoch 50: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 0s 11ms/step - loss: 3131.0315 - root_mean_squared_error: 55.9556 - mean_absolute_error: 40.7664 - val_loss: 9703.6406 - val_root_mean_squared_error: 98.5071 - val_mean_absolute_error: 88.0195
# Epoch 51/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3175.8953 - root_mean_squared_error: 56.3551 - mean_absolute_error: 42.3774
# Epoch 51: val_loss did not improve from 1574.54712
# 37/37 [==============================] - 0s 12ms/step - loss: 3183.7437 - root_mean_squared_error: 56.4247 - mean_absolute_error: 42.5177 - val_loss: 5280.7070 - val_root_mean_squared_error: 72.6685 - val_mean_absolute_error: 63.4251
# Epoch 52/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2451.0317 - root_mean_squared_error: 49.5079 - mean_absolute_error: 37.2572
# Epoch 52: val_loss improved from 1574.54712 to 1384.30933, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2471.2903 - root_mean_squared_error: 49.7121 - mean_absolute_error: 37.3329 - val_loss: 1384.3093 - val_root_mean_squared_error: 37.2063 - val_mean_absolute_error: 27.0854
# Epoch 53/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2500.4512 - root_mean_squared_error: 50.0045 - mean_absolute_error: 36.9421
# Epoch 53: val_loss did not improve from 1384.30933
# 37/37 [==============================] - 0s 12ms/step - loss: 2477.6555 - root_mean_squared_error: 49.7761 - mean_absolute_error: 36.8757 - val_loss: 3319.3179 - val_root_mean_squared_error: 57.6135 - val_mean_absolute_error: 47.2422
# Epoch 54/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2440.1355 - root_mean_squared_error: 49.3977 - mean_absolute_error: 36.6951
# Epoch 54: val_loss improved from 1384.30933 to 1367.63525, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 2550.5317 - root_mean_squared_error: 50.5028 - mean_absolute_error: 37.3361 - val_loss: 1367.6353 - val_root_mean_squared_error: 36.9816 - val_mean_absolute_error: 27.2719
# Epoch 55/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2219.0093 - root_mean_squared_error: 47.1064 - mean_absolute_error: 35.4665
# Epoch 55: val_loss did not improve from 1367.63525
# 37/37 [==============================] - 0s 10ms/step - loss: 2102.1667 - root_mean_squared_error: 45.8494 - mean_absolute_error: 34.4207 - val_loss: 2772.6382 - val_root_mean_squared_error: 52.6558 - val_mean_absolute_error: 43.8246
# Epoch 56/500
# 36/37 [============================>.] - ETA: 0s - loss: 2902.6033 - root_mean_squared_error: 53.8758 - mean_absolute_error: 37.1712
# Epoch 56: val_loss did not improve from 1367.63525
# 37/37 [==============================] - 0s 10ms/step - loss: 2937.2961 - root_mean_squared_error: 54.1968 - mean_absolute_error: 37.4682 - val_loss: 3920.7842 - val_root_mean_squared_error: 62.6162 - val_mean_absolute_error: 52.6837
# Epoch 57/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2370.0217 - root_mean_squared_error: 48.6829 - mean_absolute_error: 36.3658
# Epoch 57: val_loss did not improve from 1367.63525
# 37/37 [==============================] - 0s 11ms/step - loss: 2493.8826 - root_mean_squared_error: 49.9388 - mean_absolute_error: 37.0072 - val_loss: 3980.4211 - val_root_mean_squared_error: 63.0906 - val_mean_absolute_error: 54.0286
# Epoch 58/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2111.8586 - root_mean_squared_error: 45.9550 - mean_absolute_error: 35.1768
# Epoch 58: val_loss improved from 1367.63525 to 1253.89551, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 2203.0037 - root_mean_squared_error: 46.9362 - mean_absolute_error: 35.7361 - val_loss: 1253.8955 - val_root_mean_squared_error: 35.4104 - val_mean_absolute_error: 25.2612
# Epoch 59/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2740.6687 - root_mean_squared_error: 52.3514 - mean_absolute_error: 38.7846
# Epoch 59: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 12ms/step - loss: 2696.6245 - root_mean_squared_error: 51.9290 - mean_absolute_error: 38.5449 - val_loss: 1329.1123 - val_root_mean_squared_error: 36.4570 - val_mean_absolute_error: 27.3422
# Epoch 60/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2153.9883 - root_mean_squared_error: 46.4111 - mean_absolute_error: 34.9522
# Epoch 60: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 11ms/step - loss: 2161.9639 - root_mean_squared_error: 46.4969 - mean_absolute_error: 35.2069 - val_loss: 1330.8400 - val_root_mean_squared_error: 36.4807 - val_mean_absolute_error: 26.4452
# Epoch 61/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2576.4104 - root_mean_squared_error: 50.7584 - mean_absolute_error: 38.1948
# Epoch 61: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 10ms/step - loss: 2457.6528 - root_mean_squared_error: 49.5747 - mean_absolute_error: 37.1440 - val_loss: 3603.1260 - val_root_mean_squared_error: 60.0260 - val_mean_absolute_error: 49.0975
# Epoch 62/500
# 30/37 [=======================>......] - ETA: 0s - loss: 2605.5298 - root_mean_squared_error: 51.0444 - mean_absolute_error: 37.4089
# Epoch 62: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 10ms/step - loss: 2549.3401 - root_mean_squared_error: 50.4910 - mean_absolute_error: 37.3112 - val_loss: 4108.3779 - val_root_mean_squared_error: 64.0966 - val_mean_absolute_error: 55.7296
# Epoch 63/500
# 31/37 [========================>.....] - ETA: 0s - loss: 1950.7992 - root_mean_squared_error: 44.1679 - mean_absolute_error: 33.6421
# Epoch 63: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 9ms/step - loss: 2174.4851 - root_mean_squared_error: 46.6314 - mean_absolute_error: 34.8680 - val_loss: 1419.6930 - val_root_mean_squared_error: 37.6788 - val_mean_absolute_error: 28.0675
# Epoch 64/500
# 37/37 [==============================] - ETA: 0s - loss: 2476.2388 - root_mean_squared_error: 49.7618 - mean_absolute_error: 38.2740
# Epoch 64: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 11ms/step - loss: 2476.2388 - root_mean_squared_error: 49.7618 - mean_absolute_error: 38.2740 - val_loss: 1277.4512 - val_root_mean_squared_error: 35.7415 - val_mean_absolute_error: 25.3694
# Epoch 65/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2358.6448 - root_mean_squared_error: 48.5659 - mean_absolute_error: 36.7915
# Epoch 65: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 12ms/step - loss: 2329.1597 - root_mean_squared_error: 48.2614 - mean_absolute_error: 36.6516 - val_loss: 3274.4980 - val_root_mean_squared_error: 57.2232 - val_mean_absolute_error: 48.5359
# Epoch 66/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2653.1345 - root_mean_squared_error: 51.5086 - mean_absolute_error: 38.0037
# Epoch 66: val_loss did not improve from 1253.89551
# 37/37 [==============================] - 0s 12ms/step - loss: 2567.5930 - root_mean_squared_error: 50.6714 - mean_absolute_error: 37.4817 - val_loss: 2276.4443 - val_root_mean_squared_error: 47.7121 - val_mean_absolute_error: 37.3624
# Epoch 67/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2719.8176 - root_mean_squared_error: 52.1519 - mean_absolute_error: 37.8723
# Epoch 67: val_loss improved from 1253.89551 to 1050.76477, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2716.1182 - root_mean_squared_error: 52.1164 - mean_absolute_error: 37.9566 - val_loss: 1050.7648 - val_root_mean_squared_error: 32.4155 - val_mean_absolute_error: 23.4211
# Epoch 68/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2719.9937 - root_mean_squared_error: 52.1536 - mean_absolute_error: 39.4521
# Epoch 68: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 9ms/step - loss: 2929.6047 - root_mean_squared_error: 54.1258 - mean_absolute_error: 40.4909 - val_loss: 1430.1058 - val_root_mean_squared_error: 37.8167 - val_mean_absolute_error: 28.8288
# Epoch 69/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2006.6562 - root_mean_squared_error: 44.7957 - mean_absolute_error: 32.4642
# Epoch 69: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 9ms/step - loss: 2085.9629 - root_mean_squared_error: 45.6723 - mean_absolute_error: 33.1793 - val_loss: 1159.5198 - val_root_mean_squared_error: 34.0517 - val_mean_absolute_error: 23.9147
# Epoch 70/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2328.8933 - root_mean_squared_error: 48.2586 - mean_absolute_error: 36.0961
# Epoch 70: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 9ms/step - loss: 2252.3716 - root_mean_squared_error: 47.4592 - mean_absolute_error: 35.4836 - val_loss: 4792.6465 - val_root_mean_squared_error: 69.2289 - val_mean_absolute_error: 62.6441
# Epoch 71/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1733.4689 - root_mean_squared_error: 41.6349 - mean_absolute_error: 31.0831
# Epoch 71: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 10ms/step - loss: 2017.9265 - root_mean_squared_error: 44.9213 - mean_absolute_error: 32.2873 - val_loss: 1095.2748 - val_root_mean_squared_error: 33.0949 - val_mean_absolute_error: 24.5891
# Epoch 72/500
# 36/37 [============================>.] - ETA: 0s - loss: 1787.1874 - root_mean_squared_error: 42.2751 - mean_absolute_error: 31.2628
# Epoch 72: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 11ms/step - loss: 1782.4833 - root_mean_squared_error: 42.2195 - mean_absolute_error: 31.2432 - val_loss: 1527.4939 - val_root_mean_squared_error: 39.0832 - val_mean_absolute_error: 30.6580
# Epoch 73/500
# 37/37 [==============================] - ETA: 0s - loss: 2286.7146 - root_mean_squared_error: 47.8196 - mean_absolute_error: 34.0821
# Epoch 73: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 11ms/step - loss: 2286.7146 - root_mean_squared_error: 47.8196 - mean_absolute_error: 34.0821 - val_loss: 5079.7305 - val_root_mean_squared_error: 71.2722 - val_mean_absolute_error: 63.7122
# Epoch 74/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2166.2375 - root_mean_squared_error: 46.5429 - mean_absolute_error: 33.4714
# Epoch 74: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 11ms/step - loss: 2131.5239 - root_mean_squared_error: 46.1684 - mean_absolute_error: 33.3377 - val_loss: 1503.6368 - val_root_mean_squared_error: 38.7768 - val_mean_absolute_error: 31.0216
# Epoch 75/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2281.6350 - root_mean_squared_error: 47.7665 - mean_absolute_error: 34.6232
# Epoch 75: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 12ms/step - loss: 2320.6365 - root_mean_squared_error: 48.1730 - mean_absolute_error: 35.1378 - val_loss: 1777.6495 - val_root_mean_squared_error: 42.1622 - val_mean_absolute_error: 33.6668
# Epoch 76/500
# 36/37 [============================>.] - ETA: 0s - loss: 1846.8096 - root_mean_squared_error: 42.9745 - mean_absolute_error: 31.6413
# Epoch 76: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 11ms/step - loss: 1843.1724 - root_mean_squared_error: 42.9322 - mean_absolute_error: 31.6323 - val_loss: 2072.6711 - val_root_mean_squared_error: 45.5266 - val_mean_absolute_error: 38.1567
# Epoch 77/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1785.3529 - root_mean_squared_error: 42.2534 - mean_absolute_error: 30.6461
# Epoch 77: val_loss did not improve from 1050.76477
# 37/37 [==============================] - 0s 13ms/step - loss: 1755.1311 - root_mean_squared_error: 41.8943 - mean_absolute_error: 30.4859 - val_loss: 1371.1802 - val_root_mean_squared_error: 37.0294 - val_mean_absolute_error: 29.5144
# Epoch 78/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1725.8641 - root_mean_squared_error: 41.5435 - mean_absolute_error: 30.1621
# Epoch 78: val_loss improved from 1050.76477 to 983.67841, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 1814.1180 - root_mean_squared_error: 42.5925 - mean_absolute_error: 30.7675 - val_loss: 983.6784 - val_root_mean_squared_error: 31.3636 - val_mean_absolute_error: 22.8153
# Epoch 79/500
# 36/37 [============================>.] - ETA: 0s - loss: 3202.2288 - root_mean_squared_error: 56.5882 - mean_absolute_error: 41.7444
# Epoch 79: val_loss did not improve from 983.67841
# 37/37 [==============================] - 0s 10ms/step - loss: 3199.6294 - root_mean_squared_error: 56.5653 - mean_absolute_error: 41.7345 - val_loss: 1301.1992 - val_root_mean_squared_error: 36.0721 - val_mean_absolute_error: 28.2148
# Epoch 80/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2115.4109 - root_mean_squared_error: 45.9936 - mean_absolute_error: 33.1163
# Epoch 80: val_loss did not improve from 983.67841
# 37/37 [==============================] - 0s 12ms/step - loss: 2099.2354 - root_mean_squared_error: 45.8174 - mean_absolute_error: 32.8018 - val_loss: 5610.6162 - val_root_mean_squared_error: 74.9040 - val_mean_absolute_error: 68.3038
# Epoch 81/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1967.2228 - root_mean_squared_error: 44.3534 - mean_absolute_error: 33.1325
# Epoch 81: val_loss did not improve from 983.67841
# 37/37 [==============================] - 0s 12ms/step - loss: 1943.4781 - root_mean_squared_error: 44.0849 - mean_absolute_error: 32.9909 - val_loss: 1090.4072 - val_root_mean_squared_error: 33.0213 - val_mean_absolute_error: 24.6596
# Epoch 82/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2046.5400 - root_mean_squared_error: 45.2387 - mean_absolute_error: 31.1684
# Epoch 82: val_loss improved from 983.67841 to 922.07758, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2081.6233 - root_mean_squared_error: 45.6248 - mean_absolute_error: 32.1246 - val_loss: 922.0776 - val_root_mean_squared_error: 30.3657 - val_mean_absolute_error: 21.8855
# Epoch 83/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1771.0084 - root_mean_squared_error: 42.0833 - mean_absolute_error: 30.5848
# Epoch 83: val_loss did not improve from 922.07758
# 37/37 [==============================] - 0s 11ms/step - loss: 1886.6307 - root_mean_squared_error: 43.4354 - mean_absolute_error: 31.0501 - val_loss: 1521.0355 - val_root_mean_squared_error: 39.0005 - val_mean_absolute_error: 31.3336
# Epoch 84/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1833.4713 - root_mean_squared_error: 42.8191 - mean_absolute_error: 31.3113
# Epoch 84: val_loss did not improve from 922.07758
# 37/37 [==============================] - 0s 12ms/step - loss: 1798.1630 - root_mean_squared_error: 42.4048 - mean_absolute_error: 30.9998 - val_loss: 981.0652 - val_root_mean_squared_error: 31.3220 - val_mean_absolute_error: 22.6283
# Epoch 85/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1841.6017 - root_mean_squared_error: 42.9139 - mean_absolute_error: 30.7067
# Epoch 85: val_loss improved from 922.07758 to 916.05841, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 1818.3749 - root_mean_squared_error: 42.6424 - mean_absolute_error: 31.0217 - val_loss: 916.0584 - val_root_mean_squared_error: 30.2665 - val_mean_absolute_error: 21.7813
# Epoch 86/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1556.2394 - root_mean_squared_error: 39.4492 - mean_absolute_error: 29.0788
# Epoch 86: val_loss did not improve from 916.05841
# 37/37 [==============================] - 0s 12ms/step - loss: 1681.6337 - root_mean_squared_error: 41.0077 - mean_absolute_error: 29.6251 - val_loss: 1018.4531 - val_root_mean_squared_error: 31.9132 - val_mean_absolute_error: 23.9317
# Epoch 87/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2325.0342 - root_mean_squared_error: 48.2186 - mean_absolute_error: 36.9465
# Epoch 87: val_loss did not improve from 916.05841
# 37/37 [==============================] - 0s 13ms/step - loss: 2371.4377 - root_mean_squared_error: 48.6974 - mean_absolute_error: 37.0916 - val_loss: 2032.0364 - val_root_mean_squared_error: 45.0781 - val_mean_absolute_error: 35.9023
# Epoch 88/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2094.7129 - root_mean_squared_error: 45.7680 - mean_absolute_error: 35.0314
# Epoch 88: val_loss did not improve from 916.05841
# 37/37 [==============================] - 0s 12ms/step - loss: 2049.9978 - root_mean_squared_error: 45.2769 - mean_absolute_error: 34.5250 - val_loss: 1927.4508 - val_root_mean_squared_error: 43.9027 - val_mean_absolute_error: 38.1656
# Epoch 89/500
# 36/37 [============================>.] - ETA: 0s - loss: 1710.1864 - root_mean_squared_error: 41.3544 - mean_absolute_error: 29.8525
# Epoch 89: val_loss improved from 916.05841 to 905.82141, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 1713.6512 - root_mean_squared_error: 41.3963 - mean_absolute_error: 29.9237 - val_loss: 905.8214 - val_root_mean_squared_error: 30.0969 - val_mean_absolute_error: 22.5289
# Epoch 90/500
# 30/37 [=======================>......] - ETA: 0s - loss: 2015.4333 - root_mean_squared_error: 44.8936 - mean_absolute_error: 31.9956
# Epoch 90: val_loss did not improve from 905.82141
# 37/37 [==============================] - 0s 13ms/step - loss: 1912.8068 - root_mean_squared_error: 43.7356 - mean_absolute_error: 31.8231 - val_loss: 1023.8855 - val_root_mean_squared_error: 31.9982 - val_mean_absolute_error: 23.3045
# Epoch 91/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1756.8883 - root_mean_squared_error: 41.9153 - mean_absolute_error: 30.7047
# Epoch 91: val_loss improved from 905.82141 to 813.64655, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 1735.7780 - root_mean_squared_error: 41.6627 - mean_absolute_error: 30.6381 - val_loss: 813.6465 - val_root_mean_squared_error: 28.5245 - val_mean_absolute_error: 20.6741
# Epoch 92/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1778.6151 - root_mean_squared_error: 42.1736 - mean_absolute_error: 29.9548
# Epoch 92: val_loss did not improve from 813.64655
# 37/37 [==============================] - 0s 12ms/step - loss: 1744.8270 - root_mean_squared_error: 41.7711 - mean_absolute_error: 29.7758 - val_loss: 2077.3831 - val_root_mean_squared_error: 45.5783 - val_mean_absolute_error: 37.0235
# Epoch 93/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2004.0291 - root_mean_squared_error: 44.7664 - mean_absolute_error: 31.8697
# Epoch 93: val_loss did not improve from 813.64655
# 37/37 [==============================] - 0s 12ms/step - loss: 1928.4712 - root_mean_squared_error: 43.9144 - mean_absolute_error: 31.4775 - val_loss: 5264.8105 - val_root_mean_squared_error: 72.5590 - val_mean_absolute_error: 63.6900
# Epoch 94/500
# 31/37 [========================>.....] - ETA: 0s - loss: 1550.2415 - root_mean_squared_error: 39.3731 - mean_absolute_error: 29.7145
# Epoch 94: val_loss did not improve from 813.64655
# 37/37 [==============================] - 0s 10ms/step - loss: 1672.5919 - root_mean_squared_error: 40.8973 - mean_absolute_error: 30.6020 - val_loss: 1805.4602 - val_root_mean_squared_error: 42.4907 - val_mean_absolute_error: 34.9033
# Epoch 95/500
# 36/37 [============================>.] - ETA: 0s - loss: 2047.5227 - root_mean_squared_error: 45.2496 - mean_absolute_error: 33.8921
# Epoch 95: val_loss did not improve from 813.64655
# 37/37 [==============================] - 0s 12ms/step - loss: 2057.3552 - root_mean_squared_error: 45.3581 - mean_absolute_error: 34.0187 - val_loss: 1165.7347 - val_root_mean_squared_error: 34.1429 - val_mean_absolute_error: 27.3408
# Epoch 96/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2105.6670 - root_mean_squared_error: 45.8875 - mean_absolute_error: 35.5281
# Epoch 96: val_loss did not improve from 813.64655
# 37/37 [==============================] - 0s 12ms/step - loss: 2203.6021 - root_mean_squared_error: 46.9425 - mean_absolute_error: 35.9988 - val_loss: 1741.1129 - val_root_mean_squared_error: 41.7266 - val_mean_absolute_error: 34.6913
# Epoch 97/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1754.9612 - root_mean_squared_error: 41.8923 - mean_absolute_error: 31.2218
# Epoch 97: val_loss did not improve from 813.64655
# 37/37 [==============================] - 0s 12ms/step - loss: 1757.7257 - root_mean_squared_error: 41.9252 - mean_absolute_error: 31.2258 - val_loss: 4233.6719 - val_root_mean_squared_error: 65.0667 - val_mean_absolute_error: 58.7248
# Epoch 98/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1690.9080 - root_mean_squared_error: 41.1207 - mean_absolute_error: 30.6162
# Epoch 98: val_loss improved from 813.64655 to 778.38409, saving model to ./best_model_final_0/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 1659.8523 - root_mean_squared_error: 40.7413 - mean_absolute_error: 30.6654 - val_loss: 778.3841 - val_root_mean_squared_error: 27.8995 - val_mean_absolute_error: 20.3233
# Epoch 99/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1437.7850 - root_mean_squared_error: 37.9181 - mean_absolute_error: 27.6771
# Epoch 99: val_loss did not improve from 778.38409
# 37/37 [==============================] - 0s 11ms/step - loss: 1660.2219 - root_mean_squared_error: 40.7458 - mean_absolute_error: 30.1192 - val_loss: 7496.6221 - val_root_mean_squared_error: 86.5830 - val_mean_absolute_error: 80.7394
# Epoch 100/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2261.2703 - root_mean_squared_error: 47.5528 - mean_absolute_error: 36.0130
# Epoch 100: val_loss did not improve from 778.38409
# 37/37 [==============================] - 0s 12ms/step - loss: 2282.5859 - root_mean_squared_error: 47.7764 - mean_absolute_error: 36.3813 - val_loss: 1886.3901 - val_root_mean_squared_error: 43.4326 - val_mean_absolute_error: 35.7057
# Epoch 101/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2228.0120 - root_mean_squared_error: 47.2018 - mean_absolute_error: 35.1598
# Epoch 101: val_loss did not improve from 778.38409
# ...
# Epoch 466/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1339.4102 - root_mean_squared_error: 36.5980 - mean_absolute_error: 23.5235
# Epoch 466: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1225.1368 - root_mean_squared_error: 35.0020 - mean_absolute_error: 22.5724 - val_loss: 433.4325 - val_root_mean_squared_error: 20.8190 - val_mean_absolute_error: 14.1485
# Epoch 467/500
# 37/37 [==============================] - ETA: 0s - loss: 1033.4606 - root_mean_squared_error: 32.1475 - mean_absolute_error: 21.0813
# Epoch 467: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1033.4606 - root_mean_squared_error: 32.1475 - mean_absolute_error: 21.0813 - val_loss: 415.9411 - val_root_mean_squared_error: 20.3946 - val_mean_absolute_error: 15.0628
# Epoch 468/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1064.2059 - root_mean_squared_error: 32.6222 - mean_absolute_error: 21.7314
# Epoch 468: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1219.2556 - root_mean_squared_error: 34.9178 - mean_absolute_error: 22.3173 - val_loss: 458.8724 - val_root_mean_squared_error: 21.4213 - val_mean_absolute_error: 16.0567
# Epoch 469/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1095.4269 - root_mean_squared_error: 33.0972 - mean_absolute_error: 22.9867
# Epoch 469: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1057.7777 - root_mean_squared_error: 32.5235 - mean_absolute_error: 22.8566 - val_loss: 864.9647 - val_root_mean_squared_error: 29.4103 - val_mean_absolute_error: 24.4388
# Epoch 470/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1245.7593 - root_mean_squared_error: 35.2953 - mean_absolute_error: 24.7468
# Epoch 470: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1235.6024 - root_mean_squared_error: 35.1511 - mean_absolute_error: 24.6831 - val_loss: 387.1725 - val_root_mean_squared_error: 19.6767 - val_mean_absolute_error: 13.6607
# Epoch 471/500
# 36/37 [============================>.] - ETA: 0s - loss: 1244.7778 - root_mean_squared_error: 35.2814 - mean_absolute_error: 23.4133
# Epoch 471: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1238.2461 - root_mean_squared_error: 35.1887 - mean_absolute_error: 23.3698 - val_loss: 296.9595 - val_root_mean_squared_error: 17.2325 - val_mean_absolute_error: 11.6252
# Epoch 472/500
# 31/37 [========================>.....] - ETA: 0s - loss: 1046.0632 - root_mean_squared_error: 32.3429 - mean_absolute_error: 21.4110
# Epoch 472: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1088.8739 - root_mean_squared_error: 32.9981 - mean_absolute_error: 22.3810 - val_loss: 1212.2786 - val_root_mean_squared_error: 34.8178 - val_mean_absolute_error: 29.7658
# Epoch 473/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1435.8982 - root_mean_squared_error: 37.8932 - mean_absolute_error: 25.4872
# Epoch 473: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1453.0212 - root_mean_squared_error: 38.1185 - mean_absolute_error: 25.8060 - val_loss: 2677.6245 - val_root_mean_squared_error: 51.7458 - val_mean_absolute_error: 46.7453
# Epoch 474/500
# 31/37 [========================>.....] - ETA: 0s - loss: 1112.7159 - root_mean_squared_error: 33.3574 - mean_absolute_error: 23.3271
# Epoch 474: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1067.1183 - root_mean_squared_error: 32.6668 - mean_absolute_error: 22.9524 - val_loss: 516.0007 - val_root_mean_squared_error: 22.7156 - val_mean_absolute_error: 16.5044
# Epoch 475/500
# 34/37 [==========================>...] - ETA: 0s - loss: 965.0396 - root_mean_squared_error: 31.0651 - mean_absolute_error: 21.3133
# Epoch 475: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 948.9116 - root_mean_squared_error: 30.8044 - mean_absolute_error: 21.0918 - val_loss: 363.0714 - val_root_mean_squared_error: 19.0544 - val_mean_absolute_error: 13.6411
# Epoch 476/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1348.8062 - root_mean_squared_error: 36.7261 - mean_absolute_error: 25.5946
# Epoch 476: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1321.1527 - root_mean_squared_error: 36.3477 - mean_absolute_error: 25.6913 - val_loss: 418.7036 - val_root_mean_squared_error: 20.4622 - val_mean_absolute_error: 15.0085
# Epoch 477/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1100.0135 - root_mean_squared_error: 33.1665 - mean_absolute_error: 22.7952
# Epoch 477: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1081.8447 - root_mean_squared_error: 32.8914 - mean_absolute_error: 22.6358 - val_loss: 328.6852 - val_root_mean_squared_error: 18.1297 - val_mean_absolute_error: 12.9437
# Epoch 478/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1035.1401 - root_mean_squared_error: 32.1736 - mean_absolute_error: 20.9212
# Epoch 478: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 10ms/step - loss: 1081.0465 - root_mean_squared_error: 32.8793 - mean_absolute_error: 21.0053 - val_loss: 277.6342 - val_root_mean_squared_error: 16.6624 - val_mean_absolute_error: 11.6947
# Epoch 479/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1156.9305 - root_mean_squared_error: 34.0137 - mean_absolute_error: 22.9007
# Epoch 479: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1159.4714 - root_mean_squared_error: 34.0510 - mean_absolute_error: 23.0042 - val_loss: 345.8761 - val_root_mean_squared_error: 18.5977 - val_mean_absolute_error: 12.8686
# Epoch 480/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1126.4731 - root_mean_squared_error: 33.5630 - mean_absolute_error: 22.9022
# Epoch 480: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1111.7507 - root_mean_squared_error: 33.3429 - mean_absolute_error: 22.6789 - val_loss: 692.2414 - val_root_mean_squared_error: 26.3105 - val_mean_absolute_error: 21.9997
# Epoch 481/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1044.9707 - root_mean_squared_error: 32.3260 - mean_absolute_error: 20.9093
# Epoch 481: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1089.4944 - root_mean_squared_error: 33.0075 - mean_absolute_error: 21.5189 - val_loss: 283.9621 - val_root_mean_squared_error: 16.8512 - val_mean_absolute_error: 11.7109
# Epoch 482/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1090.4877 - root_mean_squared_error: 33.0225 - mean_absolute_error: 23.4026
# Epoch 482: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1065.5790 - root_mean_squared_error: 32.6432 - mean_absolute_error: 23.2966 - val_loss: 508.4904 - val_root_mean_squared_error: 22.5497 - val_mean_absolute_error: 17.7837
# Epoch 483/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1011.0337 - root_mean_squared_error: 31.7968 - mean_absolute_error: 21.8997
# Epoch 483: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 973.1442 - root_mean_squared_error: 31.1953 - mean_absolute_error: 21.4754 - val_loss: 2905.0732 - val_root_mean_squared_error: 53.8987 - val_mean_absolute_error: 48.0016
# Epoch 484/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1014.8438 - root_mean_squared_error: 31.8566 - mean_absolute_error: 22.0194
# Epoch 484: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 965.4474 - root_mean_squared_error: 31.0716 - mean_absolute_error: 21.4696 - val_loss: 396.1139 - val_root_mean_squared_error: 19.9026 - val_mean_absolute_error: 15.0405
# Epoch 485/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1002.5705 - root_mean_squared_error: 31.6634 - mean_absolute_error: 20.3553
# Epoch 485: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1002.5207 - root_mean_squared_error: 31.6626 - mean_absolute_error: 20.5095 - val_loss: 1270.6331 - val_root_mean_squared_error: 35.6459 - val_mean_absolute_error: 32.2095
# Epoch 486/500
# 30/37 [=======================>......] - ETA: 0s - loss: 1003.8329 - root_mean_squared_error: 31.6833 - mean_absolute_error: 20.6650
# Epoch 486: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 964.8717 - root_mean_squared_error: 31.0624 - mean_absolute_error: 20.1216 - val_loss: 378.9605 - val_root_mean_squared_error: 19.4669 - val_mean_absolute_error: 14.2450
# Epoch 487/500
# 33/37 [=========================>....] - ETA: 0s - loss: 947.0805 - root_mean_squared_error: 30.7747 - mean_absolute_error: 20.8774
# Epoch 487: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 920.9935 - root_mean_squared_error: 30.3479 - mean_absolute_error: 20.6737 - val_loss: 342.9088 - val_root_mean_squared_error: 18.5178 - val_mean_absolute_error: 12.9558
# Epoch 488/500
# 37/37 [==============================] - ETA: 0s - loss: 1160.8955 - root_mean_squared_error: 34.0719 - mean_absolute_error: 23.4251
# Epoch 488: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1160.8955 - root_mean_squared_error: 34.0719 - mean_absolute_error: 23.4251 - val_loss: 702.1075 - val_root_mean_squared_error: 26.4973 - val_mean_absolute_error: 19.5332
# Epoch 489/500
# 32/37 [========================>.....] - ETA: 0s - loss: 787.8336 - root_mean_squared_error: 28.0684 - mean_absolute_error: 19.4629
# Epoch 489: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 808.0892 - root_mean_squared_error: 28.4269 - mean_absolute_error: 19.2593 - val_loss: 877.3093 - val_root_mean_squared_error: 29.6194 - val_mean_absolute_error: 23.1302
# Epoch 490/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1248.7180 - root_mean_squared_error: 35.3372 - mean_absolute_error: 23.1110
# Epoch 490: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1239.8610 - root_mean_squared_error: 35.2117 - mean_absolute_error: 22.9845 - val_loss: 248.5249 - val_root_mean_squared_error: 15.7647 - val_mean_absolute_error: 10.3867
# Epoch 491/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1175.7646 - root_mean_squared_error: 34.2894 - mean_absolute_error: 23.4961
# Epoch 491: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1148.7303 - root_mean_squared_error: 33.8929 - mean_absolute_error: 23.1021 - val_loss: 291.7271 - val_root_mean_squared_error: 17.0800 - val_mean_absolute_error: 11.6621
# Epoch 492/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1127.0579 - root_mean_squared_error: 33.5717 - mean_absolute_error: 22.0571
# Epoch 492: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1188.4773 - root_mean_squared_error: 34.4743 - mean_absolute_error: 22.4928 - val_loss: 1298.2291 - val_root_mean_squared_error: 36.0309 - val_mean_absolute_error: 31.0008
# Epoch 493/500
# 33/37 [=========================>....] - ETA: 0s - loss: 854.4925 - root_mean_squared_error: 29.2317 - mean_absolute_error: 19.9489
# Epoch 493: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 845.5117 - root_mean_squared_error: 29.0777 - mean_absolute_error: 19.9246 - val_loss: 631.4639 - val_root_mean_squared_error: 25.1289 - val_mean_absolute_error: 19.9193
# Epoch 494/500
# 32/37 [========================>.....] - ETA: 0s - loss: 912.0303 - root_mean_squared_error: 30.1998 - mean_absolute_error: 19.9010
# Epoch 494: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1043.4458 - root_mean_squared_error: 32.3024 - mean_absolute_error: 21.4258 - val_loss: 802.3996 - val_root_mean_squared_error: 28.3267 - val_mean_absolute_error: 19.3672
# Epoch 495/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1339.4117 - root_mean_squared_error: 36.5980 - mean_absolute_error: 26.7918
# Epoch 495: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1293.0918 - root_mean_squared_error: 35.9596 - mean_absolute_error: 26.4510 - val_loss: 952.0610 - val_root_mean_squared_error: 30.8555 - val_mean_absolute_error: 24.8595
# Epoch 496/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1011.1335 - root_mean_squared_error: 31.7983 - mean_absolute_error: 21.8667
# Epoch 496: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 13ms/step - loss: 1004.0901 - root_mean_squared_error: 31.6874 - mean_absolute_error: 21.8968 - val_loss: 321.7275 - val_root_mean_squared_error: 17.9368 - val_mean_absolute_error: 12.7416
# Epoch 497/500
# 30/37 [=======================>......] - ETA: 0s - loss: 1004.2198 - root_mean_squared_error: 31.6894 - mean_absolute_error: 21.3249
# Epoch 497: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 10ms/step - loss: 984.5928 - root_mean_squared_error: 31.3782 - mean_absolute_error: 21.5684 - val_loss: 614.5803 - val_root_mean_squared_error: 24.7907 - val_mean_absolute_error: 18.5917
# Epoch 498/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1008.3292 - root_mean_squared_error: 31.7542 - mean_absolute_error: 21.4393
# Epoch 498: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1036.1991 - root_mean_squared_error: 32.1900 - mean_absolute_error: 21.7122 - val_loss: 401.2615 - val_root_mean_squared_error: 20.0315 - val_mean_absolute_error: 13.8860
# Epoch 499/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1163.2566 - root_mean_squared_error: 34.1065 - mean_absolute_error: 21.9860
# Epoch 499: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 12ms/step - loss: 1141.1394 - root_mean_squared_error: 33.7808 - mean_absolute_error: 22.0450 - val_loss: 490.3638 - val_root_mean_squared_error: 22.1442 - val_mean_absolute_error: 16.9312
# Epoch 500/500
# 36/37 [============================>.] - ETA: 0s - loss: 1359.7725 - root_mean_squared_error: 36.8751 - mean_absolute_error: 23.6660
# Epoch 500: val_loss did not improve from 230.93266
# 37/37 [==============================] - 0s 11ms/step - loss: 1352.8627 - root_mean_squared_error: 36.7813 - mean_absolute_error: 23.6296 - val_loss: 1041.9078 - val_root_mean_squared_error: 32.2786 - val_mean_absolute_error: 25.7728
#   测试集 R: 0.9685, MAE: 33.2203, RMSE: 52.8917
#   ✓ 已保存模型: ./best_model_final_0/best_model_fold_9.h5
#   ✓ 已保存训练集预测: ./best_model_final_0/fold_predictions/fold_9_train_predictions.csv
#   ✓ 已保存验证集预测: ./best_model_final_0/fold_predictions/fold_9_test_predictions.csv
#
# ============================================================
# 最佳模型训练完成!
# ============================================================
#
# 总体结果:
#   R²:   0.9580 ± 0.0209
#   MAE:  35.2619 ± 6.1901
#   RMSE: 58.5839 ± 17.3395
#
# 结果保存位置:
#   - 模型文件: ./best_model_final_0/best_model_fold_*.h5
#   - 预测结果: ./best_model_final_0/fold_predictions/
#   - 汇总信息: ./best_model_final_0/summary.json
#   - 训练结果: ./best_model_final_0/training_results.csv
#
# ============================================================
# 所有任务完成!
# ============================================================

# %%
# 在所有导入之前
import os
os.environ['PYTHONHASHSEED'] = '42'
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# 然后再导入其他库
import numpy as np
import tensorflow as tf
import os
import json
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# 设置中文字体
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei', 'DejaVu Sans']
matplotlib.rcParams['axes.unicode_minus'] = False

# 2. 在set_random_seeds函数中添加GPU配置
def set_random_seeds(seed):
    """设置所有可能的随机种子"""
    import random
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['PYTHONHASHSEED'] = str(seed)
    
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()
    
    # 添加GPU内存配置
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(f"GPU配置警告: {e}")

# 设置随机种子
SEED = 42
set_random_seeds(SEED)

# 输入输出目录
output_dir = './best_model_final_1'


# ============================================================================
# 1. 数据加载函数
# ============================================================================
def load_embedding_data(data_dir='..//..//二维高熵合金数据'):
    """加载生成的嵌入矩阵数据"""
    print("="*60)
    print("加载数据...")
    print("="*60)
    
    embedding_path = os.path.join(data_dir, 'alloy_embedding_matrices.npy')
    X_all = np.load(embedding_path)
    
    hv_path = os.path.join(data_dir, 'HV_values.npy')
    Y_all = np.load(hv_path)
    
    info_path = os.path.join(data_dir, 'data_info.json')
    with open(info_path, 'r', encoding='utf-8') as f:
        data_info = json.load(f)
    
    print(f"✓ 数据加载完成")
    print(f"  样本数量: {len(X_all)}")
    print(f"  嵌入矩阵形状: {X_all.shape}")
    print(f"  HV值范围: [{Y_all.min():.2f}, {Y_all.max():.2f}]")
    
    X_all = np.expand_dims(X_all, axis=1)
    print(f"  调整后形状: {X_all.shape}")
    
    return X_all, Y_all, data_info

# ============================================================================
# 2. CNN模型构建函数
# ============================================================================
def build_cnn_model(input_shape, hyperparams):
    """根据超参数构建CNN模型"""
    model = Sequential()
    
    conv_filters = hyperparams['conv_filters']
    kernel_size = hyperparams['kernel_size']
    use_batch_norm = hyperparams['use_batch_norm']
    dropout_rate = hyperparams['dropout_rate']
    activation = hyperparams['activation']
    
    # 第一个卷积层
    model.add(Conv2D(
        filters=conv_filters[0],
        kernel_size=kernel_size,
        strides=1,
        padding='same',
        data_format='channels_first',
        activation=activation,
        input_shape=input_shape
    ))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='same', 
                           data_format='channels_first'))
    
    # 第二个卷积层
    model.add(Conv2D(conv_filters[1], kernel_size, strides=1, padding='same',
                     data_format='channels_first', activation=activation))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D((2, 2), 2, 'same', data_format='channels_first'))
    
    # 第三个卷积层
    model.add(Conv2D(conv_filters[2], kernel_size, strides=1, padding='same',
                     data_format='channels_first', activation=activation))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D((2, 2), 2, 'same', data_format='channels_first'))
    
    # 展平
    model.add(Flatten())
    
    # 全连接层
    dense_units = hyperparams['dense_units']
    for units in dense_units:
        model.add(Dense(units, activation=activation))
        if dropout_rate > 0:
            model.add(Dropout(dropout_rate))
    
    # 输出层
    model.add(Dense(1, activation='linear'))
    
    # 编译模型
    adam = Adam(learning_rate=hyperparams['learning_rate'])
    model.compile(
        optimizer=adam, 
        loss='mean_squared_error',
        metrics=[
            tf.keras.metrics.RootMeanSquaredError(),
            tf.keras.metrics.MeanAbsoluteError()
        ]
    )
    
    return model

# ============================================================================
# 3. 使用最佳参数进行完整训练
# ============================================================================
def train_with_best_params(X_all, Y_all, best_params, output_dir='./best_model_results'):
    """使用最佳参数进行完整的十折交叉验证训练"""
    os.makedirs(output_dir, exist_ok=True)
    
    print("\n" + "="*60)
    print("使用最佳参数进行完整训练")
    print("="*60)
    print(f"\n最佳参数:")
    for k, v in best_params.items():
        if k in ['conv_filters', 'dense_units']:
            print(f"  {k}: {list(v)}")
        else:
            print(f"  {k}: {v}")
    print("="*60)
    
    kf = KFold(n_splits=10, random_state=2*10+55, shuffle=True)
    
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    results_file = os.path.join(output_dir, 'training_results.csv')
    with open(results_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['fold', 'loss_train', 'loss_test', 'r_train', 
                        'r_test', 'mae', 'rmse'])
    
    # 创建每折预测结果保存目录
    predictions_dir = os.path.join(output_dir, 'fold_predictions')
    os.makedirs(predictions_dir, exist_ok=True)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(X_all)):
        print(f"\n第 {fold + 1}/10 折")
        
        x_train, x_test = X_all[train_idx], X_all[test_idx]
        y_train, y_test = Y_all[train_idx], Y_all[test_idx]
        
        # 保存每折的模型
        model_path = os.path.join(output_dir, f'best_model_fold_{fold}.h5')
        
        callbacks = [
            # EarlyStopping(
            #     monitor='val_loss',
            #     patience=30,
            #     min_delta=0.0001,
            #     restore_best_weights=True,
            #     verbose=1,
            #     mode='min'
            # ),
            ModelCheckpoint(
                filepath=model_path,
                monitor='val_loss',
                save_best_only=True,
                mode='min',
                verbose=1
            )
        ]
        
        input_shape = x_train.shape[1:]
        model = build_cnn_model(input_shape, best_params)
        
        history = model.fit(
            x_train, y_train,
            epochs=500,
            batch_size=best_params['batch_size'],
            validation_data=(x_train, y_train),
            callbacks=callbacks,
            verbose=1
        )
        
        # 加载最佳模型
        model = load_model(model_path)
        
        loss_train, rmse_train, mae_train = model.evaluate(x_train, y_train, verbose=0)
        loss_test, rmse_test, mae_test = model.evaluate(x_test, y_test, verbose=0)
        
        # 预测
        pred_train = model.predict(x_train, batch_size=best_params['batch_size'], verbose=0).reshape(-1)
        pred_test = model.predict(x_test, batch_size=best_params['batch_size'], verbose=0).reshape(-1)
        
        r_train = np.corrcoef(pred_train, y_train)[0, 1]
        r_test = np.corrcoef(pred_test, y_test)[0, 1]
        
        mae = mean_absolute_error(y_test, pred_test)
        rmse = mean_squared_error(y_test, pred_test) ** 0.5
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r_test)
        
        print(f"  测试集 R: {r_test:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
        
        with open(results_file, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([fold, loss_train, loss_test, r_train, r_test, mae, rmse])
        
        # ========== 保存训练集预测结果 ==========
        train_predictions_file = os.path.join(predictions_dir, f'fold_{fold}_train_predictions.csv')
        with open(train_predictions_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['original_index', 'true_value', 'predicted_value', 'error'])
            for idx, true_val, pred_val in zip(train_idx, y_train, pred_train):
                writer.writerow([idx, true_val, pred_val, abs(true_val - pred_val)])
        
        # ========== 保存验证集(测试集)预测结果 ==========
        test_predictions_file = os.path.join(predictions_dir, f'fold_{fold}_test_predictions.csv')
        with open(test_predictions_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['original_index', 'true_value', 'predicted_value', 'error'])
            for idx, true_val, pred_val in zip(test_idx, y_test, pred_test):
                writer.writerow([idx, true_val, pred_val, abs(true_val - pred_val)])
        
        # ========== 保存训练集索引 ==========
        train_indices_file = os.path.join(predictions_dir, f'fold_{fold}_train_indices.npy')
        np.save(train_indices_file, train_idx)
        
        # ========== 保存验证集索引 ==========
        test_indices_file = os.path.join(predictions_dir, f'fold_{fold}_test_indices.npy')
        np.save(test_indices_file, test_idx)
        
        print(f"  ✓ 已保存模型: {model_path}")
        print(f"  ✓ 已保存训练集预测: {train_predictions_file}")
        print(f"  ✓ 已保存验证集预测: {test_predictions_file}")
        
        del model
        tf.keras.backend.clear_session()
    
    # 保存汇总结果
    serializable_params = best_params.copy()
    for key in ['conv_filters', 'dense_units']:
        if key in serializable_params:
            serializable_params[key] = list(serializable_params[key])
    
    summary = {
        'R2_mean': float(np.mean(all_r2)),
        'R2_std': float(np.std(all_r2)),
        'MAE_mean': float(np.mean(all_mae)),
        'MAE_std': float(np.std(all_mae)),
        'RMSE_mean': float(np.mean(all_rmse)),
        'RMSE_std': float(np.std(all_rmse)),
        'best_params': serializable_params
    }
    
    with open(os.path.join(output_dir, 'summary.json'), 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)
    
    print("\n" + "="*60)
    print("最佳模型训练完成!")
    print("="*60)
    print(f"\n总体结果:")
    print(f"  R²:   {np.mean(all_r2):.4f} ± {np.std(all_r2):.4f}")
    print(f"  MAE:  {np.mean(all_mae):.4f} ± {np.std(all_mae):.4f}")
    print(f"  RMSE: {np.mean(all_rmse):.4f} ± {np.std(all_rmse):.4f}")
    print(f"\n结果保存位置:")
    print(f"  - 模型文件: {output_dir}/best_model_fold_*.h5")
    print(f"  - 预测结果: {predictions_dir}/")
    print(f"  - 汇总信息: {output_dir}/summary.json")
    print(f"  - 训练结果: {output_dir}/training_results.csv")
    
    return summary

# ============================================================================
# 4. 主函数
# ============================================================================
def main():
    """使用最佳参数进行训练"""
    print("="*60)
    print("CNN最佳参数训练 - 高熵合金硬度预测")
    print("="*60)
    
    # 加载数据
    X_all, Y_all, data_info = load_embedding_data()
    
    # 最佳参数（来自调参结果）
    best_params = {
        'conv_filters': [12, 28, 56],
        'dense_units': [256, 128, 64, 16],
        'kernel_size': (5, 5),
        'learning_rate': 0.00010956749686519973,
        'batch_size': 12,
        'dropout_rate': 0.0097086836073558,
        'use_batch_norm': True,
        'activation': 'selu'
    }
    
    # 训练模型
    summary = train_with_best_params(X_all, Y_all, best_params, output_dir=output_dir)
    
    print("\n" + "="*60)
    print("所有任务完成!")
    print("="*60)

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# CNN最佳参数训练 - 高熵合金硬度预测
# ============================================================
# ============================================================
# 加载数据...
# ============================================================
# ✓ 数据加载完成
#   样本数量: 483
#   嵌入矩阵形状: (483, 21, 768)
#   HV值范围: [109.00, 1084.00]
#   调整后形状: (483, 1, 21, 768)
#
# ============================================================
# 使用最佳参数进行完整训练
# ============================================================
#
# 最佳参数:
#   conv_filters: [12, 28, 56]
#   dense_units: [256, 128, 64, 16]
#   kernel_size: (5, 5)
#   learning_rate: 0.00010956749686519973
#   batch_size: 12
#   dropout_rate: 0.0097086836073558
#   use_batch_norm: True
#   activation: selu
# ============================================================
#
# 第 1/10 折
# Epoch 1/500
# 36/37 [============================>.] - ETA: 0s - loss: 130789.5625 - root_mean_squared_error: 361.6484 - mean_absolute_error: 293.1798
# Epoch 1: val_loss improved from inf to 226864.65625, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 19ms/step - loss: 130280.8125 - root_mean_squared_error: 360.9443 - mean_absolute_error: 292.3859 - val_loss: 226864.6562 - val_root_mean_squared_error: 476.3031 - val_mean_absolute_error: 426.2698
# Epoch 2/500
# 33/37 [=========================>....] - ETA: 0s - loss: 27154.8633 - root_mean_squared_error: 164.7873 - mean_absolute_error: 132.2893
# Epoch 2: val_loss improved from 226864.65625 to 204688.82812, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 26677.7402 - root_mean_squared_error: 163.3332 - mean_absolute_error: 131.5976 - val_loss: 204688.8281 - val_root_mean_squared_error: 452.4255 - val_mean_absolute_error: 403.4766
# Epoch 3/500
# 35/37 [===========================>..] - ETA: 0s - loss: 16726.7656 - root_mean_squared_error: 129.3320 - mean_absolute_error: 99.1397
# Epoch 3: val_loss improved from 204688.82812 to 181292.12500, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 16474.8105 - root_mean_squared_error: 128.3542 - mean_absolute_error: 98.5431 - val_loss: 181292.1250 - val_root_mean_squared_error: 425.7841 - val_mean_absolute_error: 374.9931
# Epoch 4/500
# 30/37 [=======================>......] - ETA: 0s - loss: 13486.4639 - root_mean_squared_error: 116.1312 - mean_absolute_error: 89.7070
# Epoch 4: val_loss improved from 181292.12500 to 170331.93750, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 12ms/step - loss: 13149.9717 - root_mean_squared_error: 114.6733 - mean_absolute_error: 88.2998 - val_loss: 170331.9375 - val_root_mean_squared_error: 412.7129 - val_mean_absolute_error: 362.4662
# Epoch 5/500
# 34/37 [==========================>...] - ETA: 0s - loss: 12551.7471 - root_mean_squared_error: 112.0346 - mean_absolute_error: 87.9219
# Epoch 5: val_loss improved from 170331.93750 to 135282.64062, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 12ms/step - loss: 12208.2988 - root_mean_squared_error: 110.4912 - mean_absolute_error: 86.5882 - val_loss: 135282.6406 - val_root_mean_squared_error: 367.8079 - val_mean_absolute_error: 313.5259
# Epoch 6/500
# 29/37 [======================>.......] - ETA: 0s - loss: 10378.2783 - root_mean_squared_error: 101.8738 - mean_absolute_error: 79.5028
# Epoch 6: val_loss improved from 135282.64062 to 109863.24219, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 10998.1006 - root_mean_squared_error: 104.8718 - mean_absolute_error: 81.6830 - val_loss: 109863.2422 - val_root_mean_squared_error: 331.4562 - val_mean_absolute_error: 276.5293
# Epoch 7/500
# 35/37 [===========================>..] - ETA: 0s - loss: 9151.6855 - root_mean_squared_error: 95.6644 - mean_absolute_error: 73.8904
# Epoch 7: val_loss improved from 109863.24219 to 93090.57031, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 9352.1074 - root_mean_squared_error: 96.7063 - mean_absolute_error: 74.5155 - val_loss: 93090.5703 - val_root_mean_squared_error: 305.1075 - val_mean_absolute_error: 252.6765
# Epoch 8/500
# 32/37 [========================>.....] - ETA: 0s - loss: 9810.9189 - root_mean_squared_error: 99.0501 - mean_absolute_error: 77.8223
# Epoch 8: val_loss improved from 93090.57031 to 66673.74219, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 9851.4639 - root_mean_squared_error: 99.2545 - mean_absolute_error: 77.1589 - val_loss: 66673.7422 - val_root_mean_squared_error: 258.2126 - val_mean_absolute_error: 212.1974
# Epoch 9/500
# 34/37 [==========================>...] - ETA: 0s - loss: 8100.8198 - root_mean_squared_error: 90.0046 - mean_absolute_error: 70.2537
# Epoch 9: val_loss improved from 66673.74219 to 48103.54297, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 7939.9155 - root_mean_squared_error: 89.1062 - mean_absolute_error: 69.6387 - val_loss: 48103.5430 - val_root_mean_squared_error: 219.3252 - val_mean_absolute_error: 179.8880
# Epoch 10/500
# 35/37 [===========================>..] - ETA: 0s - loss: 7610.4800 - root_mean_squared_error: 87.2381 - mean_absolute_error: 67.1266
# Epoch 10: val_loss improved from 48103.54297 to 34789.55859, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 7736.2192 - root_mean_squared_error: 87.9558 - mean_absolute_error: 67.7281 - val_loss: 34789.5586 - val_root_mean_squared_error: 186.5196 - val_mean_absolute_error: 153.6231
# Epoch 11/500
# 30/37 [=======================>......] - ETA: 0s - loss: 8297.8965 - root_mean_squared_error: 91.0928 - mean_absolute_error: 70.0390
# Epoch 11: val_loss did not improve from 34789.55859
# 37/37 [==============================] - 0s 11ms/step - loss: 8021.8467 - root_mean_squared_error: 89.5648 - mean_absolute_error: 68.6442 - val_loss: 40192.9297 - val_root_mean_squared_error: 200.4817 - val_mean_absolute_error: 163.8633
# Epoch 12/500
# 29/37 [======================>.......] - ETA: 0s - loss: 7976.8140 - root_mean_squared_error: 89.3130 - mean_absolute_error: 68.6369
# Epoch 12: val_loss improved from 34789.55859 to 16756.15234, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 12ms/step - loss: 7554.3877 - root_mean_squared_error: 86.9160 - mean_absolute_error: 66.9918 - val_loss: 16756.1523 - val_root_mean_squared_error: 129.4456 - val_mean_absolute_error: 106.6816
# Epoch 13/500
# 31/37 [========================>.....] - ETA: 0s - loss: 8120.2021 - root_mean_squared_error: 90.1122 - mean_absolute_error: 66.3605
# Epoch 13: val_loss improved from 16756.15234 to 10065.46875, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 7835.4531 - root_mean_squared_error: 88.5181 - mean_absolute_error: 65.8297 - val_loss: 10065.4688 - val_root_mean_squared_error: 100.3268 - val_mean_absolute_error: 82.8140
# Epoch 14/500
# 36/37 [============================>.] - ETA: 0s - loss: 6235.4575 - root_mean_squared_error: 78.9649 - mean_absolute_error: 61.8606
# Epoch 14: val_loss improved from 10065.46875 to 10024.28711, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 6234.6719 - root_mean_squared_error: 78.9599 - mean_absolute_error: 61.9108 - val_loss: 10024.2871 - val_root_mean_squared_error: 100.1214 - val_mean_absolute_error: 81.9314
# Epoch 15/500
# 35/37 [===========================>..] - ETA: 0s - loss: 6588.5220 - root_mean_squared_error: 81.1697 - mean_absolute_error: 62.3935
# Epoch 15: val_loss improved from 10024.28711 to 8788.08398, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 6601.2437 - root_mean_squared_error: 81.2480 - mean_absolute_error: 62.5355 - val_loss: 8788.0840 - val_root_mean_squared_error: 93.7448 - val_mean_absolute_error: 74.6560
# Epoch 16/500
# 35/37 [===========================>..] - ETA: 0s - loss: 5597.7231 - root_mean_squared_error: 74.8179 - mean_absolute_error: 57.2818
# Epoch 16: val_loss improved from 8788.08398 to 6929.78760, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 5590.4966 - root_mean_squared_error: 74.7696 - mean_absolute_error: 57.3044 - val_loss: 6929.7876 - val_root_mean_squared_error: 83.2453 - val_mean_absolute_error: 67.0203
# Epoch 17/500
# 34/37 [==========================>...] - ETA: 0s - loss: 5046.1675 - root_mean_squared_error: 71.0364 - mean_absolute_error: 53.4238
# Epoch 17: val_loss improved from 6929.78760 to 3958.39868, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 4909.4307 - root_mean_squared_error: 70.0673 - mean_absolute_error: 52.8541 - val_loss: 3958.3987 - val_root_mean_squared_error: 62.9158 - val_mean_absolute_error: 47.8311
# Epoch 18/500
# 34/37 [==========================>...] - ETA: 0s - loss: 5996.3706 - root_mean_squared_error: 77.4362 - mean_absolute_error: 56.7454
# Epoch 18: val_loss did not improve from 3958.39868
# 37/37 [==============================] - 0s 12ms/step - loss: 5864.9478 - root_mean_squared_error: 76.5829 - mean_absolute_error: 56.3982 - val_loss: 12873.3076 - val_root_mean_squared_error: 113.4606 - val_mean_absolute_error: 100.2995
# Epoch 19/500
# 35/37 [===========================>..] - ETA: 0s - loss: 5304.4194 - root_mean_squared_error: 72.8314 - mean_absolute_error: 56.5358
# Epoch 19: val_loss did not improve from 3958.39868
# 37/37 [==============================] - 0s 12ms/step - loss: 5418.1055 - root_mean_squared_error: 73.6078 - mean_absolute_error: 57.1680 - val_loss: 7370.8750 - val_root_mean_squared_error: 85.8538 - val_mean_absolute_error: 70.3582
# Epoch 20/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4991.7993 - root_mean_squared_error: 70.6527 - mean_absolute_error: 55.0166
# Epoch 20: val_loss did not improve from 3958.39868
# 37/37 [==============================] - 0s 13ms/step - loss: 4873.1914 - root_mean_squared_error: 69.8082 - mean_absolute_error: 54.5840 - val_loss: 14443.7500 - val_root_mean_squared_error: 120.1822 - val_mean_absolute_error: 107.4466
# Epoch 21/500
# 34/37 [==========================>...] - ETA: 0s - loss: 4392.1211 - root_mean_squared_error: 66.2731 - mean_absolute_error: 50.4940
# Epoch 21: val_loss improved from 3958.39868 to 3198.54468, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 4568.6104 - root_mean_squared_error: 67.5915 - mean_absolute_error: 51.6166 - val_loss: 3198.5447 - val_root_mean_squared_error: 56.5557 - val_mean_absolute_error: 43.0761
# Epoch 22/500
# 37/37 [==============================] - ETA: 0s - loss: 4963.3438 - root_mean_squared_error: 70.4510 - mean_absolute_error: 52.6937
# Epoch 22: val_loss did not improve from 3198.54468
# 37/37 [==============================] - 0s 12ms/step - loss: 4963.3438 - root_mean_squared_error: 70.4510 - mean_absolute_error: 52.6937 - val_loss: 4366.6655 - val_root_mean_squared_error: 66.0807 - val_mean_absolute_error: 52.3653
# Epoch 23/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4081.3533 - root_mean_squared_error: 63.8855 - mean_absolute_error: 46.8069
# Epoch 23: val_loss improved from 3198.54468 to 3116.12134, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 3988.8879 - root_mean_squared_error: 63.1576 - mean_absolute_error: 46.6044 - val_loss: 3116.1213 - val_root_mean_squared_error: 55.8222 - val_mean_absolute_error: 43.6936
# Epoch 24/500
# 29/37 [======================>.......] - ETA: 0s - loss: 4511.4126 - root_mean_squared_error: 67.1671 - mean_absolute_error: 51.5776
# Epoch 24: val_loss improved from 3116.12134 to 2984.20068, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 4581.9453 - root_mean_squared_error: 67.6901 - mean_absolute_error: 51.1567 - val_loss: 2984.2007 - val_root_mean_squared_error: 54.6278 - val_mean_absolute_error: 42.8411
# Epoch 25/500
# 34/37 [==========================>...] - ETA: 0s - loss: 4256.2100 - root_mean_squared_error: 65.2396 - mean_absolute_error: 49.6932
# Epoch 25: val_loss improved from 2984.20068 to 2662.87061, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 4218.8545 - root_mean_squared_error: 64.9527 - mean_absolute_error: 49.3535 - val_loss: 2662.8706 - val_root_mean_squared_error: 51.6030 - val_mean_absolute_error: 39.7643
# Epoch 26/500
# 31/37 [========================>.....] - ETA: 0s - loss: 3574.0991 - root_mean_squared_error: 59.7838 - mean_absolute_error: 44.3658
# Epoch 26: val_loss did not improve from 2662.87061
# 37/37 [==============================] - 1s 14ms/step - loss: 3591.3232 - root_mean_squared_error: 59.9276 - mean_absolute_error: 44.1909 - val_loss: 6748.9907 - val_root_mean_squared_error: 82.1522 - val_mean_absolute_error: 69.1940
# Epoch 27/500
# 32/37 [========================>.....] - ETA: 0s - loss: 4174.2134 - root_mean_squared_error: 64.6081 - mean_absolute_error: 49.9802
# Epoch 27: val_loss did not improve from 2662.87061
# 37/37 [==============================] - 0s 13ms/step - loss: 3987.2351 - root_mean_squared_error: 63.1446 - mean_absolute_error: 48.9758 - val_loss: 2718.5654 - val_root_mean_squared_error: 52.1399 - val_mean_absolute_error: 41.0531
# Epoch 28/500
# 37/37 [==============================] - ETA: 0s - loss: 3517.9197 - root_mean_squared_error: 59.3121 - mean_absolute_error: 44.7476
# Epoch 28: val_loss did not improve from 2662.87061
# 37/37 [==============================] - 0s 13ms/step - loss: 3517.9197 - root_mean_squared_error: 59.3121 - mean_absolute_error: 44.7476 - val_loss: 4918.3311 - val_root_mean_squared_error: 70.1308 - val_mean_absolute_error: 57.5474
# Epoch 29/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3131.5281 - root_mean_squared_error: 55.9601 - mean_absolute_error: 42.7306
# Epoch 29: val_loss improved from 2662.87061 to 2400.34570, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 3257.7817 - root_mean_squared_error: 57.0770 - mean_absolute_error: 43.2791 - val_loss: 2400.3457 - val_root_mean_squared_error: 48.9933 - val_mean_absolute_error: 37.2271
# Epoch 30/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3839.5247 - root_mean_squared_error: 61.9639 - mean_absolute_error: 46.1056
# Epoch 30: val_loss improved from 2400.34570 to 2005.35828, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 3765.1008 - root_mean_squared_error: 61.3604 - mean_absolute_error: 45.5474 - val_loss: 2005.3583 - val_root_mean_squared_error: 44.7812 - val_mean_absolute_error: 32.7577
# Epoch 31/500
# 36/37 [============================>.] - ETA: 0s - loss: 3419.3291 - root_mean_squared_error: 58.4750 - mean_absolute_error: 44.1494
# Epoch 31: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 11ms/step - loss: 3406.7959 - root_mean_squared_error: 58.3678 - mean_absolute_error: 44.0632 - val_loss: 2089.7065 - val_root_mean_squared_error: 45.7133 - val_mean_absolute_error: 34.0325
# Epoch 32/500
# 36/37 [============================>.] - ETA: 0s - loss: 3288.4927 - root_mean_squared_error: 57.3454 - mean_absolute_error: 43.1620
# Epoch 32: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 10ms/step - loss: 3279.3755 - root_mean_squared_error: 57.2658 - mean_absolute_error: 43.1058 - val_loss: 2086.7988 - val_root_mean_squared_error: 45.6815 - val_mean_absolute_error: 33.8244
# Epoch 33/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4229.0181 - root_mean_squared_error: 65.0309 - mean_absolute_error: 47.1974
# Epoch 33: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 12ms/step - loss: 4088.1812 - root_mean_squared_error: 63.9389 - mean_absolute_error: 46.5393 - val_loss: 3091.7771 - val_root_mean_squared_error: 55.6037 - val_mean_absolute_error: 45.2126
# Epoch 34/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3043.3877 - root_mean_squared_error: 55.1669 - mean_absolute_error: 41.3386
# Epoch 34: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 12ms/step - loss: 3014.8059 - root_mean_squared_error: 54.9072 - mean_absolute_error: 41.1037 - val_loss: 2019.5956 - val_root_mean_squared_error: 44.9399 - val_mean_absolute_error: 34.1394
# Epoch 35/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4400.6138 - root_mean_squared_error: 66.3371 - mean_absolute_error: 49.9493
# Epoch 35: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 12ms/step - loss: 4391.6709 - root_mean_squared_error: 66.2697 - mean_absolute_error: 50.1139 - val_loss: 2539.2888 - val_root_mean_squared_error: 50.3914 - val_mean_absolute_error: 38.2329
# Epoch 36/500
# 37/37 [==============================] - ETA: 0s - loss: 3192.6077 - root_mean_squared_error: 56.5032 - mean_absolute_error: 41.2703
# Epoch 36: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 14ms/step - loss: 3192.6077 - root_mean_squared_error: 56.5032 - mean_absolute_error: 41.2703 - val_loss: 19285.3105 - val_root_mean_squared_error: 138.8716 - val_mean_absolute_error: 130.2111
# Epoch 37/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4326.3872 - root_mean_squared_error: 65.7753 - mean_absolute_error: 50.0172
# Epoch 37: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 12ms/step - loss: 4158.5244 - root_mean_squared_error: 64.4866 - mean_absolute_error: 48.6513 - val_loss: 2452.1196 - val_root_mean_squared_error: 49.5189 - val_mean_absolute_error: 36.8721
# Epoch 38/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3328.8918 - root_mean_squared_error: 57.6965 - mean_absolute_error: 40.9441
# Epoch 38: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 12ms/step - loss: 3266.8472 - root_mean_squared_error: 57.1563 - mean_absolute_error: 40.6439 - val_loss: 3186.1663 - val_root_mean_squared_error: 56.4461 - val_mean_absolute_error: 44.2935
# Epoch 39/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2890.3330 - root_mean_squared_error: 53.7618 - mean_absolute_error: 39.4878
# Epoch 39: val_loss did not improve from 2005.35828
# 37/37 [==============================] - 0s 12ms/step - loss: 2900.4285 - root_mean_squared_error: 53.8556 - mean_absolute_error: 39.5271 - val_loss: 3229.2634 - val_root_mean_squared_error: 56.8266 - val_mean_absolute_error: 44.6203
# Epoch 40/500
# 31/37 [========================>.....] - ETA: 0s - loss: 3612.4839 - root_mean_squared_error: 60.1039 - mean_absolute_error: 44.2619
# Epoch 40: val_loss improved from 2005.35828 to 1700.65881, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 3462.2703 - root_mean_squared_error: 58.8411 - mean_absolute_error: 43.6500 - val_loss: 1700.6588 - val_root_mean_squared_error: 41.2390 - val_mean_absolute_error: 30.4306
# Epoch 41/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2723.6838 - root_mean_squared_error: 52.1889 - mean_absolute_error: 38.4682
# Epoch 41: val_loss did not improve from 1700.65881
# 37/37 [==============================] - 0s 9ms/step - loss: 3003.1121 - root_mean_squared_error: 54.8007 - mean_absolute_error: 40.1788 - val_loss: 4420.2349 - val_root_mean_squared_error: 66.4848 - val_mean_absolute_error: 55.1831
# Epoch 42/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2736.2151 - root_mean_squared_error: 52.3088 - mean_absolute_error: 38.3474
# Epoch 42: val_loss did not improve from 1700.65881
# 37/37 [==============================] - 0s 11ms/step - loss: 2714.4646 - root_mean_squared_error: 52.1005 - mean_absolute_error: 38.3808 - val_loss: 6531.2129 - val_root_mean_squared_error: 80.8159 - val_mean_absolute_error: 72.0011
# Epoch 43/500
# 37/37 [==============================] - ETA: 0s - loss: 3537.6013 - root_mean_squared_error: 59.4777 - mean_absolute_error: 44.1272
# Epoch 43: val_loss did not improve from 1700.65881
# 37/37 [==============================] - 0s 12ms/step - loss: 3537.6013 - root_mean_squared_error: 59.4777 - mean_absolute_error: 44.1272 - val_loss: 1860.1571 - val_root_mean_squared_error: 43.1295 - val_mean_absolute_error: 32.5691
# Epoch 44/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3006.4468 - root_mean_squared_error: 54.8311 - mean_absolute_error: 41.4241
# Epoch 44: val_loss did not improve from 1700.65881
# 37/37 [==============================] - 0s 12ms/step - loss: 3060.1543 - root_mean_squared_error: 55.3187 - mean_absolute_error: 41.6544 - val_loss: 4892.7822 - val_root_mean_squared_error: 69.9484 - val_mean_absolute_error: 59.8733
# Epoch 45/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2408.1133 - root_mean_squared_error: 49.0725 - mean_absolute_error: 35.8835
# Epoch 45: val_loss did not improve from 1700.65881
# 37/37 [==============================] - 0s 13ms/step - loss: 2297.9849 - root_mean_squared_error: 47.9373 - mean_absolute_error: 35.5227 - val_loss: 3100.1719 - val_root_mean_squared_error: 55.6792 - val_mean_absolute_error: 45.6641
# Epoch 46/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2286.5361 - root_mean_squared_error: 47.8177 - mean_absolute_error: 35.1033
# Epoch 46: val_loss improved from 1700.65881 to 1437.82678, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 2308.9487 - root_mean_squared_error: 48.0515 - mean_absolute_error: 35.4064 - val_loss: 1437.8268 - val_root_mean_squared_error: 37.9187 - val_mean_absolute_error: 28.6284
# Epoch 47/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2367.1223 - root_mean_squared_error: 48.6531 - mean_absolute_error: 34.9366
# Epoch 47: val_loss did not improve from 1437.82678
# 37/37 [==============================] - 0s 11ms/step - loss: 2365.8074 - root_mean_squared_error: 48.6396 - mean_absolute_error: 35.1941 - val_loss: 3382.1406 - val_root_mean_squared_error: 58.1562 - val_mean_absolute_error: 49.0172
# Epoch 48/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2800.8838 - root_mean_squared_error: 52.9234 - mean_absolute_error: 39.3533
# Epoch 48: val_loss did not improve from 1437.82678
# 37/37 [==============================] - 0s 12ms/step - loss: 2976.6829 - root_mean_squared_error: 54.5590 - mean_absolute_error: 39.9341 - val_loss: 1968.8916 - val_root_mean_squared_error: 44.3722 - val_mean_absolute_error: 33.6907
# Epoch 49/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2601.0168 - root_mean_squared_error: 51.0002 - mean_absolute_error: 37.8330
# Epoch 49: val_loss did not improve from 1437.82678
# 37/37 [==============================] - 0s 12ms/step - loss: 2601.7769 - root_mean_squared_error: 51.0076 - mean_absolute_error: 37.8814 - val_loss: 2717.5471 - val_root_mean_squared_error: 52.1301 - val_mean_absolute_error: 44.0633
# Epoch 50/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2291.1729 - root_mean_squared_error: 47.8662 - mean_absolute_error: 35.6017
# Epoch 50: val_loss did not improve from 1437.82678
# 37/37 [==============================] - 0s 12ms/step - loss: 2402.2031 - root_mean_squared_error: 49.0123 - mean_absolute_error: 36.2349 - val_loss: 1633.3557 - val_root_mean_squared_error: 40.4148 - val_mean_absolute_error: 30.8603
# Epoch 51/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2482.2981 - root_mean_squared_error: 49.8227 - mean_absolute_error: 37.4380
# Epoch 51: val_loss did not improve from 1437.82678
# 37/37 [==============================] - 0s 12ms/step - loss: 2457.4539 - root_mean_squared_error: 49.5727 - mean_absolute_error: 37.2925 - val_loss: 5823.4873 - val_root_mean_squared_error: 76.3118 - val_mean_absolute_error: 65.3778
# Epoch 52/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2708.3411 - root_mean_squared_error: 52.0417 - mean_absolute_error: 38.1262
# Epoch 52: val_loss improved from 1437.82678 to 1416.70020, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2778.5410 - root_mean_squared_error: 52.7119 - mean_absolute_error: 38.5603 - val_loss: 1416.7002 - val_root_mean_squared_error: 37.6391 - val_mean_absolute_error: 27.5193
# Epoch 53/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2726.4119 - root_mean_squared_error: 52.2151 - mean_absolute_error: 39.1298
# Epoch 53: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 12ms/step - loss: 2730.2671 - root_mean_squared_error: 52.2520 - mean_absolute_error: 39.2739 - val_loss: 3458.6169 - val_root_mean_squared_error: 58.8100 - val_mean_absolute_error: 49.7343
# Epoch 54/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2820.9553 - root_mean_squared_error: 53.1127 - mean_absolute_error: 36.7395
# Epoch 54: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 11ms/step - loss: 2749.8467 - root_mean_squared_error: 52.4390 - mean_absolute_error: 36.2209 - val_loss: 3644.3333 - val_root_mean_squared_error: 60.3683 - val_mean_absolute_error: 52.6361
# Epoch 55/500
# 36/37 [============================>.] - ETA: 0s - loss: 2438.3735 - root_mean_squared_error: 49.3799 - mean_absolute_error: 36.6633
# Epoch 55: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 11ms/step - loss: 2452.2039 - root_mean_squared_error: 49.5197 - mean_absolute_error: 36.7957 - val_loss: 2157.4929 - val_root_mean_squared_error: 46.4488 - val_mean_absolute_error: 37.7461
# Epoch 56/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2471.7734 - root_mean_squared_error: 49.7169 - mean_absolute_error: 36.7475
# Epoch 56: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 13ms/step - loss: 2449.7129 - root_mean_squared_error: 49.4946 - mean_absolute_error: 36.8282 - val_loss: 2107.6252 - val_root_mean_squared_error: 45.9089 - val_mean_absolute_error: 37.7781
# Epoch 57/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2636.2139 - root_mean_squared_error: 51.3441 - mean_absolute_error: 36.0530
# Epoch 57: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 13ms/step - loss: 2648.2097 - root_mean_squared_error: 51.4608 - mean_absolute_error: 36.1381 - val_loss: 2389.9304 - val_root_mean_squared_error: 48.8869 - val_mean_absolute_error: 40.4956
# Epoch 58/500
# 37/37 [==============================] - ETA: 0s - loss: 2581.4990 - root_mean_squared_error: 50.8085 - mean_absolute_error: 37.5724
# Epoch 58: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 14ms/step - loss: 2581.4990 - root_mean_squared_error: 50.8085 - mean_absolute_error: 37.5724 - val_loss: 3982.9363 - val_root_mean_squared_error: 63.1105 - val_mean_absolute_error: 55.0805
# Epoch 59/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2375.7202 - root_mean_squared_error: 48.7414 - mean_absolute_error: 34.4695
# Epoch 59: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 13ms/step - loss: 2332.1428 - root_mean_squared_error: 48.2923 - mean_absolute_error: 34.3125 - val_loss: 1462.5278 - val_root_mean_squared_error: 38.2430 - val_mean_absolute_error: 29.1710
# Epoch 60/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2562.0100 - root_mean_squared_error: 50.6163 - mean_absolute_error: 36.2767
# Epoch 60: val_loss did not improve from 1416.70020
# 37/37 [==============================] - 0s 13ms/step - loss: 2597.9766 - root_mean_squared_error: 50.9703 - mean_absolute_error: 36.2741 - val_loss: 2276.3208 - val_root_mean_squared_error: 47.7108 - val_mean_absolute_error: 38.8730
# Epoch 61/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2251.9280 - root_mean_squared_error: 47.4545 - mean_absolute_error: 35.2737
# Epoch 61: val_loss improved from 1416.70020 to 1127.04236, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 2183.5879 - root_mean_squared_error: 46.7289 - mean_absolute_error: 34.4361 - val_loss: 1127.0424 - val_root_mean_squared_error: 33.5714 - val_mean_absolute_error: 24.8545
# Epoch 62/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2106.1064 - root_mean_squared_error: 45.8923 - mean_absolute_error: 32.7783
# Epoch 62: val_loss did not improve from 1127.04236
# 37/37 [==============================] - 0s 13ms/step - loss: 2168.0154 - root_mean_squared_error: 46.5620 - mean_absolute_error: 32.7954 - val_loss: 1519.8302 - val_root_mean_squared_error: 38.9850 - val_mean_absolute_error: 31.3235
# Epoch 63/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2721.0986 - root_mean_squared_error: 52.1642 - mean_absolute_error: 35.6367
# Epoch 63: val_loss did not improve from 1127.04236
# 37/37 [==============================] - 0s 12ms/step - loss: 2765.7004 - root_mean_squared_error: 52.5899 - mean_absolute_error: 36.1686 - val_loss: 2548.3635 - val_root_mean_squared_error: 50.4813 - val_mean_absolute_error: 39.6671
# Epoch 64/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2469.4153 - root_mean_squared_error: 49.6932 - mean_absolute_error: 37.9155
# Epoch 64: val_loss did not improve from 1127.04236
# 37/37 [==============================] - 0s 11ms/step - loss: 2400.6572 - root_mean_squared_error: 48.9965 - mean_absolute_error: 37.2957 - val_loss: 1283.6804 - val_root_mean_squared_error: 35.8285 - val_mean_absolute_error: 27.2669
# Epoch 65/500
# 36/37 [============================>.] - ETA: 0s - loss: 2485.5801 - root_mean_squared_error: 49.8556 - mean_absolute_error: 37.0402
# Epoch 65: val_loss did not improve from 1127.04236
# 37/37 [==============================] - 0s 12ms/step - loss: 2474.1350 - root_mean_squared_error: 49.7407 - mean_absolute_error: 36.8755 - val_loss: 1575.4514 - val_root_mean_squared_error: 39.6920 - val_mean_absolute_error: 31.6664
# Epoch 66/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2670.5574 - root_mean_squared_error: 51.6774 - mean_absolute_error: 37.3193
# Epoch 66: val_loss improved from 1127.04236 to 1101.42334, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 2594.3792 - root_mean_squared_error: 50.9350 - mean_absolute_error: 36.5376 - val_loss: 1101.4233 - val_root_mean_squared_error: 33.1877 - val_mean_absolute_error: 24.2779
# Epoch 67/500
# 37/37 [==============================] - ETA: 0s - loss: 2173.2117 - root_mean_squared_error: 46.6177 - mean_absolute_error: 34.1622
# Epoch 67: val_loss did not improve from 1101.42334
# 37/37 [==============================] - 0s 11ms/step - loss: 2173.2117 - root_mean_squared_error: 46.6177 - mean_absolute_error: 34.1622 - val_loss: 1324.8252 - val_root_mean_squared_error: 36.3981 - val_mean_absolute_error: 27.7906
# Epoch 68/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3142.8423 - root_mean_squared_error: 56.0611 - mean_absolute_error: 41.2357
# Epoch 68: val_loss did not improve from 1101.42334
# 37/37 [==============================] - 0s 10ms/step - loss: 3107.7202 - root_mean_squared_error: 55.7469 - mean_absolute_error: 41.0416 - val_loss: 1168.4098 - val_root_mean_squared_error: 34.1820 - val_mean_absolute_error: 25.8461
# Epoch 69/500
# 31/37 [========================>.....] - ETA: 0s - loss: 1970.5802 - root_mean_squared_error: 44.3912 - mean_absolute_error: 31.7189
# Epoch 69: val_loss improved from 1101.42334 to 1066.52710, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 2029.9502 - root_mean_squared_error: 45.0550 - mean_absolute_error: 31.7850 - val_loss: 1066.5271 - val_root_mean_squared_error: 32.6577 - val_mean_absolute_error: 24.6448
# Epoch 70/500
# 36/37 [============================>.] - ETA: 0s - loss: 1961.0237 - root_mean_squared_error: 44.2834 - mean_absolute_error: 32.0682
# Epoch 70: val_loss did not improve from 1066.52710
# 37/37 [==============================] - 0s 10ms/step - loss: 1955.1970 - root_mean_squared_error: 44.2176 - mean_absolute_error: 32.0315 - val_loss: 1096.9124 - val_root_mean_squared_error: 33.1197 - val_mean_absolute_error: 25.2014
# Epoch 71/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2023.0040 - root_mean_squared_error: 44.9778 - mean_absolute_error: 31.7923
# Epoch 71: val_loss did not improve from 1066.52710
# 37/37 [==============================] - 0s 11ms/step - loss: 2034.7731 - root_mean_squared_error: 45.1085 - mean_absolute_error: 31.9074 - val_loss: 2792.8311 - val_root_mean_squared_error: 52.8472 - val_mean_absolute_error: 44.5586
# Epoch 72/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2413.6902 - root_mean_squared_error: 49.1293 - mean_absolute_error: 34.4359
# Epoch 72: val_loss did not improve from 1066.52710
# 37/37 [==============================] - 0s 12ms/step - loss: 2312.7507 - root_mean_squared_error: 48.0911 - mean_absolute_error: 34.0706 - val_loss: 5700.3843 - val_root_mean_squared_error: 75.5009 - val_mean_absolute_error: 67.4147
# Epoch 73/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2400.7520 - root_mean_squared_error: 48.9975 - mean_absolute_error: 35.0289
# Epoch 73: val_loss improved from 1066.52710 to 944.30481, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2392.4846 - root_mean_squared_error: 48.9130 - mean_absolute_error: 35.2893 - val_loss: 944.3048 - val_root_mean_squared_error: 30.7295 - val_mean_absolute_error: 22.1648
# Epoch 74/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2200.4338 - root_mean_squared_error: 46.9088 - mean_absolute_error: 34.0892
# Epoch 74: val_loss did not improve from 944.30481
# 37/37 [==============================] - 0s 11ms/step - loss: 2162.5022 - root_mean_squared_error: 46.5027 - mean_absolute_error: 33.7153 - val_loss: 1204.3684 - val_root_mean_squared_error: 34.7040 - val_mean_absolute_error: 27.2281
# Epoch 75/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2359.7766 - root_mean_squared_error: 48.5775 - mean_absolute_error: 34.9232
# Epoch 75: val_loss did not improve from 944.30481
# 37/37 [==============================] - 0s 12ms/step - loss: 2493.7791 - root_mean_squared_error: 49.9378 - mean_absolute_error: 35.9455 - val_loss: 955.1224 - val_root_mean_squared_error: 30.9051 - val_mean_absolute_error: 22.3148
# Epoch 76/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2083.2581 - root_mean_squared_error: 45.6427 - mean_absolute_error: 32.8537
# Epoch 76: val_loss did not improve from 944.30481
# 37/37 [==============================] - 0s 12ms/step - loss: 2085.0757 - root_mean_squared_error: 45.6626 - mean_absolute_error: 32.7621 - val_loss: 1327.5131 - val_root_mean_squared_error: 36.4351 - val_mean_absolute_error: 28.6569
# Epoch 77/500
# 36/37 [============================>.] - ETA: 0s - loss: 1997.2448 - root_mean_squared_error: 44.6905 - mean_absolute_error: 32.1528
# Epoch 77: val_loss improved from 944.30481 to 884.48199, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 2014.7521 - root_mean_squared_error: 44.8860 - mean_absolute_error: 32.3486 - val_loss: 884.4820 - val_root_mean_squared_error: 29.7402 - val_mean_absolute_error: 21.0926
# Epoch 78/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2174.4624 - root_mean_squared_error: 46.6311 - mean_absolute_error: 34.2540
# Epoch 78: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 11ms/step - loss: 2298.4795 - root_mean_squared_error: 47.9425 - mean_absolute_error: 35.1694 - val_loss: 7932.0127 - val_root_mean_squared_error: 89.0619 - val_mean_absolute_error: 82.5860
# Epoch 79/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2825.2422 - root_mean_squared_error: 53.1530 - mean_absolute_error: 40.2496
# Epoch 79: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 13ms/step - loss: 2637.0291 - root_mean_squared_error: 51.3520 - mean_absolute_error: 38.3652 - val_loss: 1207.9642 - val_root_mean_squared_error: 34.7558 - val_mean_absolute_error: 26.4033
# Epoch 80/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2080.9719 - root_mean_squared_error: 45.6177 - mean_absolute_error: 33.8663
# Epoch 80: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 12ms/step - loss: 2125.1416 - root_mean_squared_error: 46.0993 - mean_absolute_error: 34.0611 - val_loss: 3583.3679 - val_root_mean_squared_error: 59.8612 - val_mean_absolute_error: 52.1796
# Epoch 81/500
# 30/37 [=======================>......] - ETA: 0s - loss: 2116.6594 - root_mean_squared_error: 46.0072 - mean_absolute_error: 33.9048
# Epoch 81: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 13ms/step - loss: 1977.4578 - root_mean_squared_error: 44.4686 - mean_absolute_error: 32.6926 - val_loss: 1262.7789 - val_root_mean_squared_error: 35.5356 - val_mean_absolute_error: 26.8327
# Epoch 82/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2167.2461 - root_mean_squared_error: 46.5537 - mean_absolute_error: 32.3924
# Epoch 82: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 13ms/step - loss: 2114.6670 - root_mean_squared_error: 45.9855 - mean_absolute_error: 32.1157 - val_loss: 1719.4362 - val_root_mean_squared_error: 41.4661 - val_mean_absolute_error: 34.2864
# Epoch 83/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1663.9174 - root_mean_squared_error: 40.7911 - mean_absolute_error: 29.3132
# Epoch 83: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 13ms/step - loss: 1729.5763 - root_mean_squared_error: 41.5882 - mean_absolute_error: 29.9203 - val_loss: 962.6414 - val_root_mean_squared_error: 31.0265 - val_mean_absolute_error: 21.4419
# Epoch 84/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1838.1282 - root_mean_squared_error: 42.8734 - mean_absolute_error: 31.4688
# Epoch 84: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 13ms/step - loss: 1865.8174 - root_mean_squared_error: 43.1951 - mean_absolute_error: 31.4830 - val_loss: 2260.3359 - val_root_mean_squared_error: 47.5430 - val_mean_absolute_error: 40.4991
# Epoch 85/500
# 36/37 [============================>.] - ETA: 0s - loss: 1874.3433 - root_mean_squared_error: 43.2937 - mean_absolute_error: 32.3823
# Epoch 85: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 14ms/step - loss: 1865.8411 - root_mean_squared_error: 43.1954 - mean_absolute_error: 32.2551 - val_loss: 1118.0563 - val_root_mean_squared_error: 33.4373 - val_mean_absolute_error: 25.1177
# Epoch 86/500
# 30/37 [=======================>......] - ETA: 0s - loss: 2263.5178 - root_mean_squared_error: 47.5764 - mean_absolute_error: 36.5951
# Epoch 86: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 12ms/step - loss: 2533.4934 - root_mean_squared_error: 50.3338 - mean_absolute_error: 37.6052 - val_loss: 1975.5747 - val_root_mean_squared_error: 44.4474 - val_mean_absolute_error: 36.9187
# Epoch 87/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2280.6377 - root_mean_squared_error: 47.7560 - mean_absolute_error: 35.7106
# Epoch 87: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 11ms/step - loss: 2496.0498 - root_mean_squared_error: 49.9605 - mean_absolute_error: 36.4844 - val_loss: 1505.7406 - val_root_mean_squared_error: 38.8039 - val_mean_absolute_error: 29.2481
# Epoch 88/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1900.3419 - root_mean_squared_error: 43.5929 - mean_absolute_error: 32.4369
# Epoch 88: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 12ms/step - loss: 1910.2515 - root_mean_squared_error: 43.7064 - mean_absolute_error: 32.3702 - val_loss: 1178.0599 - val_root_mean_squared_error: 34.3229 - val_mean_absolute_error: 25.9876
# Epoch 89/500
# 37/37 [==============================] - ETA: 0s - loss: 1811.0104 - root_mean_squared_error: 42.5560 - mean_absolute_error: 28.9152
# Epoch 89: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 11ms/step - loss: 1811.0104 - root_mean_squared_error: 42.5560 - mean_absolute_error: 28.9152 - val_loss: 1554.8932 - val_root_mean_squared_error: 39.4321 - val_mean_absolute_error: 31.2281
# Epoch 90/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2415.9614 - root_mean_squared_error: 49.1524 - mean_absolute_error: 33.4443
# Epoch 90: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 12ms/step - loss: 2340.2930 - root_mean_squared_error: 48.3766 - mean_absolute_error: 33.0826 - val_loss: 5664.5894 - val_root_mean_squared_error: 75.2635 - val_mean_absolute_error: 68.0984
# Epoch 91/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2477.9736 - root_mean_squared_error: 49.7792 - mean_absolute_error: 35.7123
# Epoch 91: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 11ms/step - loss: 2593.2004 - root_mean_squared_error: 50.9235 - mean_absolute_error: 36.0734 - val_loss: 3891.0071 - val_root_mean_squared_error: 62.3779 - val_mean_absolute_error: 55.3861
# Epoch 92/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1796.8170 - root_mean_squared_error: 42.3889 - mean_absolute_error: 31.5433
# Epoch 92: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 10ms/step - loss: 1782.2246 - root_mean_squared_error: 42.2164 - mean_absolute_error: 31.9869 - val_loss: 1644.1937 - val_root_mean_squared_error: 40.5487 - val_mean_absolute_error: 32.2080
# Epoch 93/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2117.9104 - root_mean_squared_error: 46.0208 - mean_absolute_error: 32.3947
# Epoch 93: val_loss did not improve from 884.48199
# 37/37 [==============================] - 0s 13ms/step - loss: 2039.3098 - root_mean_squared_error: 45.1587 - mean_absolute_error: 31.8631 - val_loss: 2589.6655 - val_root_mean_squared_error: 50.8888 - val_mean_absolute_error: 43.0425
# Epoch 94/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1749.8594 - root_mean_squared_error: 41.8313 - mean_absolute_error: 29.8640
# Epoch 94: val_loss improved from 884.48199 to 816.39948, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 1635.0924 - root_mean_squared_error: 40.4363 - mean_absolute_error: 28.6300 - val_loss: 816.3995 - val_root_mean_squared_error: 28.5727 - val_mean_absolute_error: 21.6806
# Epoch 95/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1893.8556 - root_mean_squared_error: 43.5185 - mean_absolute_error: 31.4135
# Epoch 95: val_loss did not improve from 816.39948
# 37/37 [==============================] - 0s 13ms/step - loss: 2027.6661 - root_mean_squared_error: 45.0296 - mean_absolute_error: 32.2083 - val_loss: 1593.1835 - val_root_mean_squared_error: 39.9147 - val_mean_absolute_error: 33.0409
# Epoch 96/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1975.5416 - root_mean_squared_error: 44.4471 - mean_absolute_error: 31.9669
# Epoch 96: val_loss did not improve from 816.39948
# 37/37 [==============================] - 0s 12ms/step - loss: 2007.4921 - root_mean_squared_error: 44.8050 - mean_absolute_error: 32.6854 - val_loss: 854.2908 - val_root_mean_squared_error: 29.2283 - val_mean_absolute_error: 21.4859
# Epoch 97/500
# 36/37 [============================>.] - ETA: 0s - loss: 1388.8419 - root_mean_squared_error: 37.2672 - mean_absolute_error: 27.3971
# Epoch 97: val_loss did not improve from 816.39948
# 37/37 [==============================] - 0s 11ms/step - loss: 1422.2490 - root_mean_squared_error: 37.7127 - mean_absolute_error: 27.6096 - val_loss: 1169.0413 - val_root_mean_squared_error: 34.1912 - val_mean_absolute_error: 26.5764
# Epoch 98/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1726.0164 - root_mean_squared_error: 41.5454 - mean_absolute_error: 30.3910
# Epoch 98: val_loss did not improve from 816.39948
# 37/37 [==============================] - 0s 12ms/step - loss: 1741.7390 - root_mean_squared_error: 41.7341 - mean_absolute_error: 30.6189 - val_loss: 2607.2466 - val_root_mean_squared_error: 51.0612 - val_mean_absolute_error: 42.6547
# Epoch 99/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2180.4907 - root_mean_squared_error: 46.6957 - mean_absolute_error: 33.3954
# Epoch 99: val_loss did not improve from 816.39948
# 37/37 [==============================] - 0s 12ms/step - loss: 2076.2385 - root_mean_squared_error: 45.5658 - mean_absolute_error: 32.6423 - val_loss: 1221.2723 - val_root_mean_squared_error: 34.9467 - val_mean_absolute_error: 26.1430
# Epoch 100/500
# 28/37 [=====================>........] - ETA: 0s - loss: 1220.7565 - root_mean_squared_error: 34.9393 - mean_absolute_error: 25.7111
# Epoch 100: val_loss improved from 816.39948 to 778.19299, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 1331.4414 - root_mean_squared_error: 36.4889 - mean_absolute_error: 26.4950 - val_loss: 778.1930 - val_root_mean_squared_error: 27.8961 - val_mean_absolute_error: 20.3214
# Epoch 101/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1475.7183 - root_mean_squared_error: 38.4151 - mean_absolute_error: 27.5017
# Epoch 101: val_loss did not improve from 778.19299
# 37/37 [==============================] - 0s 12ms/step - loss: 1523.6794 - root_mean_squared_error: 39.0343 - mean_absolute_error: 28.0884 - val_loss: 1298.1754 - val_root_mean_squared_error: 36.0302 - val_mean_absolute_error: 28.3797
# Epoch 102/500
# 37/37 [==============================] - ETA: 0s - loss: 1643.6786 - root_mean_squared_error: 40.5423 - mean_absolute_error: 30.9430
# Epoch 102: val_loss did not improve from 778.19299
# 37/37 [==============================] - 0s 12ms/step - loss: 1643.6786 - root_mean_squared_error: 40.5423 - mean_absolute_error: 30.9430 - val_loss: 2019.1729 - val_root_mean_squared_error: 44.9352 - val_mean_absolute_error: 37.0309
# Epoch 103/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1936.1250 - root_mean_squared_error: 44.0014 - mean_absolute_error: 31.8439
# Epoch 103: val_loss did not improve from 778.19299
# 37/37 [==============================] - 0s 12ms/step - loss: 1891.3539 - root_mean_squared_error: 43.4897 - mean_absolute_error: 31.7159 - val_loss: 973.4523 - val_root_mean_squared_error: 31.2002 - val_mean_absolute_error: 24.1497
# Epoch 104/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1852.5548 - root_mean_squared_error: 43.0413 - mean_absolute_error: 29.6912
# Epoch 104: val_loss improved from 778.19299 to 750.46979, saving model to ./best_model_final_1/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 1827.4092 - root_mean_squared_error: 42.7482 - mean_absolute_error: 29.6181 - val_loss: 750.4698 - val_root_mean_squared_error: 27.3947 - val_mean_absolute_error: 19.5291
# Epoch 105/500
# ...
# Epoch 466/500
# 34/37 [==========================>...] - ETA: 0s - loss: 849.7912 - root_mean_squared_error: 29.1512 - mean_absolute_error: 20.0600
# Epoch 466: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 12ms/step - loss: 914.9475 - root_mean_squared_error: 30.2481 - mean_absolute_error: 20.6234 - val_loss: 601.8311 - val_root_mean_squared_error: 24.5322 - val_mean_absolute_error: 17.8504
# Epoch 467/500
# 31/37 [========================>.....] - ETA: 0s - loss: 784.3329 - root_mean_squared_error: 28.0059 - mean_absolute_error: 19.4161
# Epoch 467: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 13ms/step - loss: 815.6537 - root_mean_squared_error: 28.5597 - mean_absolute_error: 19.8426 - val_loss: 843.8254 - val_root_mean_squared_error: 29.0487 - val_mean_absolute_error: 23.5906
# Epoch 468/500
# 32/37 [========================>.....] - ETA: 0s - loss: 913.4712 - root_mean_squared_error: 30.2237 - mean_absolute_error: 21.1962
# Epoch 468: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 13ms/step - loss: 887.5029 - root_mean_squared_error: 29.7910 - mean_absolute_error: 20.9669 - val_loss: 325.0781 - val_root_mean_squared_error: 18.0299 - val_mean_absolute_error: 12.0025
# Epoch 469/500
# 31/37 [========================>.....] - ETA: 0s - loss: 740.7205 - root_mean_squared_error: 27.2162 - mean_absolute_error: 20.0737
# Epoch 469: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 13ms/step - loss: 897.6198 - root_mean_squared_error: 29.9603 - mean_absolute_error: 21.0621 - val_loss: 741.8822 - val_root_mean_squared_error: 27.2375 - val_mean_absolute_error: 21.1789
# Epoch 470/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1117.4521 - root_mean_squared_error: 33.4283 - mean_absolute_error: 24.2693
# Epoch 470: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 11ms/step - loss: 1103.6508 - root_mean_squared_error: 33.2212 - mean_absolute_error: 24.0891 - val_loss: 515.1816 - val_root_mean_squared_error: 22.6976 - val_mean_absolute_error: 17.6014
# Epoch 471/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1492.6910 - root_mean_squared_error: 38.6354 - mean_absolute_error: 27.5333
# Epoch 471: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 13ms/step - loss: 1434.5469 - root_mean_squared_error: 37.8754 - mean_absolute_error: 27.1723 - val_loss: 413.5784 - val_root_mean_squared_error: 20.3366 - val_mean_absolute_error: 14.4257
# Epoch 472/500
# 30/37 [=======================>......] - ETA: 0s - loss: 910.4265 - root_mean_squared_error: 30.1733 - mean_absolute_error: 21.5952
# Epoch 472: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 10ms/step - loss: 993.2537 - root_mean_squared_error: 31.5159 - mean_absolute_error: 22.5430 - val_loss: 325.2031 - val_root_mean_squared_error: 18.0334 - val_mean_absolute_error: 13.3163
# Epoch 473/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1015.7747 - root_mean_squared_error: 31.8712 - mean_absolute_error: 22.0585
# Epoch 473: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 12ms/step - loss: 1020.1282 - root_mean_squared_error: 31.9394 - mean_absolute_error: 22.5649 - val_loss: 304.6033 - val_root_mean_squared_error: 17.4529 - val_mean_absolute_error: 12.5213
# Epoch 474/500
# 33/37 [=========================>....] - ETA: 0s - loss: 799.7553 - root_mean_squared_error: 28.2799 - mean_absolute_error: 21.1283
# Epoch 474: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 12ms/step - loss: 931.9200 - root_mean_squared_error: 30.5274 - mean_absolute_error: 21.4772 - val_loss: 449.8551 - val_root_mean_squared_error: 21.2098 - val_mean_absolute_error: 16.4856
# Epoch 475/500
# 34/37 [==========================>...] - ETA: 0s - loss: 832.7814 - root_mean_squared_error: 28.8580 - mean_absolute_error: 21.1800
# Epoch 475: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 12ms/step - loss: 807.4399 - root_mean_squared_error: 28.4155 - mean_absolute_error: 20.7949 - val_loss: 349.5315 - val_root_mean_squared_error: 18.6958 - val_mean_absolute_error: 13.4971
# Epoch 476/500
# 33/37 [=========================>....] - ETA: 0s - loss: 705.3465 - root_mean_squared_error: 26.5584 - mean_absolute_error: 18.0137
# Epoch 476: val_loss did not improve from 237.34944
# 37/37 [==============================] - 0s 13ms/step - loss: 748.2254 - root_mean_squared_error: 27.3537 - mean_absolute_error: 18.5132 - val_loss: 888.7734 - val_root_mean_squared_error: 29.8123 - val_mean_absolute_error: 25.8243
# Epoch 477/500
# 33/37 [=========================>....] - ETA: 0s - loss: 627.7902 - root_mean_squared_error: 25.0557 - mean_absolute_error: 18.2357
# Epoch 477: val_loss improved from 237.34944 to 209.10905, saving model to ./best_model_final_1/best_model_fold_9.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 669.9687 - root_mean_squared_error: 25.8838 - mean_absolute_error: 18.5456 - val_loss: 209.1091 - val_root_mean_squared_error: 14.4606 - val_mean_absolute_error: 9.1626
# Epoch 478/500
# 34/37 [==========================>...] - ETA: 0s - loss: 714.5262 - root_mean_squared_error: 26.7306 - mean_absolute_error: 18.1240
# Epoch 478: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 716.1633 - root_mean_squared_error: 26.7612 - mean_absolute_error: 18.2883 - val_loss: 555.2767 - val_root_mean_squared_error: 23.5643 - val_mean_absolute_error: 18.1598
# Epoch 479/500
# 33/37 [=========================>....] - ETA: 0s - loss: 927.3540 - root_mean_squared_error: 30.4525 - mean_absolute_error: 21.7471
# Epoch 479: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 901.8163 - root_mean_squared_error: 30.0303 - mean_absolute_error: 21.6361 - val_loss: 424.8866 - val_root_mean_squared_error: 20.6128 - val_mean_absolute_error: 15.2552
# Epoch 480/500
# 33/37 [=========================>....] - ETA: 0s - loss: 742.1735 - root_mean_squared_error: 27.2429 - mean_absolute_error: 19.4071
# Epoch 480: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 732.6231 - root_mean_squared_error: 27.0670 - mean_absolute_error: 19.3498 - val_loss: 461.5912 - val_root_mean_squared_error: 21.4847 - val_mean_absolute_error: 15.7622
# Epoch 481/500
# 33/37 [=========================>....] - ETA: 0s - loss: 756.2045 - root_mean_squared_error: 27.4992 - mean_absolute_error: 18.7538
# Epoch 481: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 734.5945 - root_mean_squared_error: 27.1034 - mean_absolute_error: 18.6159 - val_loss: 395.0095 - val_root_mean_squared_error: 19.8748 - val_mean_absolute_error: 15.3829
# Epoch 482/500
# 34/37 [==========================>...] - ETA: 0s - loss: 711.7249 - root_mean_squared_error: 26.6782 - mean_absolute_error: 18.3358
# Epoch 482: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 697.8047 - root_mean_squared_error: 26.4160 - mean_absolute_error: 18.3301 - val_loss: 324.7844 - val_root_mean_squared_error: 18.0218 - val_mean_absolute_error: 12.6597
# Epoch 483/500
# 32/37 [========================>.....] - ETA: 0s - loss: 797.6184 - root_mean_squared_error: 28.2421 - mean_absolute_error: 20.2434
# Epoch 483: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 839.5563 - root_mean_squared_error: 28.9751 - mean_absolute_error: 20.1369 - val_loss: 894.4559 - val_root_mean_squared_error: 29.9075 - val_mean_absolute_error: 23.7122
# Epoch 484/500
# 34/37 [==========================>...] - ETA: 0s - loss: 864.1378 - root_mean_squared_error: 29.3962 - mean_absolute_error: 20.1219
# Epoch 484: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 887.1595 - root_mean_squared_error: 29.7852 - mean_absolute_error: 20.1663 - val_loss: 368.8702 - val_root_mean_squared_error: 19.2060 - val_mean_absolute_error: 13.2986
# Epoch 485/500
# 31/37 [========================>.....] - ETA: 0s - loss: 753.7980 - root_mean_squared_error: 27.4554 - mean_absolute_error: 19.8611
# Epoch 485: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 14ms/step - loss: 832.4562 - root_mean_squared_error: 28.8523 - mean_absolute_error: 20.3909 - val_loss: 1144.8204 - val_root_mean_squared_error: 33.8352 - val_mean_absolute_error: 27.9267
# Epoch 486/500
# 33/37 [=========================>....] - ETA: 0s - loss: 617.7677 - root_mean_squared_error: 24.8549 - mean_absolute_error: 17.2423
# Epoch 486: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 698.6006 - root_mean_squared_error: 26.4311 - mean_absolute_error: 18.0124 - val_loss: 416.5695 - val_root_mean_squared_error: 20.4100 - val_mean_absolute_error: 14.9981
# Epoch 487/500
# 37/37 [==============================] - ETA: 0s - loss: 813.6434 - root_mean_squared_error: 28.5244 - mean_absolute_error: 19.8144
# Epoch 487: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 11ms/step - loss: 813.6434 - root_mean_squared_error: 28.5244 - mean_absolute_error: 19.8144 - val_loss: 1599.8770 - val_root_mean_squared_error: 39.9985 - val_mean_absolute_error: 35.1700
# Epoch 488/500
# 34/37 [==========================>...] - ETA: 0s - loss: 995.2676 - root_mean_squared_error: 31.5479 - mean_absolute_error: 22.9940
# Epoch 488: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 984.5363 - root_mean_squared_error: 31.3773 - mean_absolute_error: 22.6983 - val_loss: 1789.7563 - val_root_mean_squared_error: 42.3055 - val_mean_absolute_error: 37.0053
# Epoch 489/500
# 34/37 [==========================>...] - ETA: 0s - loss: 815.0610 - root_mean_squared_error: 28.5493 - mean_absolute_error: 20.6181
# Epoch 489: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 856.5162 - root_mean_squared_error: 29.2663 - mean_absolute_error: 20.6293 - val_loss: 300.3781 - val_root_mean_squared_error: 17.3314 - val_mean_absolute_error: 12.0490
# Epoch 490/500
# 32/37 [========================>.....] - ETA: 0s - loss: 760.7131 - root_mean_squared_error: 27.5810 - mean_absolute_error: 18.9651
# Epoch 490: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 806.0026 - root_mean_squared_error: 28.3902 - mean_absolute_error: 19.2340 - val_loss: 386.6069 - val_root_mean_squared_error: 19.6623 - val_mean_absolute_error: 13.2456
# Epoch 491/500
# 33/37 [=========================>....] - ETA: 0s - loss: 746.4106 - root_mean_squared_error: 27.3205 - mean_absolute_error: 19.4805
# Epoch 491: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 755.6085 - root_mean_squared_error: 27.4883 - mean_absolute_error: 19.5118 - val_loss: 347.3548 - val_root_mean_squared_error: 18.6375 - val_mean_absolute_error: 13.0415
# Epoch 492/500
# 33/37 [=========================>....] - ETA: 0s - loss: 783.4502 - root_mean_squared_error: 27.9902 - mean_absolute_error: 19.3543
# Epoch 492: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 760.7828 - root_mean_squared_error: 27.5823 - mean_absolute_error: 19.1793 - val_loss: 1664.7444 - val_root_mean_squared_error: 40.8013 - val_mean_absolute_error: 36.5767
# Epoch 493/500
# 34/37 [==========================>...] - ETA: 0s - loss: 931.9083 - root_mean_squared_error: 30.5272 - mean_absolute_error: 20.5059
# Epoch 493: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 910.0659 - root_mean_squared_error: 30.1673 - mean_absolute_error: 20.3538 - val_loss: 416.4366 - val_root_mean_squared_error: 20.4068 - val_mean_absolute_error: 15.0130
# Epoch 494/500
# 33/37 [=========================>....] - ETA: 0s - loss: 834.7698 - root_mean_squared_error: 28.8924 - mean_absolute_error: 18.4915
# Epoch 494: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 12ms/step - loss: 825.3477 - root_mean_squared_error: 28.7289 - mean_absolute_error: 18.5585 - val_loss: 480.0534 - val_root_mean_squared_error: 21.9101 - val_mean_absolute_error: 16.5740
# Epoch 495/500
# 32/37 [========================>.....] - ETA: 0s - loss: 796.8379 - root_mean_squared_error: 28.2283 - mean_absolute_error: 19.2370
# Epoch 495: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 813.5556 - root_mean_squared_error: 28.5229 - mean_absolute_error: 19.6662 - val_loss: 768.1844 - val_root_mean_squared_error: 27.7161 - val_mean_absolute_error: 22.4849
# Epoch 496/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1145.2477 - root_mean_squared_error: 33.8415 - mean_absolute_error: 21.2352
# Epoch 496: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 1072.9552 - root_mean_squared_error: 32.7560 - mean_absolute_error: 20.8224 - val_loss: 890.0947 - val_root_mean_squared_error: 29.8345 - val_mean_absolute_error: 23.2283
# Epoch 497/500
# 32/37 [========================>.....] - ETA: 0s - loss: 960.3318 - root_mean_squared_error: 30.9892 - mean_absolute_error: 21.2984
# Epoch 497: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 935.8034 - root_mean_squared_error: 30.5909 - mean_absolute_error: 21.2503 - val_loss: 1003.2622 - val_root_mean_squared_error: 31.6743 - val_mean_absolute_error: 23.7791
# Epoch 498/500
# 37/37 [==============================] - ETA: 0s - loss: 883.0001 - root_mean_squared_error: 29.7153 - mean_absolute_error: 21.4076
# Epoch 498: val_loss did not improve from 209.10905
# 37/37 [==============================] - 1s 14ms/step - loss: 883.0001 - root_mean_squared_error: 29.7153 - mean_absolute_error: 21.4076 - val_loss: 588.5448 - val_root_mean_squared_error: 24.2599 - val_mean_absolute_error: 19.5586
# Epoch 499/500
# 37/37 [==============================] - ETA: 0s - loss: 856.3914 - root_mean_squared_error: 29.2642 - mean_absolute_error: 20.8470
# Epoch 499: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 13ms/step - loss: 856.3914 - root_mean_squared_error: 29.2642 - mean_absolute_error: 20.8470 - val_loss: 1650.4082 - val_root_mean_squared_error: 40.6252 - val_mean_absolute_error: 32.0498
# Epoch 500/500
# 36/37 [============================>.] - ETA: 0s - loss: 932.5786 - root_mean_squared_error: 30.5381 - mean_absolute_error: 23.2042
# Epoch 500: val_loss did not improve from 209.10905
# 37/37 [==============================] - 0s 10ms/step - loss: 929.9001 - root_mean_squared_error: 30.4943 - mean_absolute_error: 23.1788 - val_loss: 517.4971 - val_root_mean_squared_error: 22.7486 - val_mean_absolute_error: 17.0901
#   测试集 R: 0.9691, MAE: 33.0130, RMSE: 52.8328
#   ✓ 已保存模型: ./best_model_final_1/best_model_fold_9.h5
#   ✓ 已保存训练集预测: ./best_model_final_1/fold_predictions/fold_9_train_predictions.csv
#   ✓ 已保存验证集预测: ./best_model_final_1/fold_predictions/fold_9_test_predictions.csv
#
# ============================================================
# 最佳模型训练完成!
# ============================================================
#
# 总体结果:
#   R²:   0.9589 ± 0.0208
#   MAE:  35.5415 ± 6.5345
#   RMSE: 58.0372 ± 17.3760
#
# 结果保存位置:
#   - 模型文件: ./best_model_final_1/best_model_fold_*.h5
#   - 预测结果: ./best_model_final_1/fold_predictions/
#   - 汇总信息: ./best_model_final_1/summary.json
#   - 训练结果: ./best_model_final_1/training_results.csv
#
# ============================================================
# 所有任务完成!
# ============================================================

# %%
# 在所有导入之前
import os
os.environ['PYTHONHASHSEED'] = '42'
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

# 然后再导入其他库
import numpy as np
import tensorflow as tf
import os
import json
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# 设置中文字体
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei', 'DejaVu Sans']
matplotlib.rcParams['axes.unicode_minus'] = False

# 2. 在set_random_seeds函数中添加GPU配置
def set_random_seeds(seed):
    """设置所有可能的随机种子"""
    import random
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    os.environ['PYTHONHASHSEED'] = str(seed)
    
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()
    
    # 添加GPU内存配置
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(f"GPU配置警告: {e}")

# 设置随机种子
SEED = 56
set_random_seeds(SEED)

# 输入输出目录
output_dir = './best_model_final_2'


# ============================================================================
# 1. 数据加载函数
# ============================================================================
def load_embedding_data(data_dir='..//..//二维高熵合金数据'):
    """加载生成的嵌入矩阵数据"""
    print("="*60)
    print("加载数据...")
    print("="*60)
    
    embedding_path = os.path.join(data_dir, 'alloy_embedding_matrices.npy')
    X_all = np.load(embedding_path)
    
    hv_path = os.path.join(data_dir, 'HV_values.npy')
    Y_all = np.load(hv_path)
    
    info_path = os.path.join(data_dir, 'data_info.json')
    with open(info_path, 'r', encoding='utf-8') as f:
        data_info = json.load(f)
    
    print(f"✓ 数据加载完成")
    print(f"  样本数量: {len(X_all)}")
    print(f"  嵌入矩阵形状: {X_all.shape}")
    print(f"  HV值范围: [{Y_all.min():.2f}, {Y_all.max():.2f}]")
    
    X_all = np.expand_dims(X_all, axis=1)
    print(f"  调整后形状: {X_all.shape}")
    
    return X_all, Y_all, data_info

# ============================================================================
# 2. CNN模型构建函数
# ============================================================================
def build_cnn_model(input_shape, hyperparams):
    """根据超参数构建CNN模型"""
    model = Sequential()
    
    conv_filters = hyperparams['conv_filters']
    kernel_size = hyperparams['kernel_size']
    use_batch_norm = hyperparams['use_batch_norm']
    dropout_rate = hyperparams['dropout_rate']
    activation = hyperparams['activation']
    
    # 第一个卷积层
    model.add(Conv2D(
        filters=conv_filters[0],
        kernel_size=kernel_size,
        strides=1,
        padding='same',
        data_format='channels_first',
        activation=activation,
        input_shape=input_shape
    ))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='same', 
                           data_format='channels_first'))
    
    # 第二个卷积层
    model.add(Conv2D(conv_filters[1], kernel_size, strides=1, padding='same',
                     data_format='channels_first', activation=activation))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D((2, 2), 2, 'same', data_format='channels_first'))
    
    # 第三个卷积层
    model.add(Conv2D(conv_filters[2], kernel_size, strides=1, padding='same',
                     data_format='channels_first', activation=activation))
    if use_batch_norm:
        model.add(BatchNormalization(axis=1))
    model.add(MaxPooling2D((2, 2), 2, 'same', data_format='channels_first'))
    
    # 展平
    model.add(Flatten())
    
    # 全连接层
    dense_units = hyperparams['dense_units']
    for units in dense_units:
        model.add(Dense(units, activation=activation))
        if dropout_rate > 0:
            model.add(Dropout(dropout_rate))
    
    # 输出层
    model.add(Dense(1, activation='linear'))
    
    # 编译模型
    adam = Adam(learning_rate=hyperparams['learning_rate'])
    model.compile(
        optimizer=adam, 
        loss='mean_squared_error',
        metrics=[
            tf.keras.metrics.RootMeanSquaredError(),
            tf.keras.metrics.MeanAbsoluteError()
        ]
    )
    
    return model

# ============================================================================
# 3. 使用最佳参数进行完整训练
# ============================================================================
def train_with_best_params(X_all, Y_all, best_params, output_dir='./best_model_results'):
    """使用最佳参数进行完整的十折交叉验证训练"""
    os.makedirs(output_dir, exist_ok=True)
    
    print("\n" + "="*60)
    print("使用最佳参数进行完整训练")
    print("="*60)
    print(f"\n最佳参数:")
    for k, v in best_params.items():
        if k in ['conv_filters', 'dense_units']:
            print(f"  {k}: {list(v)}")
        else:
            print(f"  {k}: {v}")
    print("="*60)
    
    kf = KFold(n_splits=10, random_state=2*10+55, shuffle=True)
    
    all_rmse = []
    all_mae = []
    all_r2 = []
    
    results_file = os.path.join(output_dir, 'training_results.csv')
    with open(results_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['fold', 'loss_train', 'loss_test', 'r_train', 
                        'r_test', 'mae', 'rmse'])
    
    # 创建每折预测结果保存目录
    predictions_dir = os.path.join(output_dir, 'fold_predictions')
    os.makedirs(predictions_dir, exist_ok=True)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(X_all)):
        print(f"\n第 {fold + 1}/10 折")
        
        x_train, x_test = X_all[train_idx], X_all[test_idx]
        y_train, y_test = Y_all[train_idx], Y_all[test_idx]
        
        # 保存每折的模型
        model_path = os.path.join(output_dir, f'best_model_fold_{fold}.h5')
        
        callbacks = [
            # EarlyStopping(
            #     monitor='val_loss',
            #     patience=30,
            #     min_delta=0.0001,
            #     restore_best_weights=True,
            #     verbose=1,
            #     mode='min'
            # ),
            ModelCheckpoint(
                filepath=model_path,
                monitor='val_loss',
                save_best_only=True,
                mode='min',
                verbose=1
            )
        ]
        
        input_shape = x_train.shape[1:]
        model = build_cnn_model(input_shape, best_params)
        
        history = model.fit(
            x_train, y_train,
            epochs=500,
            batch_size=best_params['batch_size'],
            validation_data=(x_train, y_train),
            callbacks=callbacks,
            verbose=1
        )
        
        # 加载最佳模型
        model = load_model(model_path)
        
        loss_train, rmse_train, mae_train = model.evaluate(x_train, y_train, verbose=0)
        loss_test, rmse_test, mae_test = model.evaluate(x_test, y_test, verbose=0)
        
        # 预测
        pred_train = model.predict(x_train, batch_size=best_params['batch_size'], verbose=0).reshape(-1)
        pred_test = model.predict(x_test, batch_size=best_params['batch_size'], verbose=0).reshape(-1)
        
        r_train = np.corrcoef(pred_train, y_train)[0, 1]
        r_test = np.corrcoef(pred_test, y_test)[0, 1]
        
        mae = mean_absolute_error(y_test, pred_test)
        rmse = mean_squared_error(y_test, pred_test) ** 0.5
        
        all_rmse.append(rmse)
        all_mae.append(mae)
        all_r2.append(r_test)
        
        print(f"  测试集 R: {r_test:.4f}, MAE: {mae:.4f}, RMSE: {rmse:.4f}")
        
        with open(results_file, 'a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([fold, loss_train, loss_test, r_train, r_test, mae, rmse])
        
        # ========== 保存训练集预测结果 ==========
        train_predictions_file = os.path.join(predictions_dir, f'fold_{fold}_train_predictions.csv')
        with open(train_predictions_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['original_index', 'true_value', 'predicted_value', 'error'])
            for idx, true_val, pred_val in zip(train_idx, y_train, pred_train):
                writer.writerow([idx, true_val, pred_val, abs(true_val - pred_val)])
        
        # ========== 保存验证集(测试集)预测结果 ==========
        test_predictions_file = os.path.join(predictions_dir, f'fold_{fold}_test_predictions.csv')
        with open(test_predictions_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['original_index', 'true_value', 'predicted_value', 'error'])
            for idx, true_val, pred_val in zip(test_idx, y_test, pred_test):
                writer.writerow([idx, true_val, pred_val, abs(true_val - pred_val)])
        
        # ========== 保存训练集索引 ==========
        train_indices_file = os.path.join(predictions_dir, f'fold_{fold}_train_indices.npy')
        np.save(train_indices_file, train_idx)
        
        # ========== 保存验证集索引 ==========
        test_indices_file = os.path.join(predictions_dir, f'fold_{fold}_test_indices.npy')
        np.save(test_indices_file, test_idx)
        
        print(f"  ✓ 已保存模型: {model_path}")
        print(f"  ✓ 已保存训练集预测: {train_predictions_file}")
        print(f"  ✓ 已保存验证集预测: {test_predictions_file}")
        
        del model
        tf.keras.backend.clear_session()
    
    # 保存汇总结果
    serializable_params = best_params.copy()
    for key in ['conv_filters', 'dense_units']:
        if key in serializable_params:
            serializable_params[key] = list(serializable_params[key])
    
    summary = {
        'R2_mean': float(np.mean(all_r2)),
        'R2_std': float(np.std(all_r2)),
        'MAE_mean': float(np.mean(all_mae)),
        'MAE_std': float(np.std(all_mae)),
        'RMSE_mean': float(np.mean(all_rmse)),
        'RMSE_std': float(np.std(all_rmse)),
        'best_params': serializable_params
    }
    
    with open(os.path.join(output_dir, 'summary.json'), 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=2, ensure_ascii=False)
    
    print("\n" + "="*60)
    print("最佳模型训练完成!")
    print("="*60)
    print(f"\n总体结果:")
    print(f"  R²:   {np.mean(all_r2):.4f} ± {np.std(all_r2):.4f}")
    print(f"  MAE:  {np.mean(all_mae):.4f} ± {np.std(all_mae):.4f}")
    print(f"  RMSE: {np.mean(all_rmse):.4f} ± {np.std(all_rmse):.4f}")
    print(f"\n结果保存位置:")
    print(f"  - 模型文件: {output_dir}/best_model_fold_*.h5")
    print(f"  - 预测结果: {predictions_dir}/")
    print(f"  - 汇总信息: {output_dir}/summary.json")
    print(f"  - 训练结果: {output_dir}/training_results.csv")
    
    return summary

# ============================================================================
# 4. 主函数
# ============================================================================
def main():
    """使用最佳参数进行训练"""
    print("="*60)
    print("CNN最佳参数训练 - 高熵合金硬度预测")
    print("="*60)
    
    # 加载数据
    X_all, Y_all, data_info = load_embedding_data()
    
    # 最佳参数（来自调参结果）
    best_params = {
        'conv_filters': [12, 28, 56],
        'dense_units': [256, 128, 64, 16],
        'kernel_size': (5, 5),
        'learning_rate': 0.00010956749686519973,
        'batch_size': 12,
        'dropout_rate': 0.0097086836073558,
        'use_batch_norm': True,
        'activation': 'selu'
    }
    
    # 训练模型
    summary = train_with_best_params(X_all, Y_all, best_params, output_dir=output_dir)
    
    print("\n" + "="*60)
    print("所有任务完成!")
    print("="*60)

if __name__ == "__main__":
    main()
# Out:
# ============================================================
# CNN最佳参数训练 - 高熵合金硬度预测
# ============================================================
# ============================================================
# 加载数据...
# ============================================================
# ✓ 数据加载完成
#   样本数量: 483
#   嵌入矩阵形状: (483, 21, 768)
#   HV值范围: [109.00, 1084.00]
#   调整后形状: (483, 1, 21, 768)
#
# ============================================================
# 使用最佳参数进行完整训练
# ============================================================
#
# 最佳参数:
#   conv_filters: [12, 28, 56]
#   dense_units: [256, 128, 64, 16]
#   kernel_size: (5, 5)
#   learning_rate: 0.00010956749686519973
#   batch_size: 12
#   dropout_rate: 0.0097086836073558
#   use_batch_norm: True
#   activation: selu
# ============================================================
#
# 第 1/10 折
# Epoch 1/500
# 36/37 [============================>.] - ETA: 0s - loss: 116339.3672 - root_mean_squared_error: 341.0856 - mean_absolute_error: 280.3321
# Epoch 1: val_loss improved from inf to 211318.21875, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 19ms/step - loss: 115843.5078 - root_mean_squared_error: 340.3579 - mean_absolute_error: 279.4700 - val_loss: 211318.2188 - val_root_mean_squared_error: 459.6936 - val_mean_absolute_error: 407.5809
# Epoch 2/500
# 32/37 [========================>.....] - ETA: 0s - loss: 24683.2246 - root_mean_squared_error: 157.1089 - mean_absolute_error: 123.9994
# Epoch 2: val_loss improved from 211318.21875 to 165002.70312, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 23920.9863 - root_mean_squared_error: 154.6641 - mean_absolute_error: 122.2304 - val_loss: 165002.7031 - val_root_mean_squared_error: 406.2052 - val_mean_absolute_error: 350.5168
# Epoch 3/500
# 37/37 [==============================] - ETA: 0s - loss: 15498.1035 - root_mean_squared_error: 124.4914 - mean_absolute_error: 96.1704
# Epoch 3: val_loss improved from 165002.70312 to 127008.39062, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 15498.1035 - root_mean_squared_error: 124.4914 - mean_absolute_error: 96.1704 - val_loss: 127008.3906 - val_root_mean_squared_error: 356.3824 - val_mean_absolute_error: 297.0979
# Epoch 4/500
# 34/37 [==========================>...] - ETA: 0s - loss: 15203.0713 - root_mean_squared_error: 123.3007 - mean_absolute_error: 93.3313
# Epoch 4: val_loss improved from 127008.39062 to 83955.08594, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 15096.7549 - root_mean_squared_error: 122.8689 - mean_absolute_error: 93.4923 - val_loss: 83955.0859 - val_root_mean_squared_error: 289.7501 - val_mean_absolute_error: 237.3305
# Epoch 5/500
# 32/37 [========================>.....] - ETA: 0s - loss: 12482.6963 - root_mean_squared_error: 111.7260 - mean_absolute_error: 85.7454
# Epoch 5: val_loss improved from 83955.08594 to 62374.84375, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 12500.8916 - root_mean_squared_error: 111.8074 - mean_absolute_error: 85.5637 - val_loss: 62374.8438 - val_root_mean_squared_error: 249.7496 - val_mean_absolute_error: 204.8553
# Epoch 6/500
# 35/37 [===========================>..] - ETA: 0s - loss: 11387.8965 - root_mean_squared_error: 106.7141 - mean_absolute_error: 81.3547
# Epoch 6: val_loss improved from 62374.84375 to 54682.84766, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 11233.7305 - root_mean_squared_error: 105.9893 - mean_absolute_error: 81.0879 - val_loss: 54682.8477 - val_root_mean_squared_error: 233.8436 - val_mean_absolute_error: 191.7637
# Epoch 7/500
# 32/37 [========================>.....] - ETA: 0s - loss: 10781.4521 - root_mean_squared_error: 103.8338 - mean_absolute_error: 79.5036
# Epoch 7: val_loss improved from 54682.84766 to 37661.71094, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 10582.5205 - root_mean_squared_error: 102.8714 - mean_absolute_error: 79.2115 - val_loss: 37661.7109 - val_root_mean_squared_error: 194.0662 - val_mean_absolute_error: 161.6290
# Epoch 8/500
# 35/37 [===========================>..] - ETA: 0s - loss: 9239.8447 - root_mean_squared_error: 96.1241 - mean_absolute_error: 72.4848
# Epoch 8: val_loss improved from 37661.71094 to 28936.33789, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 19ms/step - loss: 9527.9141 - root_mean_squared_error: 97.6110 - mean_absolute_error: 73.8220 - val_loss: 28936.3379 - val_root_mean_squared_error: 170.1068 - val_mean_absolute_error: 142.2019
# Epoch 9/500
# 34/37 [==========================>...] - ETA: 0s - loss: 9799.1748 - root_mean_squared_error: 98.9908 - mean_absolute_error: 75.3373
# Epoch 9: val_loss improved from 28936.33789 to 26691.12305, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 9516.5322 - root_mean_squared_error: 97.5527 - mean_absolute_error: 74.3476 - val_loss: 26691.1230 - val_root_mean_squared_error: 163.3742 - val_mean_absolute_error: 136.5211
# Epoch 10/500
# 36/37 [============================>.] - ETA: 0s - loss: 8451.6084 - root_mean_squared_error: 91.9326 - mean_absolute_error: 69.8528
# Epoch 10: val_loss improved from 26691.12305 to 21416.57422, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 8433.5146 - root_mean_squared_error: 91.8342 - mean_absolute_error: 69.7598 - val_loss: 21416.5742 - val_root_mean_squared_error: 146.3440 - val_mean_absolute_error: 121.9550
# Epoch 11/500
# 34/37 [==========================>...] - ETA: 0s - loss: 7555.0337 - root_mean_squared_error: 86.9197 - mean_absolute_error: 66.1130
# Epoch 11: val_loss improved from 21416.57422 to 18335.68945, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 8083.4365 - root_mean_squared_error: 89.9079 - mean_absolute_error: 68.0469 - val_loss: 18335.6895 - val_root_mean_squared_error: 135.4093 - val_mean_absolute_error: 112.2827
# Epoch 12/500
# 37/37 [==============================] - ETA: 0s - loss: 7773.4946 - root_mean_squared_error: 88.1674 - mean_absolute_error: 67.6424
# Epoch 12: val_loss improved from 18335.68945 to 15811.04492, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 14ms/step - loss: 7773.4946 - root_mean_squared_error: 88.1674 - mean_absolute_error: 67.6424 - val_loss: 15811.0449 - val_root_mean_squared_error: 125.7420 - val_mean_absolute_error: 103.3432
# Epoch 13/500
# 34/37 [==========================>...] - ETA: 0s - loss: 7706.5386 - root_mean_squared_error: 87.7869 - mean_absolute_error: 68.1473
# Epoch 13: val_loss did not improve from 15811.04492
# 37/37 [==============================] - 0s 12ms/step - loss: 7638.9829 - root_mean_squared_error: 87.4013 - mean_absolute_error: 68.0224 - val_loss: 17541.0234 - val_root_mean_squared_error: 132.4425 - val_mean_absolute_error: 106.9108
# Epoch 14/500
# 33/37 [=========================>....] - ETA: 0s - loss: 7361.1206 - root_mean_squared_error: 85.7970 - mean_absolute_error: 65.5737
# Epoch 14: val_loss improved from 15811.04492 to 13284.08105, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 7147.5586 - root_mean_squared_error: 84.5432 - mean_absolute_error: 64.5531 - val_loss: 13284.0811 - val_root_mean_squared_error: 115.2566 - val_mean_absolute_error: 92.7232
# Epoch 15/500
# 31/37 [========================>.....] - ETA: 0s - loss: 6870.6621 - root_mean_squared_error: 82.8895 - mean_absolute_error: 62.7883
# Epoch 15: val_loss improved from 13284.08105 to 8483.35840, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 7050.7129 - root_mean_squared_error: 83.9685 - mean_absolute_error: 64.2409 - val_loss: 8483.3584 - val_root_mean_squared_error: 92.1051 - val_mean_absolute_error: 72.8909
# Epoch 16/500
# 36/37 [============================>.] - ETA: 0s - loss: 6381.4897 - root_mean_squared_error: 79.8842 - mean_absolute_error: 60.8315
# Epoch 16: val_loss improved from 8483.35840 to 8090.85840, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 6379.5776 - root_mean_squared_error: 79.8723 - mean_absolute_error: 60.8429 - val_loss: 8090.8584 - val_root_mean_squared_error: 89.9492 - val_mean_absolute_error: 72.1235
# Epoch 17/500
# 34/37 [==========================>...] - ETA: 0s - loss: 6321.9424 - root_mean_squared_error: 79.5106 - mean_absolute_error: 61.2834
# Epoch 17: val_loss improved from 8090.85840 to 4874.79395, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 6406.5225 - root_mean_squared_error: 80.0408 - mean_absolute_error: 61.8986 - val_loss: 4874.7939 - val_root_mean_squared_error: 69.8197 - val_mean_absolute_error: 54.7648
# Epoch 18/500
# 37/37 [==============================] - ETA: 0s - loss: 6388.0928 - root_mean_squared_error: 79.9255 - mean_absolute_error: 61.3341
# Epoch 18: val_loss did not improve from 4874.79395
# 37/37 [==============================] - 0s 12ms/step - loss: 6388.0928 - root_mean_squared_error: 79.9255 - mean_absolute_error: 61.3341 - val_loss: 18731.8281 - val_root_mean_squared_error: 136.8643 - val_mean_absolute_error: 120.9080
# Epoch 19/500
# 36/37 [============================>.] - ETA: 0s - loss: 6238.0068 - root_mean_squared_error: 78.9811 - mean_absolute_error: 57.9836
# Epoch 19: val_loss improved from 4874.79395 to 4510.35938, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 6239.3804 - root_mean_squared_error: 78.9897 - mean_absolute_error: 58.0851 - val_loss: 4510.3594 - val_root_mean_squared_error: 67.1592 - val_mean_absolute_error: 51.6540
# Epoch 20/500
# 33/37 [=========================>....] - ETA: 0s - loss: 6167.0601 - root_mean_squared_error: 78.5306 - mean_absolute_error: 58.2168
# Epoch 20: val_loss did not improve from 4510.35938
# 37/37 [==============================] - 0s 12ms/step - loss: 5967.2617 - root_mean_squared_error: 77.2481 - mean_absolute_error: 57.4587 - val_loss: 6197.5166 - val_root_mean_squared_error: 78.7243 - val_mean_absolute_error: 63.4145
# Epoch 21/500
# 33/37 [=========================>....] - ETA: 0s - loss: 5301.5146 - root_mean_squared_error: 72.8115 - mean_absolute_error: 55.8986
# Epoch 21: val_loss did not improve from 4510.35938
# 37/37 [==============================] - 0s 12ms/step - loss: 5139.3804 - root_mean_squared_error: 71.6895 - mean_absolute_error: 54.8654 - val_loss: 8898.9697 - val_root_mean_squared_error: 94.3344 - val_mean_absolute_error: 80.6252
# Epoch 22/500
# 33/37 [=========================>....] - ETA: 0s - loss: 5274.6333 - root_mean_squared_error: 72.6267 - mean_absolute_error: 56.0645
# Epoch 22: val_loss improved from 4510.35938 to 3416.02368, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 14ms/step - loss: 5702.0586 - root_mean_squared_error: 75.5120 - mean_absolute_error: 57.2153 - val_loss: 3416.0237 - val_root_mean_squared_error: 58.4468 - val_mean_absolute_error: 44.9008
# Epoch 23/500
# 34/37 [==========================>...] - ETA: 0s - loss: 4660.8843 - root_mean_squared_error: 68.2707 - mean_absolute_error: 50.2286
# Epoch 23: val_loss improved from 3416.02368 to 3009.10718, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 4868.5513 - root_mean_squared_error: 69.7750 - mean_absolute_error: 51.2098 - val_loss: 3009.1072 - val_root_mean_squared_error: 54.8553 - val_mean_absolute_error: 40.0466
# Epoch 24/500
# 34/37 [==========================>...] - ETA: 0s - loss: 5533.9326 - root_mean_squared_error: 74.3904 - mean_absolute_error: 56.9337
# Epoch 24: val_loss did not improve from 3009.10718
# 37/37 [==============================] - 0s 12ms/step - loss: 5535.9141 - root_mean_squared_error: 74.4037 - mean_absolute_error: 56.8539 - val_loss: 4322.3726 - val_root_mean_squared_error: 65.7448 - val_mean_absolute_error: 52.2149
# Epoch 25/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4159.9185 - root_mean_squared_error: 64.4974 - mean_absolute_error: 48.8887
# Epoch 25: val_loss did not improve from 3009.10718
# 37/37 [==============================] - 0s 13ms/step - loss: 4301.1514 - root_mean_squared_error: 65.5832 - mean_absolute_error: 49.2081 - val_loss: 7425.5566 - val_root_mean_squared_error: 86.1717 - val_mean_absolute_error: 71.4126
# Epoch 26/500
# 36/37 [============================>.] - ETA: 0s - loss: 4657.9971 - root_mean_squared_error: 68.2495 - mean_absolute_error: 50.0943
# Epoch 26: val_loss improved from 3009.10718 to 2683.17627, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 4642.7905 - root_mean_squared_error: 68.1380 - mean_absolute_error: 50.0302 - val_loss: 2683.1763 - val_root_mean_squared_error: 51.7994 - val_mean_absolute_error: 38.0768
# Epoch 27/500
# 35/37 [===========================>..] - ETA: 0s - loss: 4263.3022 - root_mean_squared_error: 65.2940 - mean_absolute_error: 49.6332
# Epoch 27: val_loss did not improve from 2683.17627
# 37/37 [==============================] - 0s 11ms/step - loss: 4169.2568 - root_mean_squared_error: 64.5698 - mean_absolute_error: 49.0310 - val_loss: 14114.8262 - val_root_mean_squared_error: 118.8058 - val_mean_absolute_error: 108.2292
# Epoch 28/500
# 36/37 [============================>.] - ETA: 0s - loss: 4287.7246 - root_mean_squared_error: 65.4807 - mean_absolute_error: 47.9721
# Epoch 28: val_loss did not improve from 2683.17627
# 37/37 [==============================] - 0s 13ms/step - loss: 4271.6157 - root_mean_squared_error: 65.3576 - mean_absolute_error: 47.8726 - val_loss: 4020.5171 - val_root_mean_squared_error: 63.4075 - val_mean_absolute_error: 48.7806
# Epoch 29/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3651.8860 - root_mean_squared_error: 60.4308 - mean_absolute_error: 45.2257
# Epoch 29: val_loss did not improve from 2683.17627
# 37/37 [==============================] - 0s 12ms/step - loss: 3776.8596 - root_mean_squared_error: 61.4562 - mean_absolute_error: 45.5784 - val_loss: 3334.0049 - val_root_mean_squared_error: 57.7408 - val_mean_absolute_error: 45.9692
# Epoch 30/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3553.0540 - root_mean_squared_error: 59.6075 - mean_absolute_error: 45.7629
# Epoch 30: val_loss did not improve from 2683.17627
# 37/37 [==============================] - 0s 12ms/step - loss: 3538.8530 - root_mean_squared_error: 59.4883 - mean_absolute_error: 45.6427 - val_loss: 4549.9473 - val_root_mean_squared_error: 67.4533 - val_mean_absolute_error: 54.4589
# Epoch 31/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3570.0669 - root_mean_squared_error: 59.7500 - mean_absolute_error: 45.0597
# Epoch 31: val_loss did not improve from 2683.17627
# 37/37 [==============================] - 0s 12ms/step - loss: 3802.8552 - root_mean_squared_error: 61.6673 - mean_absolute_error: 45.9699 - val_loss: 3870.5032 - val_root_mean_squared_error: 62.2134 - val_mean_absolute_error: 51.2300
# Epoch 32/500
# 33/37 [=========================>....] - ETA: 0s - loss: 5579.2305 - root_mean_squared_error: 74.6942 - mean_absolute_error: 58.7164
# Epoch 32: val_loss did not improve from 2683.17627
# 37/37 [==============================] - 0s 13ms/step - loss: 5643.5693 - root_mean_squared_error: 75.1237 - mean_absolute_error: 58.5352 - val_loss: 12332.7158 - val_root_mean_squared_error: 111.0528 - val_mean_absolute_error: 101.6953
# Epoch 33/500
# 33/37 [=========================>....] - ETA: 0s - loss: 4298.4077 - root_mean_squared_error: 65.5622 - mean_absolute_error: 48.6766
# Epoch 33: val_loss improved from 2683.17627 to 2218.49268, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 16ms/step - loss: 4195.9316 - root_mean_squared_error: 64.7760 - mean_absolute_error: 47.9229 - val_loss: 2218.4927 - val_root_mean_squared_error: 47.1009 - val_mean_absolute_error: 35.3509
# Epoch 34/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3697.7991 - root_mean_squared_error: 60.8095 - mean_absolute_error: 45.9897
# Epoch 34: val_loss did not improve from 2218.49268
# 37/37 [==============================] - 0s 12ms/step - loss: 3554.4309 - root_mean_squared_error: 59.6190 - mean_absolute_error: 44.7557 - val_loss: 2828.2046 - val_root_mean_squared_error: 53.1809 - val_mean_absolute_error: 39.6018
# Epoch 35/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3883.8306 - root_mean_squared_error: 62.3204 - mean_absolute_error: 45.4373
# Epoch 35: val_loss did not improve from 2218.49268
# 37/37 [==============================] - 0s 12ms/step - loss: 3835.0439 - root_mean_squared_error: 61.9277 - mean_absolute_error: 45.1322 - val_loss: 2264.2654 - val_root_mean_squared_error: 47.5843 - val_mean_absolute_error: 36.7821
# Epoch 36/500
# 32/37 [========================>.....] - ETA: 0s - loss: 3238.3831 - root_mean_squared_error: 56.9068 - mean_absolute_error: 42.2017
# Epoch 36: val_loss did not improve from 2218.49268
# 37/37 [==============================] - 0s 13ms/step - loss: 3345.1426 - root_mean_squared_error: 57.8372 - mean_absolute_error: 42.3111 - val_loss: 2390.8081 - val_root_mean_squared_error: 48.8959 - val_mean_absolute_error: 37.3508
# Epoch 37/500
# 33/37 [=========================>....] - ETA: 0s - loss: 3577.4609 - root_mean_squared_error: 59.8119 - mean_absolute_error: 45.4853
# Epoch 37: val_loss did not improve from 2218.49268
# 37/37 [==============================] - 0s 12ms/step - loss: 3701.7874 - root_mean_squared_error: 60.8423 - mean_absolute_error: 46.0847 - val_loss: 3208.7520 - val_root_mean_squared_error: 56.6458 - val_mean_absolute_error: 45.6971
# Epoch 38/500
# 33/37 [=========================>....] - ETA: 0s - loss: 3695.9355 - root_mean_squared_error: 60.7942 - mean_absolute_error: 44.3256
# Epoch 38: val_loss improved from 2218.49268 to 1854.71924, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 3980.0608 - root_mean_squared_error: 63.0877 - mean_absolute_error: 45.9168 - val_loss: 1854.7192 - val_root_mean_squared_error: 43.0665 - val_mean_absolute_error: 31.4395
# Epoch 39/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3320.2639 - root_mean_squared_error: 57.6217 - mean_absolute_error: 42.9180
# Epoch 39: val_loss did not improve from 1854.71924
# 37/37 [==============================] - 0s 12ms/step - loss: 3363.0686 - root_mean_squared_error: 57.9920 - mean_absolute_error: 43.3789 - val_loss: 2939.8928 - val_root_mean_squared_error: 54.2208 - val_mean_absolute_error: 44.2795
# Epoch 40/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3219.1619 - root_mean_squared_error: 56.7377 - mean_absolute_error: 42.5819
# Epoch 40: val_loss did not improve from 1854.71924
# 37/37 [==============================] - 0s 13ms/step - loss: 3178.5798 - root_mean_squared_error: 56.3789 - mean_absolute_error: 42.3840 - val_loss: 2326.8992 - val_root_mean_squared_error: 48.2379 - val_mean_absolute_error: 37.9069
# Epoch 41/500
# 33/37 [=========================>....] - ETA: 0s - loss: 3190.4626 - root_mean_squared_error: 56.4842 - mean_absolute_error: 40.7961
# Epoch 41: val_loss did not improve from 1854.71924
# 37/37 [==============================] - 0s 12ms/step - loss: 3163.0173 - root_mean_squared_error: 56.2407 - mean_absolute_error: 40.4583 - val_loss: 3460.6479 - val_root_mean_squared_error: 58.8273 - val_mean_absolute_error: 47.5567
# Epoch 42/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2931.4666 - root_mean_squared_error: 54.1430 - mean_absolute_error: 39.7562
# Epoch 42: val_loss did not improve from 1854.71924
# 37/37 [==============================] - 0s 11ms/step - loss: 2909.5549 - root_mean_squared_error: 53.9403 - mean_absolute_error: 39.6170 - val_loss: 3571.5957 - val_root_mean_squared_error: 59.7628 - val_mean_absolute_error: 48.2699
# Epoch 43/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2678.3660 - root_mean_squared_error: 51.7529 - mean_absolute_error: 38.6147
# Epoch 43: val_loss did not improve from 1854.71924
# 37/37 [==============================] - 0s 12ms/step - loss: 2642.1614 - root_mean_squared_error: 51.4020 - mean_absolute_error: 38.4772 - val_loss: 3688.9497 - val_root_mean_squared_error: 60.7367 - val_mean_absolute_error: 49.9948
# Epoch 44/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2973.9050 - root_mean_squared_error: 54.5335 - mean_absolute_error: 39.8321
# Epoch 44: val_loss improved from 1854.71924 to 1782.73022, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2989.2195 - root_mean_squared_error: 54.6738 - mean_absolute_error: 40.2312 - val_loss: 1782.7302 - val_root_mean_squared_error: 42.2224 - val_mean_absolute_error: 30.6945
# Epoch 45/500
# 34/37 [==========================>...] - ETA: 0s - loss: 3548.0437 - root_mean_squared_error: 59.5655 - mean_absolute_error: 44.1142
# Epoch 45: val_loss did not improve from 1782.73022
# 37/37 [==============================] - 0s 12ms/step - loss: 3490.0042 - root_mean_squared_error: 59.0763 - mean_absolute_error: 43.7864 - val_loss: 3630.4006 - val_root_mean_squared_error: 60.2528 - val_mean_absolute_error: 50.0687
# Epoch 46/500
# 35/37 [===========================>..] - ETA: 0s - loss: 3445.0422 - root_mean_squared_error: 58.6945 - mean_absolute_error: 40.9583
# Epoch 46: val_loss did not improve from 1782.73022
# 37/37 [==============================] - 0s 12ms/step - loss: 3383.9595 - root_mean_squared_error: 58.1718 - mean_absolute_error: 40.7057 - val_loss: 2176.3428 - val_root_mean_squared_error: 46.6513 - val_mean_absolute_error: 36.0938
# Epoch 47/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2290.6936 - root_mean_squared_error: 47.8612 - mean_absolute_error: 35.5030
# Epoch 47: val_loss improved from 1782.73022 to 1585.12512, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 2304.3264 - root_mean_squared_error: 48.0034 - mean_absolute_error: 35.7059 - val_loss: 1585.1251 - val_root_mean_squared_error: 39.8136 - val_mean_absolute_error: 30.5029
# Epoch 48/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2551.6450 - root_mean_squared_error: 50.5138 - mean_absolute_error: 37.1195
# Epoch 48: val_loss did not improve from 1585.12512
# 37/37 [==============================] - 0s 11ms/step - loss: 2507.1438 - root_mean_squared_error: 50.0714 - mean_absolute_error: 36.6662 - val_loss: 2191.0332 - val_root_mean_squared_error: 46.8085 - val_mean_absolute_error: 35.2985
# Epoch 49/500
# 29/37 [======================>.......] - ETA: 0s - loss: 3128.3625 - root_mean_squared_error: 55.9318 - mean_absolute_error: 40.8185
# Epoch 49: val_loss improved from 1585.12512 to 1326.84937, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 3160.3879 - root_mean_squared_error: 56.2173 - mean_absolute_error: 41.3587 - val_loss: 1326.8494 - val_root_mean_squared_error: 36.4259 - val_mean_absolute_error: 26.4381
# Epoch 50/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2575.0916 - root_mean_squared_error: 50.7454 - mean_absolute_error: 38.1464
# Epoch 50: val_loss did not improve from 1326.84937
# 37/37 [==============================] - 0s 10ms/step - loss: 2497.4360 - root_mean_squared_error: 49.9744 - mean_absolute_error: 37.1212 - val_loss: 3090.6357 - val_root_mean_squared_error: 55.5935 - val_mean_absolute_error: 45.3362
# Epoch 51/500
# 37/37 [==============================] - ETA: 0s - loss: 3013.4644 - root_mean_squared_error: 54.8950 - mean_absolute_error: 42.1767
# Epoch 51: val_loss did not improve from 1326.84937
# 37/37 [==============================] - 0s 12ms/step - loss: 3013.4644 - root_mean_squared_error: 54.8950 - mean_absolute_error: 42.1767 - val_loss: 1453.5510 - val_root_mean_squared_error: 38.1255 - val_mean_absolute_error: 28.5990
# Epoch 52/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2716.3179 - root_mean_squared_error: 52.1183 - mean_absolute_error: 37.1320
# Epoch 52: val_loss did not improve from 1326.84937
# 37/37 [==============================] - 0s 11ms/step - loss: 2715.9177 - root_mean_squared_error: 52.1145 - mean_absolute_error: 37.2814 - val_loss: 1871.6017 - val_root_mean_squared_error: 43.2620 - val_mean_absolute_error: 34.7428
# Epoch 53/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2375.0989 - root_mean_squared_error: 48.7350 - mean_absolute_error: 36.3034
# Epoch 53: val_loss did not improve from 1326.84937
# 37/37 [==============================] - 0s 10ms/step - loss: 2304.6868 - root_mean_squared_error: 48.0072 - mean_absolute_error: 35.7415 - val_loss: 1460.0022 - val_root_mean_squared_error: 38.2100 - val_mean_absolute_error: 27.7533
# Epoch 54/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2900.6025 - root_mean_squared_error: 53.8572 - mean_absolute_error: 37.6660
# Epoch 54: val_loss did not improve from 1326.84937
# 37/37 [==============================] - 0s 10ms/step - loss: 2704.6411 - root_mean_squared_error: 52.0062 - mean_absolute_error: 36.2143 - val_loss: 2197.2727 - val_root_mean_squared_error: 46.8751 - val_mean_absolute_error: 36.1464
# Epoch 55/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2303.9707 - root_mean_squared_error: 47.9997 - mean_absolute_error: 34.6146
# Epoch 55: val_loss improved from 1326.84937 to 1176.34082, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 2494.5854 - root_mean_squared_error: 49.9458 - mean_absolute_error: 35.5116 - val_loss: 1176.3408 - val_root_mean_squared_error: 34.2978 - val_mean_absolute_error: 24.5585
# Epoch 56/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2390.4980 - root_mean_squared_error: 48.8927 - mean_absolute_error: 36.7595
# Epoch 56: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 11ms/step - loss: 2359.7009 - root_mean_squared_error: 48.5768 - mean_absolute_error: 36.7194 - val_loss: 1992.2084 - val_root_mean_squared_error: 44.6342 - val_mean_absolute_error: 36.5715
# Epoch 57/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2669.7534 - root_mean_squared_error: 51.6697 - mean_absolute_error: 35.5568
# Epoch 57: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 11ms/step - loss: 2652.0867 - root_mean_squared_error: 51.4984 - mean_absolute_error: 35.4647 - val_loss: 1386.0968 - val_root_mean_squared_error: 37.2303 - val_mean_absolute_error: 26.9738
# Epoch 58/500
# 29/37 [======================>.......] - ETA: 0s - loss: 2642.8926 - root_mean_squared_error: 51.4091 - mean_absolute_error: 37.2327
# Epoch 58: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 10ms/step - loss: 2651.8096 - root_mean_squared_error: 51.4957 - mean_absolute_error: 37.2561 - val_loss: 1379.6388 - val_root_mean_squared_error: 37.1435 - val_mean_absolute_error: 27.3278
# Epoch 59/500
# 29/37 [======================>.......] - ETA: 0s - loss: 2813.0566 - root_mean_squared_error: 53.0383 - mean_absolute_error: 37.5918
# Epoch 59: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 11ms/step - loss: 2699.0276 - root_mean_squared_error: 51.9522 - mean_absolute_error: 37.1791 - val_loss: 1513.9927 - val_root_mean_squared_error: 38.9101 - val_mean_absolute_error: 29.3651
# Epoch 60/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2210.6101 - root_mean_squared_error: 47.0171 - mean_absolute_error: 36.1431
# Epoch 60: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 11ms/step - loss: 2421.1699 - root_mean_squared_error: 49.2054 - mean_absolute_error: 37.1738 - val_loss: 1461.2695 - val_root_mean_squared_error: 38.2266 - val_mean_absolute_error: 27.9578
# Epoch 61/500
# 32/37 [========================>.....] - ETA: 0s - loss: 3763.8567 - root_mean_squared_error: 61.3503 - mean_absolute_error: 44.6718
# Epoch 61: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 9ms/step - loss: 3592.5608 - root_mean_squared_error: 59.9380 - mean_absolute_error: 43.8747 - val_loss: 2351.8181 - val_root_mean_squared_error: 48.4955 - val_mean_absolute_error: 38.7511
# Epoch 62/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2133.2681 - root_mean_squared_error: 46.1873 - mean_absolute_error: 34.0545
# Epoch 62: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 9ms/step - loss: 2229.2937 - root_mean_squared_error: 47.2154 - mean_absolute_error: 34.8204 - val_loss: 6662.6558 - val_root_mean_squared_error: 81.6251 - val_mean_absolute_error: 71.2432
# Epoch 63/500
# 36/37 [============================>.] - ETA: 0s - loss: 2537.7874 - root_mean_squared_error: 50.3765 - mean_absolute_error: 36.6831
# Epoch 63: val_loss did not improve from 1176.34082
# 37/37 [==============================] - 0s 10ms/step - loss: 2532.8921 - root_mean_squared_error: 50.3278 - mean_absolute_error: 36.6619 - val_loss: 1607.3391 - val_root_mean_squared_error: 40.0916 - val_mean_absolute_error: 31.9468
# Epoch 64/500
# 36/37 [============================>.] - ETA: 0s - loss: 2722.3818 - root_mean_squared_error: 52.1764 - mean_absolute_error: 36.7005
# Epoch 64: val_loss improved from 1176.34082 to 1174.42834, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 14ms/step - loss: 2711.3538 - root_mean_squared_error: 52.0707 - mean_absolute_error: 36.6132 - val_loss: 1174.4283 - val_root_mean_squared_error: 34.2699 - val_mean_absolute_error: 24.1467
# Epoch 65/500
# 30/37 [=======================>......] - ETA: 0s - loss: 2657.5286 - root_mean_squared_error: 51.5512 - mean_absolute_error: 35.6067
# Epoch 65: val_loss did not improve from 1174.42834
# 37/37 [==============================] - 0s 11ms/step - loss: 2568.3403 - root_mean_squared_error: 50.6788 - mean_absolute_error: 35.3997 - val_loss: 1294.6770 - val_root_mean_squared_error: 35.9816 - val_mean_absolute_error: 26.5581
# Epoch 66/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2920.1011 - root_mean_squared_error: 54.0380 - mean_absolute_error: 38.1064
# Epoch 66: val_loss did not improve from 1174.42834
# 37/37 [==============================] - 0s 13ms/step - loss: 2894.7324 - root_mean_squared_error: 53.8027 - mean_absolute_error: 38.1806 - val_loss: 1204.3259 - val_root_mean_squared_error: 34.7034 - val_mean_absolute_error: 24.8596
# Epoch 67/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2267.1047 - root_mean_squared_error: 47.6141 - mean_absolute_error: 32.7175
# Epoch 67: val_loss improved from 1174.42834 to 1017.89587, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2319.7832 - root_mean_squared_error: 48.1641 - mean_absolute_error: 33.2539 - val_loss: 1017.8959 - val_root_mean_squared_error: 31.9045 - val_mean_absolute_error: 23.1658
# Epoch 68/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2008.6498 - root_mean_squared_error: 44.8180 - mean_absolute_error: 32.0652
# Epoch 68: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 2041.9038 - root_mean_squared_error: 45.1874 - mean_absolute_error: 32.0146 - val_loss: 5080.1646 - val_root_mean_squared_error: 71.2753 - val_mean_absolute_error: 65.4429
# Epoch 69/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2395.7571 - root_mean_squared_error: 48.9465 - mean_absolute_error: 36.4715
# Epoch 69: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 2463.1423 - root_mean_squared_error: 49.6301 - mean_absolute_error: 36.7968 - val_loss: 1088.8888 - val_root_mean_squared_error: 32.9983 - val_mean_absolute_error: 24.3692
# Epoch 70/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2078.5481 - root_mean_squared_error: 45.5911 - mean_absolute_error: 33.9736
# Epoch 70: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 2241.8611 - root_mean_squared_error: 47.3483 - mean_absolute_error: 34.8960 - val_loss: 2643.2693 - val_root_mean_squared_error: 51.4127 - val_mean_absolute_error: 42.2471
# Epoch 71/500
# 31/37 [========================>.....] - ETA: 0s - loss: 2749.6416 - root_mean_squared_error: 52.4370 - mean_absolute_error: 38.5086
# Epoch 71: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 13ms/step - loss: 2773.2449 - root_mean_squared_error: 52.6616 - mean_absolute_error: 38.1893 - val_loss: 1521.5001 - val_root_mean_squared_error: 39.0064 - val_mean_absolute_error: 30.2498
# Epoch 72/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2334.6262 - root_mean_squared_error: 48.3180 - mean_absolute_error: 34.8089
# Epoch 72: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 2409.6694 - root_mean_squared_error: 49.0884 - mean_absolute_error: 35.3222 - val_loss: 2369.4678 - val_root_mean_squared_error: 48.6772 - val_mean_absolute_error: 40.5968
# Epoch 73/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1833.0386 - root_mean_squared_error: 42.8140 - mean_absolute_error: 31.7397
# Epoch 73: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 1760.1215 - root_mean_squared_error: 41.9538 - mean_absolute_error: 31.0640 - val_loss: 1142.7650 - val_root_mean_squared_error: 33.8048 - val_mean_absolute_error: 25.0452
# Epoch 74/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2214.6541 - root_mean_squared_error: 47.0601 - mean_absolute_error: 35.4078
# Epoch 74: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 11ms/step - loss: 2223.2849 - root_mean_squared_error: 47.1517 - mean_absolute_error: 35.0798 - val_loss: 1228.5465 - val_root_mean_squared_error: 35.0506 - val_mean_absolute_error: 25.0468
# Epoch 75/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2303.6650 - root_mean_squared_error: 47.9965 - mean_absolute_error: 34.0860
# Epoch 75: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 10ms/step - loss: 2401.5684 - root_mean_squared_error: 49.0058 - mean_absolute_error: 34.1984 - val_loss: 1379.3932 - val_root_mean_squared_error: 37.1402 - val_mean_absolute_error: 28.7454
# Epoch 76/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1671.8960 - root_mean_squared_error: 40.8888 - mean_absolute_error: 29.4558
# Epoch 76: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 1761.9073 - root_mean_squared_error: 41.9751 - mean_absolute_error: 30.3100 - val_loss: 1096.1689 - val_root_mean_squared_error: 33.1084 - val_mean_absolute_error: 25.9410
# Epoch 77/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2718.0696 - root_mean_squared_error: 52.1351 - mean_absolute_error: 37.9165
# Epoch 77: val_loss did not improve from 1017.89587
# 37/37 [==============================] - 0s 12ms/step - loss: 2618.9971 - root_mean_squared_error: 51.1761 - mean_absolute_error: 37.2690 - val_loss: 1197.1115 - val_root_mean_squared_error: 34.5993 - val_mean_absolute_error: 27.2708
# Epoch 78/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2116.0334 - root_mean_squared_error: 46.0004 - mean_absolute_error: 31.0106
# Epoch 78: val_loss improved from 1017.89587 to 1001.24048, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 0s 13ms/step - loss: 2053.0725 - root_mean_squared_error: 45.3108 - mean_absolute_error: 30.6772 - val_loss: 1001.2405 - val_root_mean_squared_error: 31.6424 - val_mean_absolute_error: 22.6983
# Epoch 79/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2394.1978 - root_mean_squared_error: 48.9305 - mean_absolute_error: 33.6082
# Epoch 79: val_loss did not improve from 1001.24048
# 37/37 [==============================] - 0s 11ms/step - loss: 2379.2639 - root_mean_squared_error: 48.7777 - mean_absolute_error: 33.7160 - val_loss: 1672.4014 - val_root_mean_squared_error: 40.8950 - val_mean_absolute_error: 33.0692
# Epoch 80/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2076.4639 - root_mean_squared_error: 45.5682 - mean_absolute_error: 33.4492
# Epoch 80: val_loss improved from 1001.24048 to 914.12646, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2104.0229 - root_mean_squared_error: 45.8696 - mean_absolute_error: 33.4691 - val_loss: 914.1265 - val_root_mean_squared_error: 30.2345 - val_mean_absolute_error: 21.8253
# Epoch 81/500
# 36/37 [============================>.] - ETA: 0s - loss: 1695.8533 - root_mean_squared_error: 41.1807 - mean_absolute_error: 29.4720
# Epoch 81: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 11ms/step - loss: 1692.7850 - root_mean_squared_error: 41.1435 - mean_absolute_error: 29.4587 - val_loss: 4667.4414 - val_root_mean_squared_error: 68.3187 - val_mean_absolute_error: 60.4818
# Epoch 82/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2495.6775 - root_mean_squared_error: 49.9568 - mean_absolute_error: 36.9171
# Epoch 82: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 11ms/step - loss: 2470.5198 - root_mean_squared_error: 49.7043 - mean_absolute_error: 36.4973 - val_loss: 2066.1528 - val_root_mean_squared_error: 45.4550 - val_mean_absolute_error: 35.7008
# Epoch 83/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2294.7656 - root_mean_squared_error: 47.9037 - mean_absolute_error: 34.9332
# Epoch 83: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 11ms/step - loss: 2257.4653 - root_mean_squared_error: 47.5128 - mean_absolute_error: 34.5597 - val_loss: 5321.3687 - val_root_mean_squared_error: 72.9477 - val_mean_absolute_error: 66.1461
# Epoch 84/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1999.5378 - root_mean_squared_error: 44.7162 - mean_absolute_error: 30.0055
# Epoch 84: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 12ms/step - loss: 1969.6857 - root_mean_squared_error: 44.3811 - mean_absolute_error: 29.7341 - val_loss: 963.6024 - val_root_mean_squared_error: 31.0419 - val_mean_absolute_error: 22.6465
# Epoch 85/500
# 36/37 [============================>.] - ETA: 0s - loss: 1843.1062 - root_mean_squared_error: 42.9314 - mean_absolute_error: 30.6942
# Epoch 85: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 12ms/step - loss: 1836.3235 - root_mean_squared_error: 42.8523 - mean_absolute_error: 30.6220 - val_loss: 1186.6488 - val_root_mean_squared_error: 34.4478 - val_mean_absolute_error: 27.3852
# Epoch 86/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2162.6592 - root_mean_squared_error: 46.5044 - mean_absolute_error: 34.0733
# Epoch 86: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 11ms/step - loss: 2111.7722 - root_mean_squared_error: 45.9540 - mean_absolute_error: 33.6828 - val_loss: 7315.9702 - val_root_mean_squared_error: 85.5334 - val_mean_absolute_error: 77.8185
# Epoch 87/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1801.1709 - root_mean_squared_error: 42.4402 - mean_absolute_error: 29.3747
# Epoch 87: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 12ms/step - loss: 2001.0176 - root_mean_squared_error: 44.7327 - mean_absolute_error: 30.5753 - val_loss: 4606.4990 - val_root_mean_squared_error: 67.8712 - val_mean_absolute_error: 61.6063
# Epoch 88/500
# 30/37 [=======================>......] - ETA: 0s - loss: 2088.8604 - root_mean_squared_error: 45.7041 - mean_absolute_error: 33.5548
# Epoch 88: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 10ms/step - loss: 2031.2930 - root_mean_squared_error: 45.0699 - mean_absolute_error: 33.1566 - val_loss: 927.8753 - val_root_mean_squared_error: 30.4610 - val_mean_absolute_error: 22.9505
# Epoch 89/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2288.2930 - root_mean_squared_error: 47.8361 - mean_absolute_error: 35.2137
# Epoch 89: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 12ms/step - loss: 2219.1985 - root_mean_squared_error: 47.1084 - mean_absolute_error: 34.6388 - val_loss: 1340.5000 - val_root_mean_squared_error: 36.6128 - val_mean_absolute_error: 28.3711
# Epoch 90/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2015.0594 - root_mean_squared_error: 44.8894 - mean_absolute_error: 31.7218
# Epoch 90: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 12ms/step - loss: 1910.2678 - root_mean_squared_error: 43.7066 - mean_absolute_error: 30.9189 - val_loss: 1553.2452 - val_root_mean_squared_error: 39.4112 - val_mean_absolute_error: 31.9380
# Epoch 91/500
# 35/37 [===========================>..] - ETA: 0s - loss: 1868.7869 - root_mean_squared_error: 43.2295 - mean_absolute_error: 30.9026
# Epoch 91: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 11ms/step - loss: 1866.0007 - root_mean_squared_error: 43.1972 - mean_absolute_error: 30.9325 - val_loss: 1374.4216 - val_root_mean_squared_error: 37.0732 - val_mean_absolute_error: 28.6459
# Epoch 92/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1757.5499 - root_mean_squared_error: 41.9231 - mean_absolute_error: 30.5016
# Epoch 92: val_loss did not improve from 914.12646
# 37/37 [==============================] - 0s 12ms/step - loss: 1776.3945 - root_mean_squared_error: 42.1473 - mean_absolute_error: 30.2817 - val_loss: 1278.7749 - val_root_mean_squared_error: 35.7600 - val_mean_absolute_error: 27.7524
# Epoch 93/500
# 36/37 [============================>.] - ETA: 0s - loss: 2115.8450 - root_mean_squared_error: 45.9983 - mean_absolute_error: 33.5748
# Epoch 93: val_loss improved from 914.12646 to 824.52765, saving model to ./best_model_final_2/best_model_fold_0.h5
# 37/37 [==============================] - 1s 15ms/step - loss: 2110.0542 - root_mean_squared_error: 45.9353 - mean_absolute_error: 33.5499 - val_loss: 824.5276 - val_root_mean_squared_error: 28.7146 - val_mean_absolute_error: 20.7947
# Epoch 94/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2276.7014 - root_mean_squared_error: 47.7148 - mean_absolute_error: 33.4129
# Epoch 94: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 12ms/step - loss: 2319.6428 - root_mean_squared_error: 48.1627 - mean_absolute_error: 33.5620 - val_loss: 2579.2490 - val_root_mean_squared_error: 50.7863 - val_mean_absolute_error: 43.0310
# Epoch 95/500
# 36/37 [============================>.] - ETA: 0s - loss: 2117.2498 - root_mean_squared_error: 46.0136 - mean_absolute_error: 32.5182
# Epoch 95: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 11ms/step - loss: 2111.3650 - root_mean_squared_error: 45.9496 - mean_absolute_error: 32.4921 - val_loss: 883.0770 - val_root_mean_squared_error: 29.7166 - val_mean_absolute_error: 21.6386
# Epoch 96/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1465.9641 - root_mean_squared_error: 38.2879 - mean_absolute_error: 28.1019
# Epoch 96: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 10ms/step - loss: 1625.0308 - root_mean_squared_error: 40.3117 - mean_absolute_error: 27.9543 - val_loss: 1755.7283 - val_root_mean_squared_error: 41.9014 - val_mean_absolute_error: 34.3690
# Epoch 97/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2377.8979 - root_mean_squared_error: 48.7637 - mean_absolute_error: 35.3030
# Epoch 97: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 12ms/step - loss: 2275.3835 - root_mean_squared_error: 47.7010 - mean_absolute_error: 34.7066 - val_loss: 2200.7085 - val_root_mean_squared_error: 46.9117 - val_mean_absolute_error: 37.3498
# Epoch 98/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1720.7068 - root_mean_squared_error: 41.4814 - mean_absolute_error: 30.6751
# Epoch 98: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 12ms/step - loss: 1721.0059 - root_mean_squared_error: 41.4850 - mean_absolute_error: 30.6955 - val_loss: 926.4283 - val_root_mean_squared_error: 30.4373 - val_mean_absolute_error: 21.7306
# Epoch 99/500
# 36/37 [============================>.] - ETA: 0s - loss: 2161.6045 - root_mean_squared_error: 46.4931 - mean_absolute_error: 32.1421
# Epoch 99: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 13ms/step - loss: 2160.8674 - root_mean_squared_error: 46.4851 - mean_absolute_error: 32.1997 - val_loss: 920.8838 - val_root_mean_squared_error: 30.3461 - val_mean_absolute_error: 21.9659
# Epoch 100/500
# 37/37 [==============================] - ETA: 0s - loss: 1910.1260 - root_mean_squared_error: 43.7050 - mean_absolute_error: 29.7121
# Epoch 100: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 13ms/step - loss: 1910.1260 - root_mean_squared_error: 43.7050 - mean_absolute_error: 29.7121 - val_loss: 843.3861 - val_root_mean_squared_error: 29.0411 - val_mean_absolute_error: 20.6717
# Epoch 101/500
# 35/37 [===========================>..] - ETA: 0s - loss: 2104.8486 - root_mean_squared_error: 45.8786 - mean_absolute_error: 31.8499
# Epoch 101: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 10ms/step - loss: 2126.1099 - root_mean_squared_error: 46.1098 - mean_absolute_error: 32.0830 - val_loss: 942.2139 - val_root_mean_squared_error: 30.6955 - val_mean_absolute_error: 23.0765
# Epoch 102/500
# 30/37 [=======================>......] - ETA: 0s - loss: 1851.6727 - root_mean_squared_error: 43.0311 - mean_absolute_error: 29.9680
# Epoch 102: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 10ms/step - loss: 1784.6628 - root_mean_squared_error: 42.2453 - mean_absolute_error: 29.6399 - val_loss: 899.3297 - val_root_mean_squared_error: 29.9888 - val_mean_absolute_error: 22.1585
# Epoch 103/500
# 34/37 [==========================>...] - ETA: 0s - loss: 2322.8708 - root_mean_squared_error: 48.1962 - mean_absolute_error: 33.7754
# Epoch 103: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 12ms/step - loss: 2365.1069 - root_mean_squared_error: 48.6324 - mean_absolute_error: 34.0815 - val_loss: 2680.2275 - val_root_mean_squared_error: 51.7709 - val_mean_absolute_error: 45.0834
# Epoch 104/500
# 33/37 [=========================>....] - ETA: 0s - loss: 2374.0217 - root_mean_squared_error: 48.7239 - mean_absolute_error: 34.4369
# Epoch 104: val_loss did not improve from 824.52765
# 37/37 [==============================] - 0s 12ms/step - loss: 2372.2527 - root_mean_squared_error: 48.7058 - mean_absolute_error: 34.6517 - val_loss: 6396.5439 - val_root_mean_squared_error: 79.9784 - val_mean_absolute_error: 70.2411
# Epoch 105/500
# 32/37 [========================>.....] - ETA: 0s - loss: 2041.4210 - root_mean_squared_error: 45.1821 - mean_absolute_error: 31.6114
# ...
# Epoch 466/500
# 36/37 [============================>.] - ETA: 0s - loss: 1045.6182 - root_mean_squared_error: 32.3360 - mean_absolute_error: 22.3273
# Epoch 466: val_loss did not improve from 236.02098
# 37/37 [==============================] - 1s 14ms/step - loss: 1040.5166 - root_mean_squared_error: 32.2570 - mean_absolute_error: 22.2686 - val_loss: 2769.4746 - val_root_mean_squared_error: 52.6258 - val_mean_absolute_error: 47.0613
# Epoch 467/500
# 30/37 [=======================>......] - ETA: 0s - loss: 778.1536 - root_mean_squared_error: 27.8954 - mean_absolute_error: 20.2488
# Epoch 467: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 899.0138 - root_mean_squared_error: 29.9836 - mean_absolute_error: 21.2156 - val_loss: 518.7111 - val_root_mean_squared_error: 22.7752 - val_mean_absolute_error: 17.9742
# Epoch 468/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1082.5367 - root_mean_squared_error: 32.9019 - mean_absolute_error: 22.5538
# Epoch 468: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 14ms/step - loss: 1084.1799 - root_mean_squared_error: 32.9269 - mean_absolute_error: 22.6118 - val_loss: 461.1364 - val_root_mean_squared_error: 21.4741 - val_mean_absolute_error: 15.1285
# Epoch 469/500
# 37/37 [==============================] - ETA: 0s - loss: 1013.4018 - root_mean_squared_error: 31.8340 - mean_absolute_error: 21.9386
# Epoch 469: val_loss did not improve from 236.02098
# 37/37 [==============================] - 1s 14ms/step - loss: 1013.4018 - root_mean_squared_error: 31.8340 - mean_absolute_error: 21.9386 - val_loss: 763.5591 - val_root_mean_squared_error: 27.6326 - val_mean_absolute_error: 23.2457
# Epoch 470/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1042.1450 - root_mean_squared_error: 32.2823 - mean_absolute_error: 22.3329
# Epoch 470: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 13ms/step - loss: 994.1075 - root_mean_squared_error: 31.5295 - mean_absolute_error: 21.7539 - val_loss: 826.0784 - val_root_mean_squared_error: 28.7416 - val_mean_absolute_error: 22.6689
# Epoch 471/500
# 31/37 [========================>.....] - ETA: 0s - loss: 876.6138 - root_mean_squared_error: 29.6077 - mean_absolute_error: 21.2552
# Epoch 471: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 873.8702 - root_mean_squared_error: 29.5613 - mean_absolute_error: 20.7419 - val_loss: 285.2073 - val_root_mean_squared_error: 16.8881 - val_mean_absolute_error: 10.9252
# Epoch 472/500
# 36/37 [============================>.] - ETA: 0s - loss: 1012.3176 - root_mean_squared_error: 31.8169 - mean_absolute_error: 21.3491
# Epoch 472: val_loss did not improve from 236.02098
# 37/37 [==============================] - 1s 14ms/step - loss: 1021.5502 - root_mean_squared_error: 31.9617 - mean_absolute_error: 21.4597 - val_loss: 507.3374 - val_root_mean_squared_error: 22.5242 - val_mean_absolute_error: 17.7345
# Epoch 473/500
# 36/37 [============================>.] - ETA: 0s - loss: 1044.1484 - root_mean_squared_error: 32.3133 - mean_absolute_error: 22.7726
# Epoch 473: val_loss did not improve from 236.02098
# 37/37 [==============================] - 1s 14ms/step - loss: 1048.6196 - root_mean_squared_error: 32.3824 - mean_absolute_error: 22.8835 - val_loss: 420.7930 - val_root_mean_squared_error: 20.5132 - val_mean_absolute_error: 15.3017
# Epoch 474/500
# 33/37 [=========================>....] - ETA: 0s - loss: 833.6029 - root_mean_squared_error: 28.8722 - mean_absolute_error: 19.8291
# Epoch 474: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 836.1998 - root_mean_squared_error: 28.9171 - mean_absolute_error: 19.9609 - val_loss: 368.6697 - val_root_mean_squared_error: 19.2008 - val_mean_absolute_error: 13.5982
# Epoch 475/500
# 37/37 [==============================] - ETA: 0s - loss: 1137.1156 - root_mean_squared_error: 33.7211 - mean_absolute_error: 21.9660
# Epoch 475: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 1137.1156 - root_mean_squared_error: 33.7211 - mean_absolute_error: 21.9660 - val_loss: 861.3064 - val_root_mean_squared_error: 29.3480 - val_mean_absolute_error: 24.5310
# Epoch 476/500
# 35/37 [===========================>..] - ETA: 0s - loss: 888.8632 - root_mean_squared_error: 29.8138 - mean_absolute_error: 20.3008
# Epoch 476: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 889.8084 - root_mean_squared_error: 29.8297 - mean_absolute_error: 20.4354 - val_loss: 755.4103 - val_root_mean_squared_error: 27.4847 - val_mean_absolute_error: 21.5948
# Epoch 477/500
# 35/37 [===========================>..] - ETA: 0s - loss: 787.2802 - root_mean_squared_error: 28.0585 - mean_absolute_error: 18.6297
# Epoch 477: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 778.5022 - root_mean_squared_error: 27.9017 - mean_absolute_error: 18.6161 - val_loss: 524.5373 - val_root_mean_squared_error: 22.9028 - val_mean_absolute_error: 16.1365
# Epoch 478/500
# 28/37 [=====================>........] - ETA: 0s - loss: 784.8804 - root_mean_squared_error: 28.0157 - mean_absolute_error: 20.3791
# Epoch 478: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 839.4091 - root_mean_squared_error: 28.9726 - mean_absolute_error: 20.4007 - val_loss: 691.0985 - val_root_mean_squared_error: 26.2888 - val_mean_absolute_error: 20.6484
# Epoch 479/500
# 33/37 [=========================>....] - ETA: 0s - loss: 978.4562 - root_mean_squared_error: 31.2803 - mean_absolute_error: 21.3810
# Epoch 479: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 1007.1001 - root_mean_squared_error: 31.7348 - mean_absolute_error: 21.7565 - val_loss: 720.9974 - val_root_mean_squared_error: 26.8514 - val_mean_absolute_error: 21.1422
# Epoch 480/500
# 37/37 [==============================] - ETA: 0s - loss: 979.7133 - root_mean_squared_error: 31.3004 - mean_absolute_error: 22.5924
# Epoch 480: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 979.7133 - root_mean_squared_error: 31.3004 - mean_absolute_error: 22.5924 - val_loss: 360.0337 - val_root_mean_squared_error: 18.9746 - val_mean_absolute_error: 12.7665
# Epoch 481/500
# 34/37 [==========================>...] - ETA: 0s - loss: 979.1016 - root_mean_squared_error: 31.2906 - mean_absolute_error: 21.9484
# Epoch 481: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 1024.1670 - root_mean_squared_error: 32.0026 - mean_absolute_error: 22.3077 - val_loss: 337.2003 - val_root_mean_squared_error: 18.3630 - val_mean_absolute_error: 13.4148
# Epoch 482/500
# 31/37 [========================>.....] - ETA: 0s - loss: 989.8799 - root_mean_squared_error: 31.4624 - mean_absolute_error: 22.3554
# Epoch 482: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 963.9829 - root_mean_squared_error: 31.0481 - mean_absolute_error: 22.1630 - val_loss: 2319.7100 - val_root_mean_squared_error: 48.1634 - val_mean_absolute_error: 41.5032
# Epoch 483/500
# 30/37 [=======================>......] - ETA: 0s - loss: 887.4141 - root_mean_squared_error: 29.7895 - mean_absolute_error: 20.3769
# Epoch 483: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 850.9191 - root_mean_squared_error: 29.1705 - mean_absolute_error: 19.9760 - val_loss: 655.5682 - val_root_mean_squared_error: 25.6041 - val_mean_absolute_error: 21.4394
# Epoch 484/500
# 31/37 [========================>.....] - ETA: 0s - loss: 826.6168 - root_mean_squared_error: 28.7509 - mean_absolute_error: 21.2172
# Epoch 484: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 872.0734 - root_mean_squared_error: 29.5309 - mean_absolute_error: 21.3729 - val_loss: 629.7753 - val_root_mean_squared_error: 25.0953 - val_mean_absolute_error: 21.1565
# Epoch 485/500
# 34/37 [==========================>...] - ETA: 0s - loss: 871.1635 - root_mean_squared_error: 29.5155 - mean_absolute_error: 21.3277
# Epoch 485: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 888.4038 - root_mean_squared_error: 29.8061 - mean_absolute_error: 21.6754 - val_loss: 557.1693 - val_root_mean_squared_error: 23.6044 - val_mean_absolute_error: 18.5871
# Epoch 486/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1087.7050 - root_mean_squared_error: 32.9804 - mean_absolute_error: 22.2988
# Epoch 486: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 1114.9377 - root_mean_squared_error: 33.3907 - mean_absolute_error: 22.3286 - val_loss: 1808.7460 - val_root_mean_squared_error: 42.5294 - val_mean_absolute_error: 36.0648
# Epoch 487/500
# 36/37 [============================>.] - ETA: 0s - loss: 936.5530 - root_mean_squared_error: 30.6032 - mean_absolute_error: 21.1567
# Epoch 487: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 935.9598 - root_mean_squared_error: 30.5935 - mean_absolute_error: 21.1816 - val_loss: 296.5888 - val_root_mean_squared_error: 17.2218 - val_mean_absolute_error: 11.4745
# Epoch 488/500
# 30/37 [=======================>......] - ETA: 0s - loss: 1017.8365 - root_mean_squared_error: 31.9035 - mean_absolute_error: 22.0020
# Epoch 488: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 1025.5951 - root_mean_squared_error: 32.0249 - mean_absolute_error: 22.1008 - val_loss: 257.5477 - val_root_mean_squared_error: 16.0483 - val_mean_absolute_error: 11.2298
# Epoch 489/500
# 37/37 [==============================] - ETA: 0s - loss: 667.4250 - root_mean_squared_error: 25.8346 - mean_absolute_error: 17.5668
# Epoch 489: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 667.4250 - root_mean_squared_error: 25.8346 - mean_absolute_error: 17.5668 - val_loss: 277.2040 - val_root_mean_squared_error: 16.6494 - val_mean_absolute_error: 11.7453
# Epoch 490/500
# 30/37 [=======================>......] - ETA: 0s - loss: 921.2421 - root_mean_squared_error: 30.3520 - mean_absolute_error: 19.2894
# Epoch 490: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 909.4698 - root_mean_squared_error: 30.1574 - mean_absolute_error: 19.3364 - val_loss: 291.7682 - val_root_mean_squared_error: 17.0812 - val_mean_absolute_error: 11.7821
# Epoch 491/500
# 33/37 [=========================>....] - ETA: 0s - loss: 850.7010 - root_mean_squared_error: 29.1668 - mean_absolute_error: 20.5306
# Epoch 491: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 834.2158 - root_mean_squared_error: 28.8828 - mean_absolute_error: 20.4319 - val_loss: 362.6323 - val_root_mean_squared_error: 19.0429 - val_mean_absolute_error: 13.4279
# Epoch 492/500
# 37/37 [==============================] - ETA: 0s - loss: 1004.9785 - root_mean_squared_error: 31.7014 - mean_absolute_error: 22.3487
# Epoch 492: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 1004.9785 - root_mean_squared_error: 31.7014 - mean_absolute_error: 22.3487 - val_loss: 687.3294 - val_root_mean_squared_error: 26.2170 - val_mean_absolute_error: 19.5069
# Epoch 493/500
# 33/37 [=========================>....] - ETA: 0s - loss: 932.2894 - root_mean_squared_error: 30.5334 - mean_absolute_error: 20.9824
# Epoch 493: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 9ms/step - loss: 901.8806 - root_mean_squared_error: 30.0313 - mean_absolute_error: 20.7504 - val_loss: 1362.7184 - val_root_mean_squared_error: 36.9150 - val_mean_absolute_error: 31.9757
# Epoch 494/500
# 31/37 [========================>.....] - ETA: 0s - loss: 986.4491 - root_mean_squared_error: 31.4078 - mean_absolute_error: 21.5230
# Epoch 494: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 11ms/step - loss: 933.8868 - root_mean_squared_error: 30.5596 - mean_absolute_error: 20.8862 - val_loss: 246.0142 - val_root_mean_squared_error: 15.6848 - val_mean_absolute_error: 10.5318
# Epoch 495/500
# 34/37 [==========================>...] - ETA: 0s - loss: 1142.1687 - root_mean_squared_error: 33.7960 - mean_absolute_error: 23.4134
# Epoch 495: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 13ms/step - loss: 1150.0029 - root_mean_squared_error: 33.9117 - mean_absolute_error: 23.7914 - val_loss: 352.3989 - val_root_mean_squared_error: 18.7723 - val_mean_absolute_error: 13.6163
# Epoch 496/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1164.9630 - root_mean_squared_error: 34.1316 - mean_absolute_error: 23.7283
# Epoch 496: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 1177.9362 - root_mean_squared_error: 34.3211 - mean_absolute_error: 24.0553 - val_loss: 469.7001 - val_root_mean_squared_error: 21.6726 - val_mean_absolute_error: 15.7453
# Epoch 497/500
# 33/37 [=========================>....] - ETA: 0s - loss: 1011.8408 - root_mean_squared_error: 31.8094 - mean_absolute_error: 22.1851
# Epoch 497: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 961.8132 - root_mean_squared_error: 31.0131 - mean_absolute_error: 21.5541 - val_loss: 820.0120 - val_root_mean_squared_error: 28.6359 - val_mean_absolute_error: 23.1986
# Epoch 498/500
# 32/37 [========================>.....] - ETA: 0s - loss: 1018.1772 - root_mean_squared_error: 31.9089 - mean_absolute_error: 21.7436
# Epoch 498: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 12ms/step - loss: 990.0756 - root_mean_squared_error: 31.4655 - mean_absolute_error: 21.7803 - val_loss: 2025.9552 - val_root_mean_squared_error: 45.0106 - val_mean_absolute_error: 39.1104
# Epoch 499/500
# 29/37 [======================>.......] - ETA: 0s - loss: 1052.4497 - root_mean_squared_error: 32.4415 - mean_absolute_error: 22.6530
# Epoch 499: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 1000.0031 - root_mean_squared_error: 31.6228 - mean_absolute_error: 22.3463 - val_loss: 878.3063 - val_root_mean_squared_error: 29.6362 - val_mean_absolute_error: 25.2726
# Epoch 500/500
# 31/37 [========================>.....] - ETA: 0s - loss: 701.4129 - root_mean_squared_error: 26.4842 - mean_absolute_error: 18.2397
# Epoch 500: val_loss did not improve from 236.02098
# 37/37 [==============================] - 0s 10ms/step - loss: 772.4011 - root_mean_squared_error: 27.7921 - mean_absolute_error: 19.1016 - val_loss: 612.0276 - val_root_mean_squared_error: 24.7392 - val_mean_absolute_error: 19.6974
#   测试集 R: 0.9644, MAE: 35.9752, RMSE: 55.8231
#   ✓ 已保存模型: ./best_model_final_2/best_model_fold_9.h5
#   ✓ 已保存训练集预测: ./best_model_final_2/fold_predictions/fold_9_train_predictions.csv
#   ✓ 已保存验证集预测: ./best_model_final_2/fold_predictions/fold_9_test_predictions.csv
#
# ============================================================
# 最佳模型训练完成!
# ============================================================
#
# 总体结果:
#   R²:   0.9565 ± 0.0219
#   MAE:  36.4440 ± 6.0663
#   RMSE: 59.7667 ± 18.1985
#
# 结果保存位置:
#   - 模型文件: ./best_model_final_2/best_model_fold_*.h5
#   - 预测结果: ./best_model_final_2/fold_predictions/
#   - 汇总信息: ./best_model_final_2/summary.json
#   - 训练结果: ./best_model_final_2/training_results.csv
#
# ============================================================
# 所有任务完成!
# ============================================================
